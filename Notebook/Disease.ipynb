# %%
import sys
sys.path.append(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation")  # <<< updated path here to refer to the implementation of OT-Impute and other imputation methods
import utils
import Inject_Missing_Values
import Updated_OT
import imputers
import imputers_fullyActive

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from Inject_Missing_Values import *
from imputers import OTimputer #original OT imputer
from Updated_OT import OTimputerDropOutNoise #dropout noise imputer
from imputers_fullyActive import OTimputerFullyActive # fully activeOT

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import time

# %%
# Set random seed
np.random.seed(42)
torch.manual_seed(42)
rng = np.random.default_rng(42)

# %% [markdown]
# ### Disease Data

# %% [markdown]
# Loading the data

# %%
data = fetch_openml(name="diabetes", version=1, as_frame=True)
X_full = data.data.copy()

# %%
# Convert categorical to numerical codes
for col in X_full.select_dtypes(include=['category', 'object']).columns:
    X_full[col] = X_full[col].astype('category').cat.codes

# %%
scaler = MinMaxScaler() #data [0,1]
X_full = pd.DataFrame(scaler.fit_transform(X_full), columns=X_full.columns)

# %% [markdown]
# Storing the clean data as Ground Truth

# %%
GroundTruth = X_full.copy()
X = X_full.copy()

# %%
GroundTruth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   preg    768 non-null    float64
#  1   plas    768 non-null    float64
#  2   pres    768 non-null    float64
#  3   skin    768 non-null    float64
#  4   insu    768 non-null    float64
#  5   mass    768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   age     768 non-null    float64
# dtypes: float64(8)
# memory usage: 48.1 KB

# %%
GroundTruth.nunique()
# Out:
# preg     17
# plas    136
# pres     47
# skin     51
# insu    186
# mass    248
# pedi    517
# age      52
# dtype: int64

# %% [markdown]
# Dependecies for MAR & MNAR

# %%
mean_age = GroundTruth["age"].mean()
mean_preg = GroundTruth["preg"].mean()
mean_plas = GroundTruth["plas"].mean()
median_pres = GroundTruth["pres"].median()
median_skin = GroundTruth["skin"].median()
mean_insu = GroundTruth["insu"].mean()
mean_mass = GroundTruth["mass"].mean()
median_pedi = GroundTruth["pedi"].median()

dependencies_mar = {
    "preg": {
        "influencers": ["plas"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["plas"] >= mean_plas else 0.1
    },
    "plas": {
        "influencers": ["mass"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["mass"] <= mean_mass else 0.1
    },
    "pres": {
        "influencers": ["age"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["age"] >= mean_age else 0.1
    },
    "skin": {
        "influencers": ["pres"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["pres"] <= median_pres else 0.1
    },
    "insu": {
        "influencers": ["preg"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["preg"] >= mean_preg else 0.1
    },
    "mass": {
        "influencers": ["pedi"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["pedi"] >= median_pedi else 0.1
    },
    "pedi": {
        "influencers": ["skin"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["skin"] <= median_skin else 0.1
    },
    "age": {
        "influencers": ["insu"],
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["insu"] >= mean_insu else 0.1
    }
}

# %%
mean_preg = GroundTruth["preg"].mean()
mean_plas = GroundTruth["plas"].mean()
median_pres = GroundTruth["pres"].median()
median_skin = GroundTruth["skin"].median()
mean_insu = GroundTruth["insu"].mean()
mean_mass = GroundTruth["mass"].mean()
median_pedi = GroundTruth["pedi"].median()
mean_age = GroundTruth["age"].mean()


dependencies_mnar = {
    "preg": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["preg"] >= mean_preg else 0.1
    },
    "plas": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["plas"] < mean_plas else 0.1
    },
    "pres": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["pres"] <= median_pres else 0.1
    },
    "skin": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["skin"] >= median_skin else 0.1
    },
    "insu": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["insu"] > mean_insu else 0.1
    },
    "mass": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["mass"] <= mean_mass else 0.1
    },
    "pedi": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["pedi"] >= median_pedi else 0.1
    },
    "age": {
        "condition": lambda row: True,
        "probability": lambda row: 0.5 if row["age"] > mean_age else 0.1
    }
}

# %% [markdown]
# ## Running OT-Impute, OT-Rand & Batch-Impute

# %% [markdown]
# ## MCAR

# %%
missing_rates = np.arange(10, 90, 10)  # 10% to 90% missing
budgets = [0.1, 0.2, 0.3]  # Query 10%, 25%, 50% of missing cells

rng = np.random.default_rng(42)

# Create nested results dictionary
results_mcar = {
    "MSE": {b: {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": []} for b in budgets},
    "MAE": {b: {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": []} for b in budgets},
}


for missing_rate in missing_rates:
    generator_mcar = Inject_Missing_Values() #missing value generating
    miss_mcar, index_mcar = generator_mcar.MCAR(X,missing_rate=missing_rate)

    missing_mask = miss_mcar.isna()

    

    # Vanilla OTImputer (same for all budgets)
    X_missing_tensor = torch.tensor(miss_mcar.values, dtype=torch.float64)
    ot_imputer = OTimputer(niter = 300, batchsize=128)
    X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
    X_imputed = X_imputed_tensor.detach().numpy()

    baseline_mse = mean_squared_error(
        GroundTruth.values[missing_mask.values],
        X_imputed[missing_mask.values]
    )
    baseline_mae = mean_absolute_error(
        GroundTruth.values[missing_mask.values],
        X_imputed[missing_mask.values]
    )

    for budget_fraction in budgets:
        print(f"  -> Budget {int(budget_fraction*100)}%")

        budget = int(budget_fraction * missing_mask.values.sum())

        missing_positions = np.argwhere(missing_mask.values)
   

        # Save Vanilla
        results_mcar["MSE"][budget_fraction]["OT-Impute"].append(baseline_mse)
        results_mcar["MAE"][budget_fraction]["OT-Impute"].append(baseline_mae)

        # Random Fix
        random_indices = rng.choice(len(missing_positions), size=budget, replace=False)
        random_selected_positions = missing_positions[random_indices]

        X_random_fixed = X_imputed.copy()
        for row_idx, col_idx in random_selected_positions:
            X_random_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        random_fix_mse = mean_squared_error(
            GroundTruth.values[missing_mask.values],
            X_random_fixed[missing_mask.values]
        )
        random_fix_mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values],
            X_random_fixed[missing_mask.values]
        )

        results_mcar["MSE"][budget_fraction]["OT-Rand"].append(random_fix_mse)
        results_mcar["MAE"][budget_fraction]["OT-Rand"].append(random_fix_mae)

        # ActiveOT Fix
        imputed_runs = []
        for i in range(4):
            print(f"Run {i+1}...")
            X_missing_tensor = torch.tensor(miss_mcar.values, dtype=torch.float64)
            ot_imputer = OTimputer(niter = 300, batchsize=128)
            X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
            X_imputed = X_imputed_tensor.detach().numpy()
            imputed_runs.append(X_imputed)

        imputed_stack = np.stack(imputed_runs, axis=0)
        imputed_mean = np.nanmean(imputed_stack, axis=0)
        imputed_std = np.nanstd(imputed_stack, axis=0)
        std_values = imputed_std[missing_mask.values]
        top_indices = np.argsort(-std_values)[:budget]
        active_selected_positions = missing_positions[top_indices]

        X_active_fixed = imputed_mean.copy()
        for row_idx, col_idx in active_selected_positions:
            X_active_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        active_fix_mse = mean_squared_error(
            GroundTruth.values[missing_mask.values],
            X_active_fixed[missing_mask.values]
        )
        active_fix_mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values],
            X_active_fixed[missing_mask.values]
        )

        results_mcar["MSE"][budget_fraction]["Batch-Impute"].append(active_fix_mse)
        results_mcar["MAE"][budget_fraction]["Batch-Impute"].append(active_fix_mae)


    



# saving the result
rows = []
for metric in ["MSE", "MAE"]:
    for budget in results_mcar[metric]:
        for method in results_mcar[metric][budget]:
            values = results_mcar[metric][budget][method]
            for missing_rate_idx, value in enumerate(values):
                rows.append({
                    "Metric": metric,
                    "Budget": budget,
                    "Method": method,
                    "MissingRateIndex": missing_rate_idx,
                    metric: value
                })
#dataframe convertion
df_results_mcar = pd.DataFrame(rows)

# MSE and MAE are columns side by side
df_results_mcar = df_results_mcar.pivot_table(
    index=["MissingRateIndex", "Budget", "Method"],
    columns="Metric",
    values=["MSE", "MAE"]
).reset_index()

# Flatten multi-index columns 
df_results_mcar.columns.name = None
df_results_mcar.columns = [col if isinstance(col, str) else col[1] for col in df_results_mcar.columns]
df_results_mcar.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_results_mcar_metrics.csv", index=False)
# Out:
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...

# %%
# --------------------------
# Plotting
# --------------------------
print("\nPlotting results...")

for metric_name in ["MSE", "MAE"]:
    plt.figure(figsize=(14, 5))
    for budget_fraction in budgets:
        plt.subplot(1, len(budgets), budgets.index(budget_fraction) + 1)
        plt.plot(missing_rates , results_mcar[metric_name][budget_fraction]["OT-Impute"], label="OT-Impute", marker='o')
        plt.plot(missing_rates , results_mcar[metric_name][budget_fraction]["OT-Rand"], label="OT-Rand", marker='o')
        plt.plot(missing_rates , results_mcar[metric_name][budget_fraction]["Batch-Impute"], label="Batch-Impute", marker='o')
        plt.xlabel("Missing Rate (%)")
        plt.ylabel(metric_name)
        plt.title(f"{metric_name} (Budget {int(budget_fraction*100)}%)")
        plt.legend()
        plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting results...

# %% [markdown]
# ## MAR

# %%
results_mar = {
    "MSE": {b: {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": []} for b in budgets},
    "MAE": {b: {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": []} for b in budgets},
}
for missing_rate in missing_rates:
    generator_mar = Inject_Missing_Values()
    miss_mar, index_mar = generator_mar.MAR(X,missing_rate=missing_rate,dependencies=dependencies_mar)

    total_missing_percentage_mar = miss_mar.isnull().sum().sum() / miss_mar.size * 100
    print(f"Total Missing Percentage MAR: {total_missing_percentage_mar:.2f}%")

    missing_percentage = (miss_mar.isnull().sum() / len(miss_mar)) * 100
    print(missing_percentage)

    missing_mask = miss_mar.isna()

    # Vanilla OTImputer (same for all budgets)
    X_missing_tensor = torch.tensor(miss_mar.values, dtype=torch.float64)
    ot_imputer = OTimputer(niter = 300, batchsize=128)
    X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
    X_imputed = X_imputed_tensor.detach().numpy()

    baseline_mse = mean_squared_error(
        GroundTruth.values[missing_mask.values],
        X_imputed[missing_mask.values]
    )
    baseline_mae = mean_absolute_error(
        GroundTruth.values[missing_mask.values],
        X_imputed[missing_mask.values]
    )

    for budget_fraction in budgets:
        print(f"  -> Budget {int(budget_fraction*100)}%")

        budget = int(budget_fraction * missing_mask.values.sum())

        missing_positions = np.argwhere(missing_mask.values)
   

        # Save Vanilla
        results_mar["MSE"][budget_fraction]["OT-Impute"].append(baseline_mse)
        results_mar["MAE"][budget_fraction]["OT-Impute"].append(baseline_mae)

        # Random Fix
        random_indices = rng.choice(len(missing_positions), size=budget, replace=False)
        random_selected_positions = missing_positions[random_indices]

        X_random_fixed = X_imputed.copy()
        for row_idx, col_idx in random_selected_positions:
            X_random_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        random_fix_mse = mean_squared_error(
            GroundTruth.values[missing_mask.values],
            X_random_fixed[missing_mask.values]
        )
        random_fix_mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values],
            X_random_fixed[missing_mask.values]
        )

        results_mar["MSE"][budget_fraction]["OT-Rand"].append(random_fix_mse)
        results_mar["MAE"][budget_fraction]["OT-Rand"].append(random_fix_mae)

        # ActiveOT Fix
        imputed_runs = []
        for i in range(4):
            print(f"Run {i+1}...")
            X_missing_tensor = torch.tensor(miss_mar.values, dtype=torch.float64)
            ot_imputer = OTimputer(niter = 300, batchsize=128)
            X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
            X_imputed = X_imputed_tensor.detach().numpy()
            imputed_runs.append(X_imputed)

        imputed_stack = np.stack(imputed_runs, axis=0)
        imputed_mean = np.nanmean(imputed_stack, axis=0)
        imputed_std = np.nanstd(imputed_stack, axis=0)
        std_values = imputed_std[missing_mask.values]
        top_indices = np.argsort(-std_values)[:budget]
        active_selected_positions = missing_positions[top_indices]

        X_active_fixed = imputed_mean.copy()
        for row_idx, col_idx in active_selected_positions:
            X_active_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        active_fix_mse = mean_squared_error(
            GroundTruth.values[missing_mask.values],
            X_active_fixed[missing_mask.values]
        )
        active_fix_mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values],
            X_active_fixed[missing_mask.values]
        )

        results_mar["MSE"][budget_fraction]["Batch-Impute"].append(active_fix_mse)
        results_mar["MAE"][budget_fraction]["Batch-Impute"].append(active_fix_mae)


    



# saving the result
rows = []
for metric in ["MSE", "MAE"]:
    for budget in results_mar[metric]:
        for method in results_mar[metric][budget]:
            values = results_mar[metric][budget][method]
            for missing_rate_idx, value in enumerate(values):
                rows.append({
                    "Metric": metric,
                    "Budget": budget,
                    "Method": method,
                    "MissingRateIndex": missing_rate_idx,
                    metric: value
                })
#dataframe convertion
df_results_mar = pd.DataFrame(rows)

# MSE and MAE are columns side by side
df_results_mar = df_results_mar.pivot_table(
    index=["MissingRateIndex", "Budget", "Method"],
    columns="Metric",
    values=["MSE", "MAE"]
).reset_index()

# Flatten multi-index columns 
df_results_mar.columns.name = None
df_results_mar.columns = [col if isinstance(col, str) else col[1] for col in df_results_mar.columns]
df_results_mar.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_results_mar_metrics.csv", index=False)
# Out:
# Total Missing Percentage MAR: 9.99%
# preg    12.109375
# plas     9.375000
# pres     8.463542
# skin     9.635417
# insu    10.026042
# mass    10.546875
# pedi    10.156250
# age      9.635417
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 19.99%
# preg    22.005208
# plas    21.093750
# pres    16.276042
# skin    20.182292
# insu    19.661458
# mass    20.442708
# pedi    21.744792
# age     18.489583
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 30.00%
# preg    31.380208
# plas    31.640625
# pres    25.130208
# skin    31.250000
# insu    30.468750
# mass    30.989583
# pedi    33.072917
# age     26.041667
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 39.99%
# preg    41.666667
# plas    39.973958
# pres    35.546875
# skin    41.927083
# insu    39.583333
# mass    42.187500
# pedi    42.968750
# age     36.067708
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 50.00%
# preg    49.739583
# plas    51.953125
# pres    45.963542
# skin    52.213542
# insu    49.218750
# mass    51.302083
# pedi    55.859375
# age     43.750000
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 59.99%
# preg    58.984375
# plas    62.239583
# pres    56.119792
# skin    62.760417
# insu    60.416667
# mass    60.807292
# pedi    63.281250
# age     55.338542
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 69.99%
# preg    68.229167
# plas    70.703125
# pres    66.796875
# skin    72.526042
# insu    71.093750
# mass    70.442708
# pedi    73.307292
# age     66.796875
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Total Missing Percentage MAR: 80.00%
# preg    79.947917
# plas    81.380208
# pres    75.781250
# skin    83.072917
# insu    80.208333
# mass    80.859375
# pedi    81.770833
# age     76.953125
# dtype: float64
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...

# %%
# --------------------------
# Plotting
# --------------------------
print("\nPlotting results...")

for metric_name in ["MSE", "MAE"]:
    plt.figure(figsize=(14, 5))
    for budget_fraction in budgets:
        plt.subplot(1, len(budgets), budgets.index(budget_fraction) + 1)
        plt.plot(missing_rates, results_mar[metric_name][budget_fraction]["OT-Impute"], label="OT-Impute", marker='o')
        plt.plot(missing_rates, results_mar[metric_name][budget_fraction]["OT-Rand"], label="OT-Rand", marker='o')
        plt.plot(missing_rates, results_mar[metric_name][budget_fraction]["Batch-Impute"], label="Batch-Impute", marker='o')
        plt.xlabel("Missing Rate (%)")
        plt.ylabel(metric_name)
        plt.title(f"{metric_name} (Budget {int(budget_fraction*100)}%)")
        plt.legend()
        plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting results...

# %% [markdown]
# ## MNAR

# %%
results_mnar = {
    "MSE": {b: {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": []} for b in budgets},
    "MAE": {b: {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": []} for b in budgets},
}
for missing_rate in missing_rates:
    generator_mnar = Inject_Missing_Values()
    miss_mnar, index_mnar = generator_mnar.MAR(X,missing_rate=missing_rate,dependencies=dependencies_mnar)

    missing_mask = miss_mnar.isna()

    # Vanilla OTImputer (same for all budgets)
    X_missing_tensor = torch.tensor(miss_mnar.values, dtype=torch.float64)
    ot_imputer = OTimputer(niter = 300, batchsize=128)
    X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
    X_imputed = X_imputed_tensor.detach().numpy()

    baseline_mse = mean_squared_error(
        GroundTruth.values[missing_mask.values],
        X_imputed[missing_mask.values]
    )
    baseline_mae = mean_absolute_error(
        GroundTruth.values[missing_mask.values],
        X_imputed[missing_mask.values]
    )

    for budget_fraction in budgets:
        print(f"  -> Budget {int(budget_fraction*100)}%")

        budget = int(budget_fraction * missing_mask.values.sum())

        missing_positions = np.argwhere(missing_mask.values)
   

        # Save Vanilla
        results_mnar["MSE"][budget_fraction]["OT-Impute"].append(baseline_mse)
        results_mnar["MAE"][budget_fraction]["OT-Impute"].append(baseline_mae)

        # Random Fix
        random_indices = rng.choice(len(missing_positions), size=budget, replace=False)
        random_selected_positions = missing_positions[random_indices]

        X_random_fixed = X_imputed.copy()
        for row_idx, col_idx in random_selected_positions:
            X_random_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        random_fix_mse = mean_squared_error(
            GroundTruth.values[missing_mask.values],
            X_random_fixed[missing_mask.values]
        )
        random_fix_mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values],
            X_random_fixed[missing_mask.values]
        )

        results_mnar["MSE"][budget_fraction]["OT-Rand"].append(random_fix_mse)
        results_mnar["MAE"][budget_fraction]["OT-Rand"].append(random_fix_mae)

        # ActiveOT Fix
        imputed_runs = []
        for i in range(4):
            print(f"Run {i+1}...")
            X_missing_tensor = torch.tensor(miss_mnar.values, dtype=torch.float64)
            ot_imputer = OTimputer(niter = 300, batchsize=128)
            X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
            X_imputed = X_imputed_tensor.detach().numpy()
            imputed_runs.append(X_imputed)

        imputed_stack = np.stack(imputed_runs, axis=0)
        imputed_mean = np.nanmean(imputed_stack, axis=0)
        imputed_std = np.nanstd(imputed_stack, axis=0)
        std_values = imputed_std[missing_mask.values]
        top_indices = np.argsort(-std_values)[:budget]
        active_selected_positions = missing_positions[top_indices]

        X_active_fixed = imputed_mean.copy()
        for row_idx, col_idx in active_selected_positions:
            X_active_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        active_fix_mse = mean_squared_error(
            GroundTruth.values[missing_mask.values],
            X_active_fixed[missing_mask.values]
        )
        active_fix_mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values],
            X_active_fixed[missing_mask.values]
        )

        results_mnar["MSE"][budget_fraction]["Batch-Impute"].append(active_fix_mse)
        results_mnar["MAE"][budget_fraction]["Batch-Impute"].append(active_fix_mae)


    



# saving the result
rows = []
for metric in ["MSE", "MAE"]:
    for budget in results_mnar[metric]:
        for method in results_mnar[metric][budget]:
            values = results_mnar[metric][budget][method]
            for missing_rate_idx, value in enumerate(values):
                rows.append({
                    "Metric": metric,
                    "Budget": budget,
                    "Method": method,
                    "MissingRateIndex": missing_rate_idx,
                    metric: value
                })
#dataframe convertion
df_results_mnar = pd.DataFrame(rows)

# MSE and MAE are columns side by side
df_results_mnar = df_results_mnar.pivot_table(
    index=["MissingRateIndex", "Budget", "Method"],
    columns="Metric",
    values=["MSE", "MAE"]
).reset_index()

# Flatten multi-index columns 
df_results_mnar.columns.name = None
df_results_mnar.columns = [col if isinstance(col, str) else col[1] for col in df_results_mnar.columns]
df_results_mnar.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_results_mnar_metrics.csv", index=False)
# Out:
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 10%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 20%
# Run 1...
# Run 2...
# Run 3...
# Run 4...
#   -> Budget 30%
# Run 1...
# Run 2...
# Run 3...
# Run 4...

# %%
# --------------------------
# Plotting
# --------------------------
print("\nPlotting results...")

for metric_name in ["MSE", "MAE"]:
    plt.figure(figsize=(14, 5))
    for budget_fraction in budgets:
        plt.subplot(1, len(budgets), budgets.index(budget_fraction) + 1)
        plt.plot(missing_rates, results_mnar[metric_name][budget_fraction]["OT-Impute"], label="OT-Impute", marker='o')
        plt.plot(missing_rates, results_mnar[metric_name][budget_fraction]["OT-Rand"], label="OT-Rand", marker='o')
        plt.plot(missing_rates, results_mnar[metric_name][budget_fraction]["Batch-Impute"], label="Batch-Impute", marker='o')
        plt.xlabel("Missing Rate (%)")
        plt.ylabel(metric_name)
        plt.title(f"{metric_name} (Budget {int(budget_fraction*100)}%)")
        plt.legend()
        plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting results...

# %%
import matplotlib.pyplot as plt

# === Data Setup (replace these with your real data) ===
# Each pattern result should follow this format:
# results_*[metric]["budget_fraction"]["method"] = list of values
pattern_data = {
    "MCAR": results_mcar,
    "MAR": results_mar,
    "MNAR": results_mnar
}

missing_patterns = ["MCAR", "MAR", "MNAR"]
budgets = [0.1, 0.2, 0.3]
methods = ["OT-Impute", "OT-Rand", "Batch-Impute"]
missing_rates = [10, 20, 30, 40, 50, 60, 70, 80]  # Adjust as needed

# === Style Settings ===
line_styles = {0.1: '-', 0.2: '--', 0.3: ':'}
markers = {"OT-Impute": 'o', "OT-Rand": 's', "Batch-Impute": '^'}
colors = {"OT-Impute": '#0072B2', "OT-Rand": '#E69F00', "Batch-Impute": '#009E73'}  # colorblind-friendly

# === Optional: std values for error bands ===
# Format: std_data[pattern][metric][budget][method] = list of stds
# Set to None if not using
std_data = None  # or load your std_data dictionary here

# === Plotting ===
fig, axes = plt.subplots(2, 3, figsize=(18, 10), sharex=True)

metrics = ["MSE", "MAE"]

vanilla_labeled = False

for row_idx, metric in enumerate(metrics):
    for col_idx, pattern in enumerate(missing_patterns):
        ax = axes[row_idx, col_idx]
    
        results = pattern_data[pattern]

        for budget in budgets:
            for method in methods:
                plot_method = "Batch-Impute" if method == "Batch-Impute" else method
                values = results[metric][budget][plot_method]

                if len(values) != len(missing_rates):
                    print(f"⚠️ Skipped: {pattern}, {metric}, {method}, budget {budget}")
                    continue

                # Plot mean line
                if method == "OT-Impute":
                    label = "OT-Impute" if not vanilla_labeled else None
                    vanilla_labeled = True
                else:
                    label = f"{method} ({int(budget * 100)}% budget)"

                

                ax.plot(
                    missing_rates,
                    values,
                    linestyle=line_styles[budget],
                    marker=markers[method],
                    color=colors[method],
                    label=label
                )


                # Optional: Error bands
                if std_data:
                    std_vals = std_data[pattern][metric][budget][method]
                    if len(std_vals) == len(values):
                        lower = [v - s for v, s in zip(values, std_vals)]
                        upper = [v + s for v, s in zip(values, std_vals)]
                        ax.fill_between(missing_rates, lower, upper, color=colors[method], alpha=0.2)

        if row_idx == 0:
            ax.set_title(pattern)
        if col_idx == 0:
            ax.set_ylabel(metric)
        ax.set_xlabel("Missing Rate (%)")
        ax.grid(True)

# === Shared Legend ===
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, fontsize='medium', bbox_to_anchor=(0.5, -0.05))

# === Main Title & Layout ===

plt.tight_layout(rect=[0, 0.07, 1, 0.95])
fig.savefig(r"C:\Users\zhossai3\Desktop\OT-Fix Imputation\Output\Adult_matrix.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Comarision with Baseline

# %% [markdown]
# MCAR Budget 0.1

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import mean_absolute_error

# Configuration
missing_rates = np.arange(10, 90, 10)
budget_fraction = 0.1
methods = ["Mean", "KNN", "MICE", "OT-Impute", "OT-Rand", "Batch-Impute"]
all_results_comparision_mcar_b01 = []

num_runs = 5  # Repeat the whole process this many times

for run in range(num_runs):
    print(f"\n===== RUN {run + 1} / {num_runs} =====")
    for missing_rate in missing_rates:
        print(f"\n=== Missing Rate: {missing_rate}% ===")

        # Inject missing values
        generator = Inject_Missing_Values()
        X_missing, _ = generator.MCAR(X, missing_rate=missing_rate)
        missing_mask = X_missing.isna()
        missing_positions = np.argwhere(missing_mask.values)
        budget = int(budget_fraction * len(missing_positions))

        # Initialize imputers
        imputers = {
            "Mean": lambda df: df.fillna(df.mean()),
            "KNN": KNNImputer(n_neighbors=5),
            "MICE": IterativeImputer(max_iter=50, random_state=42),
            "OT-Impute": OTimputer(niter=300, batchsize=128)
        }

        mae_scores = {}

        # Basic Imputers
        for method in ["Mean", "KNN", "MICE", "OT-Impute"]:
            print(f"Running {method}...")
            try:
                if method == "Mean":
                    imputed = imputers[method](X_missing).values
                elif method == "OT-Impute":
                    Xt = torch.tensor(X_missing.values, dtype=torch.float64)
                    imputed = imputers[method].fit_transform(Xt).detach().numpy()
                else:
                    imputed = imputers[method].fit_transform(X_missing)

                mae = mean_absolute_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])
                mae_scores[method] = round(mae, 4)
                all_results_comparision_mcar_b01.append({
                    "Run": run,
                    "MissingRate(%)": missing_rate,
                    "Method": method,
                    "MAE": round(mae, 4)
                })
            except Exception as e:
                print(f"Error in {method}: {e}")

        # OT-RandomFix
        print("Running OT-RandomFix...")
        imputed_ot = imputers["OT-Impute"].fit_transform(torch.tensor(X_missing.values, dtype=torch.float64)).detach().numpy()
        rand_idx = np.random.choice(len(missing_positions), size=budget, replace=False)
        rand_selected = missing_positions[rand_idx]
        X_random_fixed = imputed_ot.copy()
        for r, c in rand_selected:
            X_random_fixed[r, c] = GroundTruth.values[r, c]

        mae_random = mean_absolute_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])
        mae_scores["OT-Rand"] = round(mae_random, 4)
        all_results_comparision_mcar_b01.append({
            "Run": run,
            "MissingRate(%)": missing_rate,
            "Method": "OT-Rand",
            "MAE": round(mae_random, 4)
        })

        # OT-ActiveOT (1-shot uncertainty)
        print("Running OT-ActiveOT...")
        runs = []
        for _ in range(4):
            Xt = torch.tensor(X_missing.values, dtype=torch.float64)
            runs.append(imputers["OT-Impute"].fit_transform(Xt).detach().numpy())

        stacked = np.stack(runs)
        mean_imp = np.mean(stacked, axis=0)
        std_imp = np.std(stacked, axis=0)
        std_vals = std_imp[missing_mask.values]
        top_idx = np.argsort(-std_vals)[:budget]
        active_selected = missing_positions[top_idx]
        X_active_fixed = mean_imp.copy()
        for r, c in active_selected:
            X_active_fixed[r, c] = GroundTruth.values[r, c]

        mae_active = mean_absolute_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])
        mae_scores["Batch-Impute"] = round(mae_active, 4)
        all_results_comparision_mcar_b01.append({
            "Run": run,
            "MissingRate(%)": missing_rate,
            "Method": "Batch-Impute",
            "MAE": round(mae_active, 4)
        })

        # Print per-missing-rate result
        print("\n📊 MAE Comparison:")
        df_mae = pd.DataFrame([
            {"Method": k, "MAE": v} for k, v in mae_scores.items()
        ]).sort_values("MAE")
        print(df_mae.to_string(index=False))

# === Save all runs ===
df_comparision_mcar_b01 = pd.DataFrame(all_results_comparision_mcar_b01)
df_comparision_mcar_b01.to_csv(
    r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_mae_base_comparison_mcar_budget01_allruns.csv",
    index=False
)
# Out:
# ===== RUN 1 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0818
#      OT-Rand 0.0945
#         MICE 0.0970
#    OT-Impute 0.1022
#          KNN 0.1044
#         Mean 0.1182
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0900
#      OT-Rand 0.0980
#         MICE 0.1046
#          KNN 0.1144
#    OT-Impute 0.1184
#         Mean 0.1221
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0902
#      OT-Rand 0.1039
#    OT-Impute 0.1152
#         MICE 0.1184
#          KNN 0.1214
#         Mean 0.1216
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0968
#      OT-Rand 0.1144
#          KNN 0.1234
#         Mean 0.1247
#    OT-Impute 0.1260
#         MICE 0.1268
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0968
#      OT-Rand 0.1149
#    OT-Impute 0.1222
#         Mean 0.1226
#          KNN 0.1259
#         MICE 0.1314
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1018
#      OT-Rand 0.1173
#         MICE 0.1223
#         Mean 0.1235
#          KNN 0.1253
#    OT-Impute 0.1284
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1034
#      OT-Rand 0.1176
#         Mean 0.1233
#         MICE 0.1258
#          KNN 0.1268
#    OT-Impute 0.1295
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1070
#      OT-Rand 0.1227
#         Mean 0.1235
#          KNN 0.1246
#         MICE 0.1280
#    OT-Impute 0.1341
#
# ===== RUN 2 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0908
#      OT-Rand 0.1020
#         MICE 0.1076
#          KNN 0.1116
#    OT-Impute 0.1135
#         Mean 0.1225
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0938
#      OT-Rand 0.1027
#         MICE 0.1088
#    OT-Impute 0.1148
#          KNN 0.1170
#         Mean 0.1258
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0922
#      OT-Rand 0.1040
#    OT-Impute 0.1160
#         Mean 0.1195
#          KNN 0.1200
#         MICE 0.1244
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0957
#      OT-Rand 0.1089
#    OT-Impute 0.1224
#         Mean 0.1251
#          KNN 0.1272
#         MICE 0.1285
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1006
#      OT-Rand 0.1147
#         MICE 0.1227
#         Mean 0.1234
#          KNN 0.1253
#    OT-Impute 0.1269
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1004
#      OT-Rand 0.1123
#         MICE 0.1201
#         Mean 0.1220
#          KNN 0.1231
#    OT-Impute 0.1278
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1036
#      OT-Rand 0.1194
#         MICE 0.1220
#         Mean 0.1225
#          KNN 0.1277
#    OT-Impute 0.1296
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1086
#      OT-Rand 0.1221
#         Mean 0.1228
#          KNN 0.1266
#         MICE 0.1278
#    OT-Impute 0.1344
#
# ===== RUN 3 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0940
#      OT-Rand 0.1021
#         MICE 0.1046
#          KNN 0.1120
#    OT-Impute 0.1153
#         Mean 0.1245
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0869
#      OT-Rand 0.1022
#         MICE 0.1046
#          KNN 0.1112
#    OT-Impute 0.1122
#         Mean 0.1178
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0953
#      OT-Rand 0.1055
#    OT-Impute 0.1182
#          KNN 0.1208
#         Mean 0.1240
#         MICE 0.1293
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0975
#      OT-Rand 0.1108
#         Mean 0.1245
#    OT-Impute 0.1249
#         MICE 0.1265
#          KNN 0.1293
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0988
#      OT-Rand 0.1106
#         Mean 0.1233
#    OT-Impute 0.1248
#          KNN 0.1270
#         MICE 0.1284
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0996
#      OT-Rand 0.1131
#         MICE 0.1211
#         Mean 0.1227
#          KNN 0.1240
#    OT-Impute 0.1262
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1052
#      OT-Rand 0.1219
#         Mean 0.1230
#         MICE 0.1248
#          KNN 0.1286
#    OT-Impute 0.1338
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1097
#      OT-Rand 0.1227
#         Mean 0.1240
#         MICE 0.1298
#          KNN 0.1301
#    OT-Impute 0.1365
#
# ===== RUN 4 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0790
#      OT-Rand 0.0955
#         MICE 0.0990
#          KNN 0.1034
#    OT-Impute 0.1055
#         Mean 0.1180
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0893
#      OT-Rand 0.1034
#         MICE 0.1055
#    OT-Impute 0.1112
#          KNN 0.1131
#         Mean 0.1230
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0897
#      OT-Rand 0.1024
#          KNN 0.1151
#    OT-Impute 0.1164
#         Mean 0.1222
#         MICE 0.1340
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0929
#      OT-Rand 0.1085
#    OT-Impute 0.1174
#         Mean 0.1223
#          KNN 0.1224
#         MICE 0.1264
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0980
#      OT-Rand 0.1106
#         Mean 0.1223
#    OT-Impute 0.1238
#          KNN 0.1243
#         MICE 0.1265
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1026
#      OT-Rand 0.1145
#         MICE 0.1225
#         Mean 0.1238
#          KNN 0.1245
#    OT-Impute 0.1276
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1060
#      OT-Rand 0.1193
#         Mean 0.1232
#         MICE 0.1246
#          KNN 0.1249
#    OT-Impute 0.1310
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1089
#      OT-Rand 0.1191
#         Mean 0.1224
#         MICE 0.1232
#          KNN 0.1248
#    OT-Impute 0.1329
#
# ===== RUN 5 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0871
#      OT-Rand 0.1001
#         MICE 0.1019
#          KNN 0.1081
#    OT-Impute 0.1105
#         Mean 0.1194
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0827
#      OT-Rand 0.0981
#         MICE 0.1015
#          KNN 0.1083
#    OT-Impute 0.1084
#         Mean 0.1213
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0934
#      OT-Rand 0.1029
#    OT-Impute 0.1192
#         Mean 0.1213
#          KNN 0.1215
#         MICE 0.1263
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0968
#      OT-Rand 0.1109
#    OT-Impute 0.1223
#         Mean 0.1254
#          KNN 0.1288
#         MICE 0.1313
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0982
#      OT-Rand 0.1096
#         Mean 0.1233
#    OT-Impute 0.1247
#          KNN 0.1262
#         MICE 0.1309
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1022
#      OT-Rand 0.1165
#         Mean 0.1236
#         MICE 0.1237
#          KNN 0.1269
#    OT-Impute 0.1282
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1032
#      OT-Rand 0.1177
#         Mean 0.1233
#          KNN 0.1251
#         MICE 0.1252
#    OT-Impute 0.1308
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1056
#      OT-Rand 0.1185
#         MICE 0.1204
#         Mean 0.1219
#          KNN 0.1258
#    OT-Impute 0.1313

# %% [markdown]
# MAR

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import mean_absolute_error

# Configuration
missing_rates = np.arange(10, 90, 10)
budget_fraction = 0.1
methods = ["Mean", "KNN", "MICE", "OT-Impute", "OT-Rand", "Batch-Impute"]
all_results_comparision_mar_b01 = []

num_runs = 5  # Repeat the whole process this many times

for run in range(num_runs):
    print(f"\n===== RUN {run + 1} / {num_runs} =====")
    for missing_rate in missing_rates:
        print(f"\n=== Missing Rate: {missing_rate}% ===")

        # Inject missing values
        generator = Inject_Missing_Values()
        X_missing, _ = generator.MAR(X, missing_rate=missing_rate,dependencies=dependencies_mar)
        missing_mask = X_missing.isna()
        missing_positions = np.argwhere(missing_mask.values)
        budget = int(budget_fraction * len(missing_positions))

        # Initialize imputers
        imputers = {
            "Mean": lambda df: df.fillna(df.mean()),
            "KNN": KNNImputer(n_neighbors=5),
            "MICE": IterativeImputer(max_iter=50, random_state=42),
            "OT-Impute": OTimputer(niter=300, batchsize=128)
        }

        mae_scores = {}

        # Basic Imputers
        for method in ["Mean", "KNN", "MICE", "OT-Impute"]:
            print(f"Running {method}...")
            try:
                if method == "Mean":
                    imputed = imputers[method](X_missing).values
                elif method == "OT-Impute":
                    Xt = torch.tensor(X_missing.values, dtype=torch.float64)
                    imputed = imputers[method].fit_transform(Xt).detach().numpy()
                else:
                    imputed = imputers[method].fit_transform(X_missing)

                mae = mean_absolute_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])
                mae_scores[method] = round(mae, 4)
                all_results_comparision_mar_b01.append({
                    "Run": run,
                    "MissingRate(%)": missing_rate,
                    "Method": method,
                    "MAE": round(mae, 4)
                })
            except Exception as e:
                print(f"Error in {method}: {e}")

        # OT-RandomFix
        print("Running OT-RandomFix...")
        imputed_ot = imputers["OT-Impute"].fit_transform(torch.tensor(X_missing.values, dtype=torch.float64)).detach().numpy()
        rand_idx = np.random.choice(len(missing_positions), size=budget, replace=False)
        rand_selected = missing_positions[rand_idx]
        X_random_fixed = imputed_ot.copy()
        for r, c in rand_selected:
            X_random_fixed[r, c] = GroundTruth.values[r, c]

        mae_random = mean_absolute_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])
        mae_scores["OT-Rand"] = round(mae_random, 4)
        all_results_comparision_mar_b01.append({
            "Run": run,
            "MissingRate(%)": missing_rate,
            "Method": "OT-Rand",
            "MAE": round(mae_random, 4)
        })

        # OT-ActiveOT (1-shot uncertainty)
        print("Running OT-ActiveOT...")
        runs = []
        for _ in range(4):
            Xt = torch.tensor(X_missing.values, dtype=torch.float64)
            runs.append(imputers["OT-Impute"].fit_transform(Xt).detach().numpy())

        stacked = np.stack(runs)
        mean_imp = np.mean(stacked, axis=0)
        std_imp = np.std(stacked, axis=0)
        std_vals = std_imp[missing_mask.values]
        top_idx = np.argsort(-std_vals)[:budget]
        active_selected = missing_positions[top_idx]
        X_active_fixed = mean_imp.copy()
        for r, c in active_selected:
            X_active_fixed[r, c] = GroundTruth.values[r, c]

        mae_active = mean_absolute_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])
        mae_scores["Batch-Impute"] = round(mae_active, 4)
        all_results_comparision_mar_b01.append({
            "Run": run,
            "MissingRate(%)": missing_rate,
            "Method": "Batch-Impute",
            "MAE": round(mae_active, 4)
        })

        # Print per-missing-rate result
        print("\n📊 MAE Comparison:")
        df_mae = pd.DataFrame([
            {"Method": k, "MAE": v} for k, v in mae_scores.items()
        ]).sort_values("MAE")
        print(df_mae.to_string(index=False))

# === Save all runs ===
df_comparision_mar_b01 = pd.DataFrame(all_results_comparision_mar_b01)
df_comparision_mar_b01.to_csv(
    r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_mae_base_comparison_mar_budget01_allruns.csv",
    index=False
)
# Out:
# ===== RUN 1 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0805
#      OT-Rand 0.0901
#         MICE 0.0934
#          KNN 0.1034
#    OT-Impute 0.1037
#         Mean 0.1177
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0855
#      OT-Rand 0.0944
#    OT-Impute 0.1037
#         MICE 0.1048
#          KNN 0.1171
#         Mean 0.1195
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0871
#      OT-Rand 0.0998
#    OT-Impute 0.1123
#         Mean 0.1186
#         MICE 0.1259
#          KNN 0.1314
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0898
#      OT-Rand 0.1046
#    OT-Impute 0.1147
#         Mean 0.1212
#         MICE 0.1298
#          KNN 0.1336
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0927
#      OT-Rand 0.1027
#    OT-Impute 0.1196
#         Mean 0.1219
#         MICE 0.1254
#          KNN 0.1338
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0956
#      OT-Rand 0.1096
#         MICE 0.1233
#    OT-Impute 0.1236
#         Mean 0.1241
#          KNN 0.1259
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1025
#      OT-Rand 0.1152
#          KNN 0.1225
#         Mean 0.1246
#         MICE 0.1257
#    OT-Impute 0.1286
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1082
#          KNN 0.1188
#      OT-Rand 0.1220
#         Mean 0.1252
#         MICE 0.1301
#    OT-Impute 0.1329
#
# ===== RUN 2 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0766
#      OT-Rand 0.0877
#         MICE 0.0934
#    OT-Impute 0.1032
#          KNN 0.1034
#         Mean 0.1177
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0865
#      OT-Rand 0.0928
#         MICE 0.1048
#    OT-Impute 0.1088
#          KNN 0.1171
#         Mean 0.1195
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0861
#      OT-Rand 0.0970
#    OT-Impute 0.1101
#         Mean 0.1186
#         MICE 0.1259
#          KNN 0.1314
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0894
#      OT-Rand 0.1030
#    OT-Impute 0.1119
#         Mean 0.1212
#         MICE 0.1298
#          KNN 0.1336
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0925
#      OT-Rand 0.1022
#    OT-Impute 0.1152
#         Mean 0.1219
#         MICE 0.1254
#          KNN 0.1338
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0969
#      OT-Rand 0.1114
#    OT-Impute 0.1222
#         MICE 0.1233
#         Mean 0.1241
#          KNN 0.1259
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1021
#      OT-Rand 0.1156
#          KNN 0.1225
#         Mean 0.1246
#         MICE 0.1257
#    OT-Impute 0.1304
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1083
#          KNN 0.1188
#      OT-Rand 0.1226
#         Mean 0.1252
#         MICE 0.1301
#    OT-Impute 0.1368
#
# ===== RUN 3 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0773
#      OT-Rand 0.0897
#         MICE 0.0934
#    OT-Impute 0.1027
#          KNN 0.1034
#         Mean 0.1177
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0831
#      OT-Rand 0.0938
#         MICE 0.1048
#    OT-Impute 0.1070
#          KNN 0.1171
#         Mean 0.1195
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0850
#      OT-Rand 0.0968
#    OT-Impute 0.1121
#         Mean 0.1186
#         MICE 0.1259
#          KNN 0.1314
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0894
#      OT-Rand 0.1019
#    OT-Impute 0.1130
#         Mean 0.1212
#         MICE 0.1298
#          KNN 0.1336
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0932
#      OT-Rand 0.1053
#    OT-Impute 0.1168
#         Mean 0.1219
#         MICE 0.1254
#          KNN 0.1338
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0973
#      OT-Rand 0.1090
#         MICE 0.1233
#    OT-Impute 0.1235
#         Mean 0.1241
#          KNN 0.1259
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1027
#      OT-Rand 0.1180
#          KNN 0.1225
#         Mean 0.1246
#    OT-Impute 0.1254
#         MICE 0.1257
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1076
#          KNN 0.1188
#      OT-Rand 0.1212
#         Mean 0.1252
#         MICE 0.1301
#    OT-Impute 0.1342
#
# ===== RUN 4 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0773
#      OT-Rand 0.0885
#         MICE 0.0934
#          KNN 0.1034
#    OT-Impute 0.1036
#         Mean 0.1177
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0851
#      OT-Rand 0.0961
#         MICE 0.1048
#    OT-Impute 0.1074
#          KNN 0.1171
#         Mean 0.1195
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0856
#      OT-Rand 0.0990
#    OT-Impute 0.1118
#         Mean 0.1186
#         MICE 0.1259
#          KNN 0.1314
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0898
#      OT-Rand 0.1022
#    OT-Impute 0.1114
#         Mean 0.1212
#         MICE 0.1298
#          KNN 0.1336
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0914
#      OT-Rand 0.1016
#    OT-Impute 0.1171
#         Mean 0.1219
#         MICE 0.1254
#          KNN 0.1338
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0982
#      OT-Rand 0.1103
#    OT-Impute 0.1215
#         MICE 0.1233
#         Mean 0.1241
#          KNN 0.1259
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1019
#      OT-Rand 0.1152
#          KNN 0.1225
#         Mean 0.1246
#         MICE 0.1257
#    OT-Impute 0.1266
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1071
#          KNN 0.1188
#      OT-Rand 0.1210
#         Mean 0.1252
#         MICE 0.1301
#    OT-Impute 0.1342
#
# ===== RUN 5 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0761
#      OT-Rand 0.0869
#         MICE 0.0934
#    OT-Impute 0.1025
#          KNN 0.1034
#         Mean 0.1177
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0837
#      OT-Rand 0.0949
#         MICE 0.1048
#    OT-Impute 0.1063
#          KNN 0.1171
#         Mean 0.1195
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0883
#      OT-Rand 0.0955
#    OT-Impute 0.1105
#         Mean 0.1186
#         MICE 0.1259
#          KNN 0.1314
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0908
#      OT-Rand 0.1021
#    OT-Impute 0.1120
#         Mean 0.1212
#         MICE 0.1298
#          KNN 0.1336
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0923
#      OT-Rand 0.1043
#    OT-Impute 0.1157
#         Mean 0.1219
#         MICE 0.1254
#          KNN 0.1338
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.0977
#      OT-Rand 0.1103
#    OT-Impute 0.1229
#         MICE 0.1233
#         Mean 0.1241
#          KNN 0.1259
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1016
#      OT-Rand 0.1156
#          KNN 0.1225
#         Mean 0.1246
#         MICE 0.1257
#    OT-Impute 0.1259
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1100
#          KNN 0.1188
#      OT-Rand 0.1220
#         Mean 0.1252
#         MICE 0.1301
#    OT-Impute 0.1368

# %% [markdown]
# MNAR

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import mean_absolute_error

# Configuration
missing_rates = np.arange(10, 90, 10)
budget_fraction = 0.1
methods = ["Mean", "KNN", "MICE", "OT-Impute", "OT-Rand", "Batch-Impute"]
all_results_comparision_mnar_b01 = []

num_runs = 5  # Repeat the whole process this many times

for run in range(num_runs):
    print(f"\n===== RUN {run + 1} / {num_runs} =====")
    for missing_rate in missing_rates:
        print(f"\n=== Missing Rate: {missing_rate}% ===")

        # Inject missing values
        generator = Inject_Missing_Values()
        X_missing, _ = generator.MNAR(X, missing_rate=missing_rate,dependencies=dependencies_mnar)
        missing_mask = X_missing.isna()
        missing_positions = np.argwhere(missing_mask.values)
        budget = int(budget_fraction * len(missing_positions))

        # Initialize imputers
        imputers = {
            "Mean": lambda df: df.fillna(df.mean()),
            "KNN": KNNImputer(n_neighbors=5),
            "MICE": IterativeImputer(max_iter=50, random_state=42),
            "OT-Impute": OTimputer(niter=300, batchsize=128)
        }

        mae_scores = {}

        # Basic Imputers
        for method in ["Mean", "KNN", "MICE", "OT-Impute"]:
            print(f"Running {method}...")
            try:
                if method == "Mean":
                    imputed = imputers[method](X_missing).values
                elif method == "OT-Impute":
                    Xt = torch.tensor(X_missing.values, dtype=torch.float64)
                    imputed = imputers[method].fit_transform(Xt).detach().numpy()
                else:
                    imputed = imputers[method].fit_transform(X_missing)

                mae = mean_absolute_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])
                mae_scores[method] = round(mae, 4)
                all_results_comparision_mnar_b01.append({
                    "Run": run,
                    "MissingRate(%)": missing_rate,
                    "Method": method,
                    "MAE": round(mae, 4)
                })
            except Exception as e:
                print(f"Error in {method}: {e}")

        # OT-RandomFix
        print("Running OT-RandomFix...")
        imputed_ot = imputers["OT-Impute"].fit_transform(torch.tensor(X_missing.values, dtype=torch.float64)).detach().numpy()
        rand_idx = np.random.choice(len(missing_positions), size=budget, replace=False)
        rand_selected = missing_positions[rand_idx]
        X_random_fixed = imputed_ot.copy()
        for r, c in rand_selected:
            X_random_fixed[r, c] = GroundTruth.values[r, c]

        mae_random = mean_absolute_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])
        mae_scores["OT-Rand"] = round(mae_random, 4)
        all_results_comparision_mnar_b01.append({
            "Run": run,
            "MissingRate(%)": missing_rate,
            "Method": "OT-Rand",
            "MAE": round(mae_random, 4)
        })

        # OT-ActiveOT (1-shot uncertainty)
        print("Running OT-ActiveOT...")
        runs = []
        for _ in range(4):
            Xt = torch.tensor(X_missing.values, dtype=torch.float64)
            runs.append(imputers["OT-Impute"].fit_transform(Xt).detach().numpy())

        stacked = np.stack(runs)
        mean_imp = np.mean(stacked, axis=0)
        std_imp = np.std(stacked, axis=0)
        std_vals = std_imp[missing_mask.values]
        top_idx = np.argsort(-std_vals)[:budget]
        active_selected = missing_positions[top_idx]
        X_active_fixed = mean_imp.copy()
        for r, c in active_selected:
            X_active_fixed[r, c] = GroundTruth.values[r, c]

        mae_active = mean_absolute_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])
        mae_scores["Batch-Impute"] = round(mae_active, 4)
        all_results_comparision_mnar_b01.append({
            "Run": run,
            "MissingRate(%)": missing_rate,
            "Method": "Batch-Impute",
            "MAE": round(mae_active, 4)
        })

        # Print per-missing-rate result
        print("\n📊 MAE Comparison:")
        df_mae = pd.DataFrame([
            {"Method": k, "MAE": v} for k, v in mae_scores.items()
        ]).sort_values("MAE")
        print(df_mae.to_string(index=False))

# === Save all runs ===
df_comparision_mnar_b01 = pd.DataFrame(all_results_comparision_mnar_b01)
df_comparision_mnar_b01.to_csv(
    r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_mae_base_comparison_mnar_budget01_allruns.csv",
    index=False
)
# Out:
# ===== RUN 1 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1019
#         MICE 0.1162
#      OT-Rand 0.1178
#          KNN 0.1196
#    OT-Impute 0.1305
#         Mean 0.1329
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1079
#         MICE 0.1195
#      OT-Rand 0.1227
#          KNN 0.1269
#    OT-Impute 0.1325
#         Mean 0.1364
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1133
#      OT-Rand 0.1253
#         MICE 0.1352
#          KNN 0.1369
#    OT-Impute 0.1397
#         Mean 0.1415
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1243
#      OT-Rand 0.1349
#         MICE 0.1434
#          KNN 0.1438
#         Mean 0.1476
#    OT-Impute 0.1491
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1340
#      OT-Rand 0.1430
#         MICE 0.1476
#          KNN 0.1539
#         Mean 0.1546
#    OT-Impute 0.1604
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1427
#      OT-Rand 0.1491
#         MICE 0.1558
#          KNN 0.1613
#         Mean 0.1638
#    OT-Impute 0.1665
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1493
#      OT-Rand 0.1542
#         MICE 0.1645
#         Mean 0.1663
#          KNN 0.1679
#    OT-Impute 0.1731
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1434
#      OT-Rand 0.1481
#          KNN 0.1623
#         Mean 0.1630
#         MICE 0.1635
#    OT-Impute 0.1649
#
# ===== RUN 2 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1025
#      OT-Rand 0.1132
#         MICE 0.1162
#          KNN 0.1196
#    OT-Impute 0.1319
#         Mean 0.1329
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1061
#         MICE 0.1195
#      OT-Rand 0.1235
#          KNN 0.1269
#    OT-Impute 0.1314
#         Mean 0.1364
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1151
#      OT-Rand 0.1281
#         MICE 0.1352
#    OT-Impute 0.1364
#          KNN 0.1369
#         Mean 0.1415
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1267
#      OT-Rand 0.1358
#         MICE 0.1434
#          KNN 0.1438
#         Mean 0.1476
#    OT-Impute 0.1502
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1350
#      OT-Rand 0.1449
#         MICE 0.1476
#          KNN 0.1539
#         Mean 0.1546
#    OT-Impute 0.1591
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1445
#      OT-Rand 0.1502
#         MICE 0.1558
#          KNN 0.1613
#         Mean 0.1638
#    OT-Impute 0.1719
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1491
#      OT-Rand 0.1552
#         MICE 0.1645
#         Mean 0.1663
#          KNN 0.1679
#    OT-Impute 0.1707
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1431
#      OT-Rand 0.1476
#          KNN 0.1623
#         Mean 0.1630
#         MICE 0.1635
#    OT-Impute 0.1672
#
# ===== RUN 3 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1051
#      OT-Rand 0.1151
#         MICE 0.1162
#          KNN 0.1196
#    OT-Impute 0.1307
#         Mean 0.1329
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1075
#         MICE 0.1195
#      OT-Rand 0.1222
#          KNN 0.1269
#         Mean 0.1364
#    OT-Impute 0.1387
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1128
#      OT-Rand 0.1260
#         MICE 0.1352
#          KNN 0.1369
#    OT-Impute 0.1380
#         Mean 0.1415
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1264
#      OT-Rand 0.1341
#         MICE 0.1434
#          KNN 0.1438
#         Mean 0.1476
#    OT-Impute 0.1509
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1329
#      OT-Rand 0.1437
#         MICE 0.1476
#          KNN 0.1539
#         Mean 0.1546
#    OT-Impute 0.1601
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1430
#      OT-Rand 0.1508
#         MICE 0.1558
#          KNN 0.1613
#         Mean 0.1638
#    OT-Impute 0.1683
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1478
#      OT-Rand 0.1540
#         MICE 0.1645
#         Mean 0.1663
#          KNN 0.1679
#    OT-Impute 0.1711
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1426
#      OT-Rand 0.1504
#          KNN 0.1623
#         Mean 0.1630
#         MICE 0.1635
#    OT-Impute 0.1645
#
# ===== RUN 4 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1040
#         MICE 0.1162
#      OT-Rand 0.1166
#          KNN 0.1196
#         Mean 0.1329
#    OT-Impute 0.1331
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1075
#      OT-Rand 0.1192
#         MICE 0.1195
#          KNN 0.1269
#    OT-Impute 0.1331
#         Mean 0.1364
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1127
#      OT-Rand 0.1255
#         MICE 0.1352
#          KNN 0.1369
#    OT-Impute 0.1383
#         Mean 0.1415
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1239
#      OT-Rand 0.1376
#         MICE 0.1434
#          KNN 0.1438
#         Mean 0.1476
#    OT-Impute 0.1548
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1340
#      OT-Rand 0.1436
#         MICE 0.1476
#          KNN 0.1539
#         Mean 0.1546
#    OT-Impute 0.1601
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1435
#      OT-Rand 0.1501
#         MICE 0.1558
#          KNN 0.1613
#         Mean 0.1638
#    OT-Impute 0.1698
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1490
#      OT-Rand 0.1550
#         MICE 0.1645
#         Mean 0.1663
#          KNN 0.1679
#    OT-Impute 0.1729
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1436
#      OT-Rand 0.1487
#          KNN 0.1623
#         Mean 0.1630
#         MICE 0.1635
#    OT-Impute 0.1666
#
# ===== RUN 5 / 5 =====
#
# === Missing Rate: 10% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1051
#      OT-Rand 0.1158
#         MICE 0.1162
#          KNN 0.1196
#    OT-Impute 0.1312
#         Mean 0.1329
#
# === Missing Rate: 20% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1103
#         MICE 0.1195
#      OT-Rand 0.1218
#          KNN 0.1269
#    OT-Impute 0.1359
#         Mean 0.1364
#
# === Missing Rate: 30% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1150
#      OT-Rand 0.1272
#         MICE 0.1352
#          KNN 0.1369
#    OT-Impute 0.1396
#         Mean 0.1415
#
# === Missing Rate: 40% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1241
#      OT-Rand 0.1382
#         MICE 0.1434
#          KNN 0.1438
#         Mean 0.1476
#    OT-Impute 0.1503
#
# === Missing Rate: 50% ===
# Running Mean...
# Running KNN...
# Running MICE...
# c:\Users\zhossai3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1321
#      OT-Rand 0.1432
#         MICE 0.1476
#          KNN 0.1539
#         Mean 0.1546
#    OT-Impute 0.1618
#
# === Missing Rate: 60% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1430
#      OT-Rand 0.1509
#         MICE 0.1558
#          KNN 0.1613
#         Mean 0.1638
#    OT-Impute 0.1694
#
# === Missing Rate: 70% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1489
#      OT-Rand 0.1548
#         MICE 0.1645
#         Mean 0.1663
#          KNN 0.1679
#    OT-Impute 0.1719
#
# === Missing Rate: 80% ===
# Running Mean...
# Running KNN...
# Running MICE...
# Running OT-Impute...
# Running OT-RandomFix...
# Running OT-ActiveOT...
#
# 📊 MAE Comparison:
#       Method    MAE
# Batch-Impute 0.1439
#      OT-Rand 0.1496
#          KNN 0.1623
#         Mean 0.1630
#         MICE 0.1635
#    OT-Impute 0.1650

# %% [markdown]
# ## Optimization

# %% [markdown]
# ### MAE vd Dropout noise for BatchOpt-Impute MCAR

# %%
missing_rate = 30  # 10% to 90%
budget_fractions = 0.1  # fixed 10%
dropOutNoises = [0.0, 0.00001, 0.00005, 0.0001, 0.0005,
                 0.001, 0.005, 0.01, 0.05,
                 0.1]



results_mcar_opt_dropOut = {d: [] for d in dropOutNoises}
n_runs = 10  # or 10


for dropOutNoise in dropOutNoises:
    print(f"\n=== Dropout Noise: {dropOutNoise} ===")
    for run in range(n_runs):
        print(f"  Run {run+1}/{n_runs}")
        
        generator_mcar = Inject_Missing_Values()
        miss_mcar, index_mcar = generator_mcar.MCAR(X, missing_rate=missing_rate)
        missing_mask = miss_mcar.isna()
        missing_positions = np.argwhere(missing_mask.values)
        budget = int(budget_fraction * missing_mask.values.sum())

        X_missing_tensor = torch.tensor(miss_mcar.values, dtype=torch.float64)
        ot_imputer = OTimputerDropOutNoise(
            niter=300,
            batchsize=128,
            dropout_noise_scale=dropOutNoise
        )
        X_imputed_tensor, confidence_scores = ot_imputer.fit_transform(
            X_missing_tensor, track_confidence=True, snapshot_interval=10
        )

        imputed_mean_opt = X_imputed_tensor.detach().numpy()
        std_values_opt = confidence_scores.detach().numpy()
        top_indices_opt = np.argsort(-std_values_opt)[:budget]
        active_selected_positions_opt = missing_positions[top_indices_opt]

        X_activeopt_fixed = imputed_mean_opt.copy()
        for row_idx, col_idx in active_selected_positions_opt:
            X_activeopt_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values]
        )
        results_mcar_opt_dropOut[dropOutNoise].append(mae)





# Flatten results into a list of records
records_mcar_dropOut = []

for noise, maes in results_mcar_opt_dropOut.items():
    for run_id, mae in enumerate(maes):
        records_mcar_dropOut.append({
            "DropoutNoise": noise,
            "Run": run_id + 1,
            "MAE": mae
        })

# Convert to DataFrame
df_results = pd.DataFrame(records_mcar_dropOut)

# Save to CSV
df_results.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MCAR_DropoutNoise_MAE_Results.csv", index=False)
print("Results saved to DropoutNoise_MAE_Results.csv")
# Out:
# === Dropout Noise: 0.0 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 1e-05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 5e-05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.0001 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.0005 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.001 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.005 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.01 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.1 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
# Results saved to DropoutNoise_MAE_Results.csv

# %% [markdown]
# ### MAE vd Dropout noise for BatchOpt-Impute MAR

# %%
missing_rate = 30  # 10% to 90%
budget_fractions = 0.1  # fixed 10%
dropOutNoises = [0.0, 0.00001, 0.00005, 0.0001, 0.0005,
                 0.001, 0.005, 0.01, 0.05,
                 0.1]



results_mar_opt_dropOut = {d: [] for d in dropOutNoises}
n_runs = 10  # or 10


for dropOutNoise in dropOutNoises:
    print(f"\n=== Dropout Noise: {dropOutNoise} ===")
    for run in range(n_runs):
        print(f"  Run {run+1}/{n_runs}")
        
        generator_mar = Inject_Missing_Values()
        miss_mar, index_mar = generator_mar.MAR(X, missing_rate=missing_rate,dependencies=dependencies_mar)
        missing_mask = miss_mar.isna()
        missing_positions = np.argwhere(missing_mask.values)
        budget = int(budget_fraction * missing_mask.values.sum())

        X_missing_tensor = torch.tensor(miss_mar.values, dtype=torch.float64)
        ot_imputer = OTimputerDropOutNoise(
            niter=300,
            batchsize=128,
            dropout_noise_scale=dropOutNoise
        )
        X_imputed_tensor, confidence_scores = ot_imputer.fit_transform(
            X_missing_tensor, track_confidence=True, snapshot_interval=10
        )

        imputed_mean_opt = X_imputed_tensor.detach().numpy()
        std_values_opt = confidence_scores.detach().numpy()
        top_indices_opt = np.argsort(-std_values_opt)[:budget]
        active_selected_positions_opt = missing_positions[top_indices_opt]

        X_activeopt_fixed = imputed_mean_opt.copy()
        for row_idx, col_idx in active_selected_positions_opt:
            X_activeopt_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values]
        )
        results_mar_opt_dropOut[dropOutNoise].append(mae)





# Flatten results into a list of records
records_mar_dropOut = []

for noise, maes in results_mar_opt_dropOut.items():
    for run_id, mae in enumerate(maes):
        records_mar_dropOut.append({
            "DropoutNoise": noise,
            "Run": run_id + 1,
            "MAE": mae
        })

# Convert to DataFrame
df_results = pd.DataFrame(records_mar_dropOut)

# Save to CSV
df_results.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MAR_DropoutNoise_MAE_Results.csv", index=False)
# Out:
# === Dropout Noise: 0.0 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 1e-05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 5e-05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.0001 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.0005 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.001 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.005 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.01 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.1 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10

# %% [markdown]
# ### MAE vd Dropout noise for BatchOpt-Impute MNAR

# %%
missing_rate = 30  # 10% to 90%
budget_fractions = 0.1  # fixed 10%
dropOutNoises = [0.0, 0.00001, 0.00005, 0.0001, 0.0005,
                 0.001, 0.005, 0.01, 0.05,
                 0.1]



results_mnar_opt_dropOut = {d: [] for d in dropOutNoises}
n_runs = 10  # or 10


for dropOutNoise in dropOutNoises:
    print(f"\n=== Dropout Noise: {dropOutNoise} ===")
    for run in range(n_runs):
        print(f"  Run {run+1}/{n_runs}")
        
        generator_mnar = Inject_Missing_Values()
        miss_mnar, index_mnar = generator_mnar.MNAR(X, missing_rate=missing_rate,dependencies=dependencies_mnar)
        missing_mask = miss_mnar.isna()
        missing_positions = np.argwhere(missing_mask.values)
        budget = int(budget_fraction * missing_mask.values.sum())

        X_missing_tensor = torch.tensor(miss_mnar.values, dtype=torch.float64)
        ot_imputer = OTimputerDropOutNoise(
            niter=300,
            batchsize=128,
            dropout_noise_scale=dropOutNoise
        )
        X_imputed_tensor, confidence_scores = ot_imputer.fit_transform(
            X_missing_tensor, track_confidence=True, snapshot_interval=10
        )

        imputed_mean_opt = X_imputed_tensor.detach().numpy()
        std_values_opt = confidence_scores.detach().numpy()
        top_indices_opt = np.argsort(-std_values_opt)[:budget]
        active_selected_positions_opt = missing_positions[top_indices_opt]

        X_activeopt_fixed = imputed_mean_opt.copy()
        for row_idx, col_idx in active_selected_positions_opt:
            X_activeopt_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

        mae = mean_absolute_error(
            GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values]
        )
        results_mnar_opt_dropOut[dropOutNoise].append(mae)





# Flatten results into a list of records
records_mnar_dropOut = []

for noise, maes in results_mnar_opt_dropOut.items():
    for run_id, mae in enumerate(maes):
        records_mnar_dropOut.append({
            "DropoutNoise": noise,
            "Run": run_id + 1,
            "MAE": mae
        })

# Convert to DataFrame
df_results = pd.DataFrame(records_mnar_dropOut)

# Save to CSV
df_results.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MNAR_DropoutNoise_MAE_Results.csv", index=False)
print("Results saved to DropoutNoise_MAE_Results.csv")
# Out:
# === Dropout Noise: 0.0 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 1e-05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 5e-05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.0001 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.0005 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.001 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.005 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.01 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.05 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
#
# === Dropout Noise: 0.1 ===
#   Run 1/10
#   Run 2/10
#   Run 3/10
#   Run 4/10
#   Run 5/10
#   Run 6/10
#   Run 7/10
#   Run 8/10
#   Run 9/10
#   Run 10/10
# Results saved to DropoutNoise_MAE_Results.csv

# %% [markdown]
# MCAR

# %%
missing_rates = np.arange(10, 90, 10)  # 10% to 90%
budget_fraction = 0.1  # fixed 10%

results_mcar_opt = {
    "MSE": {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": [], "BatchOpt-Impute": []},
    "MAE": {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": [], "BatchOpt-Impute": []},
    "Time": {"Batch-Impute": [], "BatchOpt-Impute": []}
}

for missing_rate in missing_rates:
    print(f"\n=== Missing rate: {int(missing_rate)}% ===")

    generator_mcar = Inject_Missing_Values()
    miss_mcar, index_mcar = generator_mcar.MCAR(X,missing_rate=missing_rate)

    missing_mask = miss_mcar.isna()
    missing_positions = np.argwhere(missing_mask.values)

    budget = int(budget_fraction * missing_mask.values.sum())

    # -------------------
    # Vanilla OTImputer, running OT just once
    # -------------------
    X_missing_tensor = torch.tensor(miss_mcar.values, dtype=torch.float64)
    ot_imputer = OTimputer(niter=300, batchsize=128)
    X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)

    imputed = X_imputed_tensor.detach().numpy() #not mean just the normal imp matrix

    baseline_mse = mean_squared_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])
    baseline_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])

    results_mcar_opt["MSE"]["OT-Impute"].append(baseline_mse)
    results_mcar_opt["MAE"]["OT-Impute"].append(baseline_mae)


    # -------------------
    # Random Fix
    # -------------------
    random_indices = rng.choice(len(missing_positions), size=budget, replace=False)
    random_selected_positions = missing_positions[random_indices]

    X_random_fixed = imputed.copy()
    for row_idx, col_idx in random_selected_positions:
        X_random_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    random_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])
    random_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])

    results_mcar_opt["MSE"]["OT-Rand"].append(random_fix_mse)
    results_mcar_opt["MAE"]["OT-Rand"].append(random_fix_mae)

    # -------------------
    # ActiveOT (external std - multiple runs)
    # -------------------

    start_time = time.time()

    imputed_runs = []
    for _ in range(4):
        X_missing_tensor = torch.tensor(miss_mcar.values, dtype=torch.float64)
        ot_imputer = OTimputer(niter=300, batchsize=128)
        X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
        X_imputed = X_imputed_tensor.detach().numpy()
        imputed_runs.append(X_imputed)

    imputed_stack = np.stack(imputed_runs, axis=0)
    imputed_mean_active = np.nanmean(imputed_stack, axis=0)
    imputed_std_active = np.nanstd(imputed_stack, axis=0)

    std_values_active = imputed_std_active[missing_mask.values]
    top_indices = np.argsort(-std_values_active)[:budget]
    active_selected_positions = missing_positions[top_indices]

    X_active_fixed = imputed_mean_active.copy()
    for row_idx, col_idx in active_selected_positions:
        X_active_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    active_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])
    active_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])

    end_time = time.time()
    activeot_time = end_time - start_time

    results_mcar_opt["MSE"]["Batch-Impute"].append(active_fix_mse)
    results_mcar_opt["MAE"]["Batch-Impute"].append(active_fix_mae)
    results_mcar_opt["Time"]["Batch-Impute"].append(activeot_time)


    # -------------------
    # ActiveOTOpt (internal std - track_confidence=True) using internal std to sort confidence
    # -------------------
    start_time = time.time()

    X_missing_tensor = torch.tensor(miss_mcar.values, dtype=torch.float64)
    ot_imputer = OTimputerDropOutNoise(
        niter=300,
        batchsize=128,
        dropout_noise_scale= 0.001
         )
    X_imputed_tensor, confidence_scores = ot_imputer.fit_transform(
        X_missing_tensor, track_confidence=True, snapshot_interval = 10
    )

    imputed_mean_opt = X_imputed_tensor.detach().numpy()
    std_values_opt = confidence_scores.detach().numpy()

    top_indices_opt = np.argsort(-std_values_opt)[:budget]
    active_selected_positions_opt = missing_positions[top_indices_opt]

    X_activeopt_fixed = imputed_mean_opt.copy()
    for row_idx, col_idx in active_selected_positions_opt:
        X_activeopt_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    activeopt_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values])
    activeopt_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values])

    end_time = time.time()
    activeotopt_time = end_time - start_time

    results_mcar_opt["MSE"]["BatchOpt-Impute"].append(activeopt_fix_mse)
    results_mcar_opt["MAE"]["BatchOpt-Impute"].append(activeopt_fix_mae)
    results_mcar_opt["Time"]["BatchOpt-Impute"].append(activeotopt_time)


# Save MAE results
mae_df = pd.DataFrame(results_mcar_opt["MAE"])
mae_df.insert(0, "MissingRate", missing_rates)
mae_df.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MCAR_OPT_Results_MAE.csv", index=False)

# Save Runtime results
time_df = pd.DataFrame(results_mcar_opt["Time"])
time_df.insert(0, "MissingRate", missing_rates)
time_df.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MCAR_OPT_Results_Time.csv", index=False)
# Out:
# === Missing rate: 10% ===
#
# === Missing rate: 20% ===
#
# === Missing rate: 30% ===
#
# === Missing rate: 40% ===
#
# === Missing rate: 50% ===
#
# === Missing rate: 60% ===
#
# === Missing rate: 70% ===
#
# === Missing rate: 80% ===

# %% [markdown]
# MAR

# %%
missing_rates = np.arange(10, 90, 10)  # 10% to 90%
budget_fraction = 0.1  # fixed 10%

results_mar_opt = {
    "MSE": {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": [], "BatchOpt-Impute": []},
    "MAE": {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": [], "BatchOpt-Impute": []},
    "Time": {"Batch-Impute": [], "BatchOpt-Impute": []}
}

for missing_rate in missing_rates:
    print(f"\n=== Missing rate: {int(missing_rate)}% ===")

    generator_mar = Inject_Missing_Values()
    miss_mar, index_mar = generator_mar.MAR(X,missing_rate=missing_rate,dependencies=dependencies_mar)

    missing_mask = miss_mar.isna()
    missing_positions = np.argwhere(missing_mask.values)

    budget = int(budget_fraction * missing_mask.values.sum())

    # -------------------
    # Vanilla OTImputer, running OT just once
    # -------------------
    X_missing_tensor = torch.tensor(miss_mar.values, dtype=torch.float64)
    ot_imputer = OTimputer(niter=300, batchsize=128)
    X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)

    imputed = X_imputed_tensor.detach().numpy() #not mean just the normal imp matrix

    baseline_mse = mean_squared_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])
    baseline_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])

    results_mar_opt["MSE"]["OT-Impute"].append(baseline_mse)
    results_mar_opt["MAE"]["OT-Impute"].append(baseline_mae)


    # -------------------
    # Random Fix
    # -------------------
    random_indices = rng.choice(len(missing_positions), size=budget, replace=False)
    random_selected_positions = missing_positions[random_indices]

    X_random_fixed = imputed.copy()
    for row_idx, col_idx in random_selected_positions:
        X_random_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    random_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])
    random_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])

    results_mar_opt["MSE"]["OT-Rand"].append(random_fix_mse)
    results_mar_opt["MAE"]["OT-Rand"].append(random_fix_mae)

    # -------------------
    # ActiveOT (external std - multiple runs)
    # -------------------

    start_time = time.time()

    imputed_runs = []
    for _ in range(4):
        X_missing_tensor = torch.tensor(miss_mar.values, dtype=torch.float64)
        ot_imputer = OTimputer(niter=300, batchsize=128)
        X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
        X_imputed = X_imputed_tensor.detach().numpy()
        imputed_runs.append(X_imputed)

    imputed_stack = np.stack(imputed_runs, axis=0)
    imputed_mean_active = np.nanmean(imputed_stack, axis=0)
    imputed_std_active = np.nanstd(imputed_stack, axis=0)

    std_values_active = imputed_std_active[missing_mask.values]
    top_indices = np.argsort(-std_values_active)[:budget]
    active_selected_positions = missing_positions[top_indices]

    X_active_fixed = imputed_mean_active.copy()
    for row_idx, col_idx in active_selected_positions:
        X_active_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    active_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])
    active_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])

    end_time = time.time()
    activeot_time = end_time - start_time

    results_mar_opt["MSE"]["Batch-Impute"].append(active_fix_mse)
    results_mar_opt["MAE"]["Batch-Impute"].append(active_fix_mae)
    results_mar_opt["Time"]["Batch-Impute"].append(activeot_time)


    # -------------------
    # ActiveOTOpt (internal std - track_confidence=True) using internal std to sort confidence
    # -------------------
    start_time = time.time()

    X_missing_tensor = torch.tensor(miss_mar.values, dtype=torch.float64)
    ot_imputer = OTimputerDropOutNoise(
        niter=300,
        batchsize=128,
        dropout_noise_scale= 0.001
         )
    X_imputed_tensor, confidence_scores = ot_imputer.fit_transform(
        X_missing_tensor, track_confidence=True, snapshot_interval = 10
    )

    imputed_mean_opt = X_imputed_tensor.detach().numpy()
    std_values_opt = confidence_scores.detach().numpy()

    top_indices_opt = np.argsort(-std_values_opt)[:budget]
    active_selected_positions_opt = missing_positions[top_indices_opt]

    X_activeopt_fixed = imputed_mean_opt.copy()
    for row_idx, col_idx in active_selected_positions_opt:
        X_activeopt_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    activeopt_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values])
    activeopt_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values])

    end_time = time.time()
    activeotopt_time = end_time - start_time

    results_mar_opt["MSE"]["BatchOpt-Impute"].append(activeopt_fix_mse)
    results_mar_opt["MAE"]["BatchOpt-Impute"].append(activeopt_fix_mae)
    results_mar_opt["Time"]["BatchOpt-Impute"].append(activeotopt_time)


# Save MAE results
mae_df = pd.DataFrame(results_mar_opt["MAE"])
mae_df.insert(0, "MissingRate", missing_rates)
mae_df.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MAR_OPT_Results_MAE.csv", index=False)

# Save Runtime results
time_df = pd.DataFrame(results_mar_opt["Time"])
time_df.insert(0, "MissingRate", missing_rates)
time_df.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MAR_OPT_Results_Time.csv", index=False)
# Out:
# === Missing rate: 10% ===
#
# === Missing rate: 20% ===
#
# === Missing rate: 30% ===
#
# === Missing rate: 40% ===
#
# === Missing rate: 50% ===
#
# === Missing rate: 60% ===
#
# === Missing rate: 70% ===
#
# === Missing rate: 80% ===

# %% [markdown]
# MNAR

# %%
missing_rates = np.arange(10, 90, 10)  # 10% to 90%
budget_fraction = 0.1  # fixed 10%

results_mnar_opt = {
    "MSE": {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": [], "BatchOpt-Impute": []},
    "MAE": {"OT-Impute": [], "OT-Rand": [], "Batch-Impute": [], "BatchOpt-Impute": []},
    "Time": {"Batch-Impute": [], "BatchOpt-Impute": []}
}

for missing_rate in missing_rates:
    print(f"\n=== Missing rate: {int(missing_rate)}% ===")

    generator_mnar = Inject_Missing_Values()
    miss_mnar, index_mnar = generator_mnar.MNAR(X,missing_rate=missing_rate,dependencies=dependencies_mnar)

    missing_mask = miss_mnar.isna()
    missing_positions = np.argwhere(missing_mask.values)

    budget = int(budget_fraction * missing_mask.values.sum())

    # -------------------
    # Vanilla OTImputer, running OT just once
    # -------------------
    X_missing_tensor = torch.tensor(miss_mnar.values, dtype=torch.float64)
    ot_imputer = OTimputer(niter=300, batchsize=128)
    X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)

    imputed = X_imputed_tensor.detach().numpy() #not mean just the normal imp matrix

    baseline_mse = mean_squared_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])
    baseline_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], imputed[missing_mask.values])

    results_mnar_opt["MSE"]["OT-Impute"].append(baseline_mse)
    results_mnar_opt["MAE"]["OT-Impute"].append(baseline_mae)


    # -------------------
    # Random Fix
    # -------------------
    random_indices = rng.choice(len(missing_positions), size=budget, replace=False)
    random_selected_positions = missing_positions[random_indices]

    X_random_fixed = imputed.copy()
    for row_idx, col_idx in random_selected_positions:
        X_random_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    random_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])
    random_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_random_fixed[missing_mask.values])

    results_mnar_opt["MSE"]["OT-Rand"].append(random_fix_mse)
    results_mnar_opt["MAE"]["OT-Rand"].append(random_fix_mae)

    # -------------------
    # ActiveOT (external std - multiple runs)
    # -------------------

    start_time = time.time()

    imputed_runs = []
    for _ in range(4):
        X_missing_tensor = torch.tensor(miss_mnar.values, dtype=torch.float64)
        ot_imputer = OTimputer(niter=300, batchsize=128)
        X_imputed_tensor = ot_imputer.fit_transform(X_missing_tensor)
        X_imputed = X_imputed_tensor.detach().numpy()
        imputed_runs.append(X_imputed)

    imputed_stack = np.stack(imputed_runs, axis=0)
    imputed_mean_active = np.nanmean(imputed_stack, axis=0)
    imputed_std_active = np.nanstd(imputed_stack, axis=0)

    std_values_active = imputed_std_active[missing_mask.values]
    top_indices = np.argsort(-std_values_active)[:budget]
    active_selected_positions = missing_positions[top_indices]

    X_active_fixed = imputed_mean_active.copy()
    for row_idx, col_idx in active_selected_positions:
        X_active_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    active_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])
    active_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_active_fixed[missing_mask.values])

    end_time = time.time()
    activeot_time = end_time - start_time

    results_mnar_opt["MSE"]["Batch-Impute"].append(active_fix_mse)
    results_mnar_opt["MAE"]["Batch-Impute"].append(active_fix_mae)
    results_mnar_opt["Time"]["Batch-Impute"].append(activeot_time)


    # -------------------
    # ActiveOTOpt (internal std - track_confidence=True) using internal std to sort confidence
    # -------------------
    start_time = time.time()

    X_missing_tensor = torch.tensor(miss_mnar.values, dtype=torch.float64)
    ot_imputer = OTimputerDropOutNoise(
        niter=300,
        batchsize=128,
        dropout_noise_scale= 0.001
         )
    X_imputed_tensor, confidence_scores = ot_imputer.fit_transform(
        X_missing_tensor, track_confidence=True, snapshot_interval = 10
    )

    imputed_mean_opt = X_imputed_tensor.detach().numpy()
    std_values_opt = confidence_scores.detach().numpy()

    top_indices_opt = np.argsort(-std_values_opt)[:budget]
    active_selected_positions_opt = missing_positions[top_indices_opt]

    X_activeopt_fixed = imputed_mean_opt.copy()
    for row_idx, col_idx in active_selected_positions_opt:
        X_activeopt_fixed[row_idx, col_idx] = GroundTruth.values[row_idx, col_idx]

    activeopt_fix_mse = mean_squared_error(GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values])
    activeopt_fix_mae = mean_absolute_error(GroundTruth.values[missing_mask.values], X_activeopt_fixed[missing_mask.values])

    end_time = time.time()
    activeotopt_time = end_time - start_time

    results_mnar_opt["MSE"]["BatchOpt-Impute"].append(activeopt_fix_mse)
    results_mnar_opt["MAE"]["BatchOpt-Impute"].append(activeopt_fix_mae)
    results_mnar_opt["Time"]["BatchOpt-Impute"].append(activeotopt_time)


# Save MAE results
mae_df = pd.DataFrame(results_mnar_opt["MAE"])
mae_df.insert(0, "MissingRate", missing_rates)
mae_df.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MNAR_OPT_Results_MAE.csv", index=False)

# Save Runtime results
time_df = pd.DataFrame(results_mnar_opt["Time"])
time_df.insert(0, "MissingRate", missing_rates)
time_df.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MNAR_OPT_Results_Time.csv", index=False)
# Out:
# === Missing rate: 10% ===
#
# === Missing rate: 20% ===
#
# === Missing rate: 30% ===
#
# === Missing rate: 40% ===
#
# === Missing rate: 50% ===
#
# === Missing rate: 60% ===
#
# === Missing rate: 70% ===
#
# === Missing rate: 80% ===

# %% [markdown]
# ## Fully Active

# %% [markdown]
# MCAR

# %%
generator_mcar = Inject_Missing_Values()
X_missing, index_mcar = generator_mcar.MCAR(X, missing_rate=30)
mask = X_missing.isna()
missing_pos = np.argwhere(mask.values)

results_fullyActive_mcar = []
max_k = 15
budget_fractions = [0.1, 0.2, 0.3]

for budget_fraction in budget_fractions:
    print(f"\n===== Running for Budget Fraction: {budget_fraction} =====")
    budget = int(budget_fraction * len(missing_pos))

    for k in range(1, max_k + 1):
        print(f"\nRunning iterative ActiveFix with k={k} steps...")
        start = time.time()
        current_X = X_missing.copy()
        fixed_mask = np.zeros_like(mask.values, dtype=bool)  # Tracks fixed values
        budget_per_iter = budget // k

        if budget_per_iter == 0:
            print(f"  Skipping k={k} (budget too small per iteration)")
            continue

        intermediate_mae = []
        unique_queried_cells = set()
        avg_std_per_iteration = []

        for step in range(k):
            print(f"  Iteration {step+1}/{k}...")

            # Start from the original missing data with fixed values filled in
            initial_X = X_missing.values.copy()
            initial_X[fixed_mask] = GroundTruth.values[fixed_mask]

            # Run OTimputer 4 times to obtain aggregated imputed values
            X_runs = []
            for _ in range(4):
                Xt = torch.tensor(initial_X, dtype=torch.float64)
                X_imp = OTimputerFullyActive(niter=100, batchsize=64).fit_transform(Xt).detach().numpy()
                X_runs.append(X_imp)

            # Aggregate the imputed values (mean and std)
            X_stack = np.stack(X_runs)
            X_mean = np.mean(X_stack, axis=0)
            X_std = np.std(X_stack, axis=0)

            # Update the imputed values with the aggregated mean, keeping fixed values intact
            current_X.values[mask.values & ~fixed_mask] = X_mean[mask.values & ~fixed_mask]

            # Identify uncertain cells not fixed yet
            candidates = np.argwhere(mask.values & ~fixed_mask)
            std_vals = np.array([X_std[tuple(pos)] for pos in candidates])

            # Sort the standard deviations in descending order and select the top uncertain cells
            top_idx = np.argsort(-std_vals)[:min(budget_per_iter, len(std_vals))]
            selected_pos = candidates[top_idx]

            # Update unique queried cells and average std for this iteration
            unique_queried_cells.update([tuple(pos) for pos in selected_pos])
            avg_std = np.mean([X_std[tuple(pos)] for pos in selected_pos])
            avg_std_per_iteration.append(avg_std)

            print(f"    X_std (non-zero elements): {np.count_nonzero(X_std)}")
            print(f"    X_std (max value): {np.max(X_std)}")
            print(f"    Avg Std of Queried Cells: {avg_std:.4f}")

            # Query the oracle and update the dataset
            if selected_pos.size > 0:
                rows, cols = zip(*selected_pos)
                current_X.values[rows, cols] = GroundTruth.values[rows, cols]
                fixed_mask[rows, cols] = True  # Mark these cells as fixed

            # Calculate intermediate MAE after each iteration
            mae_iter = mean_absolute_error(GroundTruth.values[mask.values], current_X.values[mask.values])
            intermediate_mae.append(mae_iter)
            print(f"    Intermediate MAE after iteration {step+1}: {mae_iter:.4f}")

        elapsed = time.time() - start
        mae = mean_absolute_error(GroundTruth.values[mask.values], current_X.values[mask.values])
        num_unique = len(unique_queried_cells)
        avg_std_total = np.mean(avg_std_per_iteration)

        results_fullyActive_mcar.append({
            'k': k,
            'BudgetFraction': budget_fraction,
            'MAE': mae,
            'Runtime': elapsed,
            'UniqueQueried': num_unique,
            'AvgStdQueried': avg_std_total
        })
        print(f"  Final MAE: {mae:.4f}, Time: {elapsed:.2f}s, Unique Queried: {num_unique}, Avg Std: {avg_std_total:.4f}")

# Convert results to DataFrame and display
df_iter_mcar = pd.DataFrame(results_fullyActive_mcar)
print("\nFinal Results:")
print(df_iter_mcar)

df_iter_mcar = pd.DataFrame(results_fullyActive_mcar)
print("\nFinal Results:")
print(df_iter_mcar)

# Save the results to CSV
df_iter_mcar.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MCAR.csv", index=False)
print("Results saved to German_iterative_activeFix_results.csv.")
# Out:
# ===== Running for Budget Fraction: 0.1 =====
#
# Running iterative ActiveFix with k=1 steps...
#   Iteration 1/1...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.24330051043094594
#     Avg Std of Queried Cells: 0.1530
#     Intermediate MAE after iteration 1: 0.0961
#   Final MAE: 0.0961, Time: 62.99s, Unique Queried: 184, Avg Std: 0.1530
#
# Running iterative ActiveFix with k=2 steps...
#   Iteration 1/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.21789863916853106
#     Avg Std of Queried Cells: 0.1664
#     Intermediate MAE after iteration 1: 0.0998
#   Iteration 2/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.27790739865395164
#     Avg Std of Queried Cells: 0.1666
#     Intermediate MAE after iteration 2: 0.0913
#   Final MAE: 0.0913, Time: 153.20s, Unique Queried: 184, Avg Std: 0.1665
#
# Running iterative ActiveFix with k=3 steps...
#   Iteration 1/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.282606539452093
#     Avg Std of Queried Cells: 0.1830
#     Intermediate MAE after iteration 1: 0.1022
#   Iteration 2/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1782
#     X_std (max value): 0.23528220816288692
#     Avg Std of Queried Cells: 0.1847
#     Intermediate MAE after iteration 2: 0.0975
#   Iteration 3/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1721
#     X_std (max value): 0.24021896094400474
#     Avg Std of Queried Cells: 0.1712
#     Intermediate MAE after iteration 3: 0.0935
#   Final MAE: 0.0935, Time: 220.42s, Unique Queried: 183, Avg Std: 0.1796
#
# Running iterative ActiveFix with k=4 steps...
#   Iteration 1/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2539992210590512
#     Avg Std of Queried Cells: 0.1847
#     Intermediate MAE after iteration 1: 0.1042
#   Iteration 2/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1797
#     X_std (max value): 0.2609497913245728
#     Avg Std of Queried Cells: 0.1851
#     Intermediate MAE after iteration 2: 0.1004
#   Iteration 3/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.24175518439820434
#     Avg Std of Queried Cells: 0.1918
#     Intermediate MAE after iteration 3: 0.0968
#   Iteration 4/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1705
#     X_std (max value): 0.2611693780675111
#     Avg Std of Queried Cells: 0.1733
#     Intermediate MAE after iteration 4: 0.0931
#   Final MAE: 0.0931, Time: 253.06s, Unique Queried: 184, Avg Std: 0.1837
#
# Running iterative ActiveFix with k=5 steps...
#   Iteration 1/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.24373622246784787
#     Avg Std of Queried Cells: 0.1837
#     Intermediate MAE after iteration 1: 0.1062
#   Iteration 2/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.24942878160893864
#     Avg Std of Queried Cells: 0.1963
#     Intermediate MAE after iteration 2: 0.1021
#   Iteration 3/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.28266305529060515
#     Avg Std of Queried Cells: 0.1887
#     Intermediate MAE after iteration 3: 0.0998
#   Iteration 4/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.24164610440267525
#     Avg Std of Queried Cells: 0.1797
#     Intermediate MAE after iteration 4: 0.0973
#   Iteration 5/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.2383733037812761
#     Avg Std of Queried Cells: 0.1820
#     Intermediate MAE after iteration 5: 0.0945
#   Final MAE: 0.0945, Time: 310.23s, Unique Queried: 180, Avg Std: 0.1861
#
# Running iterative ActiveFix with k=6 steps...
#   Iteration 1/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2319091203215209
#     Avg Std of Queried Cells: 0.1969
#     Intermediate MAE after iteration 1: 0.1076
#   Iteration 2/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1813
#     X_std (max value): 0.2542557547897231
#     Avg Std of Queried Cells: 0.1884
#     Intermediate MAE after iteration 2: 0.1058
#   Iteration 3/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.2831819519977746
#     Avg Std of Queried Cells: 0.1972
#     Intermediate MAE after iteration 3: 0.1002
#   Iteration 4/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1753
#     X_std (max value): 0.23588951084970444
#     Avg Std of Queried Cells: 0.1887
#     Intermediate MAE after iteration 4: 0.1000
#   Iteration 5/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.2466749899398471
#     Avg Std of Queried Cells: 0.2010
#     Intermediate MAE after iteration 5: 0.0959
#   Iteration 6/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1693
#     X_std (max value): 0.22992503961959407
#     Avg Std of Queried Cells: 0.1932
#     Intermediate MAE after iteration 6: 0.0931
#   Final MAE: 0.0931, Time: 369.69s, Unique Queried: 180, Avg Std: 0.1942
#
# Running iterative ActiveFix with k=7 steps...
#   Iteration 1/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2828081364379726
#     Avg Std of Queried Cells: 0.1951
#     Intermediate MAE after iteration 1: 0.1054
#   Iteration 2/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1817
#     X_std (max value): 0.25349660643095884
#     Avg Std of Queried Cells: 0.1937
#     Intermediate MAE after iteration 2: 0.1039
#   Iteration 3/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1791
#     X_std (max value): 0.2899893695469869
#     Avg Std of Queried Cells: 0.2043
#     Intermediate MAE after iteration 3: 0.1044
#   Iteration 4/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1765
#     X_std (max value): 0.2519899534121228
#     Avg Std of Queried Cells: 0.2044
#     Intermediate MAE after iteration 4: 0.1009
#   Iteration 5/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1739
#     X_std (max value): 0.24019991867667764
#     Avg Std of Queried Cells: 0.1934
#     Intermediate MAE after iteration 5: 0.0980
#   Iteration 6/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1713
#     X_std (max value): 0.24423020782738902
#     Avg Std of Queried Cells: 0.1918
#     Intermediate MAE after iteration 6: 0.0957
#   Iteration 7/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.2321434092870444
#     Avg Std of Queried Cells: 0.1955
#     Intermediate MAE after iteration 7: 0.0934
#   Final MAE: 0.0934, Time: 420.48s, Unique Queried: 182, Avg Std: 0.1969
#
# Running iterative ActiveFix with k=8 steps...
#   Iteration 1/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.23526159135624392
#     Avg Std of Queried Cells: 0.1999
#     Intermediate MAE after iteration 1: 0.1056
#   Iteration 2/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1820
#     X_std (max value): 0.2514338086316218
#     Avg Std of Queried Cells: 0.1986
#     Intermediate MAE after iteration 2: 0.1052
#   Iteration 3/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1797
#     X_std (max value): 0.21812722464142903
#     Avg Std of Queried Cells: 0.1951
#     Intermediate MAE after iteration 3: 0.1038
#   Iteration 4/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1774
#     X_std (max value): 0.253008839981947
#     Avg Std of Queried Cells: 0.1998
#     Intermediate MAE after iteration 4: 0.1020
#   Iteration 5/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.241254338150775
#     Avg Std of Queried Cells: 0.1995
#     Intermediate MAE after iteration 5: 0.0994
#   Iteration 6/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1728
#     X_std (max value): 0.2250488426135779
#     Avg Std of Queried Cells: 0.1910
#     Intermediate MAE after iteration 6: 0.0998
#   Iteration 7/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1705
#     X_std (max value): 0.2579958808701717
#     Avg Std of Queried Cells: 0.1938
#     Intermediate MAE after iteration 7: 0.0961
#   Iteration 8/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1682
#     X_std (max value): 0.21605963862759775
#     Avg Std of Queried Cells: 0.1847
#     Intermediate MAE after iteration 8: 0.0946
#   Final MAE: 0.0946, Time: 501.00s, Unique Queried: 184, Avg Std: 0.1953
#
# Running iterative ActiveFix with k=9 steps...
#   Iteration 1/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22816842020310452
#     Avg Std of Queried Cells: 0.2005
#     Intermediate MAE after iteration 1: 0.1075
#   Iteration 2/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1823
#     X_std (max value): 0.26299654497344843
#     Avg Std of Queried Cells: 0.1963
#     Intermediate MAE after iteration 2: 0.1045
#   Iteration 3/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1803
#     X_std (max value): 0.2652361072222947
#     Avg Std of Queried Cells: 0.2039
#     Intermediate MAE after iteration 3: 0.1063
#   Iteration 4/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.2554927539538658
#     Avg Std of Queried Cells: 0.1996
#     Intermediate MAE after iteration 4: 0.1028
#   Iteration 5/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1763
#     X_std (max value): 0.2506282382923111
#     Avg Std of Queried Cells: 0.2129
#     Intermediate MAE after iteration 5: 0.1005
#   Iteration 6/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1743
#     X_std (max value): 0.2407809092765196
#     Avg Std of Queried Cells: 0.2029
#     Intermediate MAE after iteration 6: 0.0991
#   Iteration 7/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.23978891210848563
#     Avg Std of Queried Cells: 0.1986
#     Intermediate MAE after iteration 7: 0.0981
#   Iteration 8/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1703
#     X_std (max value): 0.27294982165835885
#     Avg Std of Queried Cells: 0.2019
#     Intermediate MAE after iteration 8: 0.0948
#   Iteration 9/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1683
#     X_std (max value): 0.23655963751017192
#     Avg Std of Queried Cells: 0.1966
#     Intermediate MAE after iteration 9: 0.0935
#   Final MAE: 0.0935, Time: 561.80s, Unique Queried: 180, Avg Std: 0.2015
#
# Running iterative ActiveFix with k=10 steps...
#   Iteration 1/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.23340534526165238
#     Avg Std of Queried Cells: 0.2081
#     Intermediate MAE after iteration 1: 0.1054
#   Iteration 2/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1825
#     X_std (max value): 0.25458295082545734
#     Avg Std of Queried Cells: 0.2021
#     Intermediate MAE after iteration 2: 0.1055
#   Iteration 3/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.25584923686685007
#     Avg Std of Queried Cells: 0.2135
#     Intermediate MAE after iteration 3: 0.1032
#   Iteration 4/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1789
#     X_std (max value): 0.26675952847261164
#     Avg Std of Queried Cells: 0.2086
#     Intermediate MAE after iteration 4: 0.1005
#   Iteration 5/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.2220516469519184
#     Avg Std of Queried Cells: 0.2001
#     Intermediate MAE after iteration 5: 0.0998
#   Iteration 6/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1753
#     X_std (max value): 0.236052169759385
#     Avg Std of Queried Cells: 0.2011
#     Intermediate MAE after iteration 6: 0.0990
#   Iteration 7/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.261179376388771
#     Avg Std of Queried Cells: 0.1938
#     Intermediate MAE after iteration 7: 0.0959
#   Iteration 8/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1717
#     X_std (max value): 0.25512284741389535
#     Avg Std of Queried Cells: 0.2085
#     Intermediate MAE after iteration 8: 0.0970
#   Iteration 9/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.21568674411487285
#     Avg Std of Queried Cells: 0.1915
#     Intermediate MAE after iteration 9: 0.0943
#   Iteration 10/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1681
#     X_std (max value): 0.23949184711375973
#     Avg Std of Queried Cells: 0.1986
#     Intermediate MAE after iteration 10: 0.0941
#   Final MAE: 0.0941, Time: 627.46s, Unique Queried: 180, Avg Std: 0.2026
#
# Running iterative ActiveFix with k=11 steps...
#   Iteration 1/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.24543589234200588
#     Avg Std of Queried Cells: 0.2060
#     Intermediate MAE after iteration 1: 0.1059
#   Iteration 2/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1827
#     X_std (max value): 0.2607193629733508
#     Avg Std of Queried Cells: 0.2119
#     Intermediate MAE after iteration 2: 0.1063
#   Iteration 3/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1811
#     X_std (max value): 0.27819247212500037
#     Avg Std of Queried Cells: 0.2124
#     Intermediate MAE after iteration 3: 0.1055
#   Iteration 4/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1795
#     X_std (max value): 0.24063028127640532
#     Avg Std of Queried Cells: 0.2122
#     Intermediate MAE after iteration 4: 0.1037
#   Iteration 5/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1779
#     X_std (max value): 0.24448970968096403
#     Avg Std of Queried Cells: 0.2065
#     Intermediate MAE after iteration 5: 0.1020
#   Iteration 6/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1763
#     X_std (max value): 0.2594648018028542
#     Avg Std of Queried Cells: 0.2119
#     Intermediate MAE after iteration 6: 0.1003
#   Iteration 7/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1747
#     X_std (max value): 0.2667506869912479
#     Avg Std of Queried Cells: 0.2025
#     Intermediate MAE after iteration 7: 0.0992
#   Iteration 8/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1731
#     X_std (max value): 0.21010861634294523
#     Avg Std of Queried Cells: 0.1906
#     Intermediate MAE after iteration 8: 0.0983
#   Iteration 9/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1715
#     X_std (max value): 0.2805675029702994
#     Avg Std of Queried Cells: 0.2133
#     Intermediate MAE after iteration 9: 0.0957
#   Iteration 10/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.27044462257342283
#     Avg Std of Queried Cells: 0.2066
#     Intermediate MAE after iteration 10: 0.0944
#   Iteration 11/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1683
#     X_std (max value): 0.2636593535836101
#     Avg Std of Queried Cells: 0.2081
#     Intermediate MAE after iteration 11: 0.0930
#   Final MAE: 0.0930, Time: 709.19s, Unique Queried: 176, Avg Std: 0.2074
#
# Running iterative ActiveFix with k=12 steps...
#   Iteration 1/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.27484789361339923
#     Avg Std of Queried Cells: 0.2147
#     Intermediate MAE after iteration 1: 0.1063
#   Iteration 2/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1828
#     X_std (max value): 0.25056210918732497
#     Avg Std of Queried Cells: 0.2066
#     Intermediate MAE after iteration 2: 0.1071
#   Iteration 3/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1813
#     X_std (max value): 0.227450034617414
#     Avg Std of Queried Cells: 0.2105
#     Intermediate MAE after iteration 3: 0.1051
#   Iteration 4/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1798
#     X_std (max value): 0.24838047537783003
#     Avg Std of Queried Cells: 0.2102
#     Intermediate MAE after iteration 4: 0.1054
#   Iteration 5/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.2295331317662071
#     Avg Std of Queried Cells: 0.2128
#     Intermediate MAE after iteration 5: 0.1030
#   Iteration 6/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1768
#     X_std (max value): 0.23280149072552436
#     Avg Std of Queried Cells: 0.2066
#     Intermediate MAE after iteration 6: 0.1014
#   Iteration 7/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1753
#     X_std (max value): 0.2435962644712559
#     Avg Std of Queried Cells: 0.2056
#     Intermediate MAE after iteration 7: 0.1005
#   Iteration 8/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1738
#     X_std (max value): 0.22506925969835273
#     Avg Std of Queried Cells: 0.1890
#     Intermediate MAE after iteration 8: 0.1000
#   Iteration 9/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.2529011773069972
#     Avg Std of Queried Cells: 0.1953
#     Intermediate MAE after iteration 9: 0.0967
#   Iteration 10/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1708
#     X_std (max value): 0.26755230066053975
#     Avg Std of Queried Cells: 0.2078
#     Intermediate MAE after iteration 10: 0.0966
#   Iteration 11/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1693
#     X_std (max value): 0.2511622961920984
#     Avg Std of Queried Cells: 0.2019
#     Intermediate MAE after iteration 11: 0.0955
#   Iteration 12/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1678
#     X_std (max value): 0.21906238207370332
#     Avg Std of Queried Cells: 0.2059
#     Intermediate MAE after iteration 12: 0.0932
#   Final MAE: 0.0932, Time: 730.85s, Unique Queried: 180, Avg Std: 0.2056
#
# Running iterative ActiveFix with k=13 steps...
#   Iteration 1/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.23116103521335454
#     Avg Std of Queried Cells: 0.2082
#     Intermediate MAE after iteration 1: 0.1063
#   Iteration 2/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1829
#     X_std (max value): 0.24867702619118875
#     Avg Std of Queried Cells: 0.2133
#     Intermediate MAE after iteration 2: 0.1070
#   Iteration 3/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1815
#     X_std (max value): 0.24139932409596354
#     Avg Std of Queried Cells: 0.2052
#     Intermediate MAE after iteration 3: 0.1050
#   Iteration 4/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1801
#     X_std (max value): 0.2593545187431207
#     Avg Std of Queried Cells: 0.2074
#     Intermediate MAE after iteration 4: 0.1038
#   Iteration 5/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1787
#     X_std (max value): 0.24126566509186442
#     Avg Std of Queried Cells: 0.2153
#     Intermediate MAE after iteration 5: 0.1013
#   Iteration 6/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1773
#     X_std (max value): 0.23100853868550228
#     Avg Std of Queried Cells: 0.2040
#     Intermediate MAE after iteration 6: 0.1010
#   Iteration 7/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1759
#     X_std (max value): 0.24725434855240083
#     Avg Std of Queried Cells: 0.2008
#     Intermediate MAE after iteration 7: 0.1006
#   Iteration 8/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1745
#     X_std (max value): 0.23279495359851646
#     Avg Std of Queried Cells: 0.2060
#     Intermediate MAE after iteration 8: 0.0976
#   Iteration 9/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1731
#     X_std (max value): 0.26682334486363174
#     Avg Std of Queried Cells: 0.2108
#     Intermediate MAE after iteration 9: 0.0967
#   Iteration 10/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1717
#     X_std (max value): 0.281758401987357
#     Avg Std of Queried Cells: 0.2188
#     Intermediate MAE after iteration 10: 0.0964
#   Iteration 11/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1703
#     X_std (max value): 0.255994349891404
#     Avg Std of Queried Cells: 0.2024
#     Intermediate MAE after iteration 11: 0.0945
#   Iteration 12/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1689
#     X_std (max value): 0.2679125993558247
#     Avg Std of Queried Cells: 0.2021
#     Intermediate MAE after iteration 12: 0.0915
#   Iteration 13/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1675
#     X_std (max value): 0.2478656237309459
#     Avg Std of Queried Cells: 0.2049
#     Intermediate MAE after iteration 13: 0.0926
#   Final MAE: 0.0926, Time: 817.32s, Unique Queried: 182, Avg Std: 0.2076
#
# Running iterative ActiveFix with k=14 steps...
#   Iteration 1/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2564318400395399
#     Avg Std of Queried Cells: 0.2167
#     Intermediate MAE after iteration 1: 0.1068
#   Iteration 2/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1830
#     X_std (max value): 0.2857892378800463
#     Avg Std of Queried Cells: 0.2248
#     Intermediate MAE after iteration 2: 0.1058
#   Iteration 3/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1817
#     X_std (max value): 0.23998309892204367
#     Avg Std of Queried Cells: 0.2055
#     Intermediate MAE after iteration 3: 0.1060
#   Iteration 4/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1804
#     X_std (max value): 0.23875355625730676
#     Avg Std of Queried Cells: 0.2056
#     Intermediate MAE after iteration 4: 0.1016
#   Iteration 5/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1791
#     X_std (max value): 0.23084753643418535
#     Avg Std of Queried Cells: 0.2090
#     Intermediate MAE after iteration 5: 0.1035
#   Iteration 6/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1778
#     X_std (max value): 0.2505258907106853
#     Avg Std of Queried Cells: 0.2099
#     Intermediate MAE after iteration 6: 0.1028
#   Iteration 7/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1765
#     X_std (max value): 0.24120901594819782
#     Avg Std of Queried Cells: 0.2053
#     Intermediate MAE after iteration 7: 0.0998
#   Iteration 8/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1752
#     X_std (max value): 0.24966086029609497
#     Avg Std of Queried Cells: 0.2155
#     Intermediate MAE after iteration 8: 0.1010
#   Iteration 9/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1739
#     X_std (max value): 0.23695718519523576
#     Avg Std of Queried Cells: 0.2140
#     Intermediate MAE after iteration 9: 0.0981
#   Iteration 10/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1726
#     X_std (max value): 0.22917000789723332
#     Avg Std of Queried Cells: 0.2090
#     Intermediate MAE after iteration 10: 0.0965
#   Iteration 11/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1713
#     X_std (max value): 0.22724906634106407
#     Avg Std of Queried Cells: 0.2009
#     Intermediate MAE after iteration 11: 0.0959
#   Iteration 12/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1700
#     X_std (max value): 0.2518242633037505
#     Avg Std of Queried Cells: 0.2085
#     Intermediate MAE after iteration 12: 0.0945
#   Iteration 13/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.2324130497324951
#     Avg Std of Queried Cells: 0.2049
#     Intermediate MAE after iteration 13: 0.0929
#   Iteration 14/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1674
#     X_std (max value): 0.23648907592871465
#     Avg Std of Queried Cells: 0.2127
#     Intermediate MAE after iteration 14: 0.0921
#   Final MAE: 0.0921, Time: 856.43s, Unique Queried: 182, Avg Std: 0.2102
#
# Running iterative ActiveFix with k=15 steps...
#   Iteration 1/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.26782706584521404
#     Avg Std of Queried Cells: 0.2205
#     Intermediate MAE after iteration 1: 0.1070
#   Iteration 2/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1831
#     X_std (max value): 0.25133117579132436
#     Avg Std of Queried Cells: 0.2230
#     Intermediate MAE after iteration 2: 0.1078
#   Iteration 3/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1819
#     X_std (max value): 0.26775596361859333
#     Avg Std of Queried Cells: 0.2028
#     Intermediate MAE after iteration 3: 0.1049
#   Iteration 4/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.23813444631517497
#     Avg Std of Queried Cells: 0.2049
#     Intermediate MAE after iteration 4: 0.1036
#   Iteration 5/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1795
#     X_std (max value): 0.244527580002493
#     Avg Std of Queried Cells: 0.2107
#     Intermediate MAE after iteration 5: 0.1043
#   Iteration 6/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.2486902296562926
#     Avg Std of Queried Cells: 0.2135
#     Intermediate MAE after iteration 6: 0.1026
#   Iteration 7/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.2353172868463463
#     Avg Std of Queried Cells: 0.2102
#     Intermediate MAE after iteration 7: 0.1012
#   Iteration 8/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1759
#     X_std (max value): 0.2560535430418723
#     Avg Std of Queried Cells: 0.2208
#     Intermediate MAE after iteration 8: 0.1005
#   Iteration 9/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1747
#     X_std (max value): 0.24232463227224366
#     Avg Std of Queried Cells: 0.2100
#     Intermediate MAE after iteration 9: 0.0990
#   Iteration 10/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.27480231191878907
#     Avg Std of Queried Cells: 0.2295
#     Intermediate MAE after iteration 10: 0.0989
#   Iteration 11/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.24930167944291903
#     Avg Std of Queried Cells: 0.2182
#     Intermediate MAE after iteration 11: 0.0987
#   Iteration 12/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1711
#     X_std (max value): 0.21191521339195424
#     Avg Std of Queried Cells: 0.1970
#     Intermediate MAE after iteration 12: 0.0972
#   Iteration 13/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.22183433378639508
#     Avg Std of Queried Cells: 0.1972
#     Intermediate MAE after iteration 13: 0.0952
#   Iteration 14/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.26413743885093766
#     Avg Std of Queried Cells: 0.2223
#     Intermediate MAE after iteration 14: 0.0952
#   Iteration 15/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1675
#     X_std (max value): 0.2393737920796555
#     Avg Std of Queried Cells: 0.2116
#     Intermediate MAE after iteration 15: 0.0933
#   Final MAE: 0.0933, Time: 897.33s, Unique Queried: 180, Avg Std: 0.2128
#
# ===== Running for Budget Fraction: 0.2 =====
#
# Running iterative ActiveFix with k=1 steps...
#   Iteration 1/1...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2546354123962863
#     Avg Std of Queried Cells: 0.1266
#     Intermediate MAE after iteration 1: 0.0806
#   Final MAE: 0.0806, Time: 58.54s, Unique Queried: 368, Avg Std: 0.1266
#
# Running iterative ActiveFix with k=2 steps...
#   Iteration 1/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2748130883982283
#     Avg Std of Queried Cells: 0.1521
#     Intermediate MAE after iteration 1: 0.0940
#   Iteration 2/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1659
#     X_std (max value): 0.23619877506586343
#     Avg Std of Queried Cells: 0.1445
#     Intermediate MAE after iteration 2: 0.0794
#   Final MAE: 0.0794, Time: 124.14s, Unique Queried: 368, Avg Std: 0.1483
#
# Running iterative ActiveFix with k=3 steps...
#   Iteration 1/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2400708128005408
#     Avg Std of Queried Cells: 0.1615
#     Intermediate MAE after iteration 1: 0.0975
#   Iteration 2/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1721
#     X_std (max value): 0.23528839301338755
#     Avg Std of Queried Cells: 0.1547
#     Intermediate MAE after iteration 2: 0.0886
#   Iteration 3/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1599
#     X_std (max value): 0.23892107897763232
#     Avg Std of Queried Cells: 0.1468
#     Intermediate MAE after iteration 3: 0.0785
#   Final MAE: 0.0785, Time: 183.08s, Unique Queried: 366, Avg Std: 0.1544
#
# Running iterative ActiveFix with k=4 steps...
#   Iteration 1/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.26521135166286197
#     Avg Std of Queried Cells: 0.1683
#     Intermediate MAE after iteration 1: 0.1007
#   Iteration 2/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.24458595660111956
#     Avg Std of Queried Cells: 0.1636
#     Intermediate MAE after iteration 2: 0.0930
#   Iteration 3/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1659
#     X_std (max value): 0.24950960464328314
#     Avg Std of Queried Cells: 0.1627
#     Intermediate MAE after iteration 3: 0.0868
#   Iteration 4/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1567
#     X_std (max value): 0.21834707333718434
#     Avg Std of Queried Cells: 0.1511
#     Intermediate MAE after iteration 4: 0.0795
#   Final MAE: 0.0795, Time: 243.62s, Unique Queried: 368, Avg Std: 0.1615
#
# Running iterative ActiveFix with k=5 steps...
#   Iteration 1/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2510146239958074
#     Avg Std of Queried Cells: 0.1689
#     Intermediate MAE after iteration 1: 0.1031
#   Iteration 2/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1770
#     X_std (max value): 0.27341523848598565
#     Avg Std of Queried Cells: 0.1744
#     Intermediate MAE after iteration 2: 0.0968
#   Iteration 3/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1697
#     X_std (max value): 0.23019196479468418
#     Avg Std of Queried Cells: 0.1662
#     Intermediate MAE after iteration 3: 0.0908
#   Iteration 4/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1624
#     X_std (max value): 0.23442810539579265
#     Avg Std of Queried Cells: 0.1567
#     Intermediate MAE after iteration 4: 0.0838
#   Iteration 5/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1551
#     X_std (max value): 0.23419961731309272
#     Avg Std of Queried Cells: 0.1602
#     Intermediate MAE after iteration 5: 0.0796
#   Final MAE: 0.0796, Time: 310.27s, Unique Queried: 365, Avg Std: 0.1653
#
# Running iterative ActiveFix with k=6 steps...
#   Iteration 1/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.25396939447714667
#     Avg Std of Queried Cells: 0.1869
#     Intermediate MAE after iteration 1: 0.1014
#   Iteration 2/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1782
#     X_std (max value): 0.2174124843003702
#     Avg Std of Queried Cells: 0.1725
#     Intermediate MAE after iteration 2: 0.0975
#   Iteration 3/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1721
#     X_std (max value): 0.2402168912657446
#     Avg Std of Queried Cells: 0.1710
#     Intermediate MAE after iteration 3: 0.0925
#   Iteration 4/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1660
#     X_std (max value): 0.21477309164444064
#     Avg Std of Queried Cells: 0.1694
#     Intermediate MAE after iteration 4: 0.0870
#   Iteration 5/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# ...
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1765
#     X_std (max value): 0.23657954922318739
#     Avg Std of Queried Cells: 0.1795
#     Intermediate MAE after iteration 3: 0.0995
#   Iteration 4/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1726
#     X_std (max value): 0.2589998137631811
#     Avg Std of Queried Cells: 0.1826
#     Intermediate MAE after iteration 4: 0.0952
#   Iteration 5/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.22247814907166752
#     Avg Std of Queried Cells: 0.1791
#     Intermediate MAE after iteration 5: 0.0929
#   Iteration 6/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1648
#     X_std (max value): 0.2824320227089096
#     Avg Std of Queried Cells: 0.1762
#     Intermediate MAE after iteration 6: 0.0902
#   Iteration 7/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1609
#     X_std (max value): 0.29757423702651925
#     Avg Std of Queried Cells: 0.1760
#     Intermediate MAE after iteration 7: 0.0846
#   Iteration 8/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1570
#     X_std (max value): 0.24099326163675092
#     Avg Std of Queried Cells: 0.1731
#     Intermediate MAE after iteration 8: 0.0833
#   Iteration 9/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1531
#     X_std (max value): 0.24403056427747358
#     Avg Std of Queried Cells: 0.1778
#     Intermediate MAE after iteration 9: 0.0795
#   Iteration 10/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1492
#     X_std (max value): 0.27163077463889107
#     Avg Std of Queried Cells: 0.1851
#     Intermediate MAE after iteration 10: 0.0785
#   Iteration 11/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1453
#     X_std (max value): 0.2353960896163522
#     Avg Std of Queried Cells: 0.1735
#     Intermediate MAE after iteration 11: 0.0750
#   Iteration 12/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1414
#     X_std (max value): 0.25050506897129826
#     Avg Std of Queried Cells: 0.1810
#     Intermediate MAE after iteration 12: 0.0720
#   Iteration 13/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1375
#     X_std (max value): 0.21902237867601287
#     Avg Std of Queried Cells: 0.1556
#     Intermediate MAE after iteration 13: 0.0690
#   Iteration 14/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1336
#     X_std (max value): 0.23433342282600803
#     Avg Std of Queried Cells: 0.1620
#     Intermediate MAE after iteration 14: 0.0693
#   Final MAE: 0.0693, Time: 847.64s, Unique Queried: 546, Avg Std: 0.1779
#
# Running iterative ActiveFix with k=15 steps...
#   Iteration 1/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.25914663378351344
#     Avg Std of Queried Cells: 0.2022
#     Intermediate MAE after iteration 1: 0.1061
#   Iteration 2/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.2770311815199217
#     Avg Std of Queried Cells: 0.1885
#     Intermediate MAE after iteration 2: 0.1023
#   Iteration 3/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.2578478729985769
#     Avg Std of Queried Cells: 0.1876
#     Intermediate MAE after iteration 3: 0.1000
#   Iteration 4/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.2462296699212268
#     Avg Std of Queried Cells: 0.1867
#     Intermediate MAE after iteration 4: 0.0959
#   Iteration 5/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.24292180013800505
#     Avg Std of Queried Cells: 0.1882
#     Intermediate MAE after iteration 5: 0.0939
#   Iteration 6/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1663
#     X_std (max value): 0.21859311840678688
#     Avg Std of Queried Cells: 0.1716
#     Intermediate MAE after iteration 6: 0.0910
#   Iteration 7/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1627
#     X_std (max value): 0.26693452040884114
#     Avg Std of Queried Cells: 0.1811
#     Intermediate MAE after iteration 7: 0.0889
#   Iteration 8/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1591
#     X_std (max value): 0.22655753467441583
#     Avg Std of Queried Cells: 0.1817
#     Intermediate MAE after iteration 8: 0.0841
#   Iteration 9/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1555
#     X_std (max value): 0.2204966129950437
#     Avg Std of Queried Cells: 0.1681
#     Intermediate MAE after iteration 9: 0.0834
#   Iteration 10/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1519
#     X_std (max value): 0.21050655550969735
#     Avg Std of Queried Cells: 0.1707
#     Intermediate MAE after iteration 10: 0.0812
#   Iteration 11/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1483
#     X_std (max value): 0.2316149649063432
#     Avg Std of Queried Cells: 0.1740
#     Intermediate MAE after iteration 11: 0.0784
#   Iteration 12/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1447
#     X_std (max value): 0.2469759625079534
#     Avg Std of Queried Cells: 0.1647
#     Intermediate MAE after iteration 12: 0.0761
#   Iteration 13/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1411
#     X_std (max value): 0.20237814488185701
#     Avg Std of Queried Cells: 0.1672
#     Intermediate MAE after iteration 13: 0.0734
#   Iteration 14/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1375
#     X_std (max value): 0.21623449287260219
#     Avg Std of Queried Cells: 0.1660
#     Intermediate MAE after iteration 14: 0.0711
#   Iteration 15/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1339
#     X_std (max value): 0.19502399883387384
#     Avg Std of Queried Cells: 0.1561
#     Intermediate MAE after iteration 15: 0.0681
#   Final MAE: 0.0681, Time: 977.40s, Unique Queried: 540, Avg Std: 0.1770
#
# Final Results:
#      k  BudgetFraction       MAE      Runtime  UniqueQueried  AvgStdQueried
# 0    1             0.1  0.096092    62.992816            184       0.152952
# 1    2             0.1  0.091315   153.196187            184       0.166524
# 2    3             0.1  0.093504   220.422066            183       0.179626
# 3    4             0.1  0.093063   253.055698            184       0.183709
# 4    5             0.1  0.094527   310.225814            180       0.186090
# 5    6             0.1  0.093127   369.692526            180       0.194231
# 6    7             0.1  0.093436   420.478762            182       0.196875
# 7    8             0.1  0.094601   500.999215            184       0.195302
# 8    9             0.1  0.093541   561.798338            180       0.201463
# 9   10             0.1  0.094090   627.458959            180       0.202595
# 10  11             0.1  0.093000   709.188508            176       0.207440
# 11  12             0.1  0.093164   730.845702            180       0.205566
# 12  13             0.1  0.092583   817.316628            182       0.207620
# 13  14             0.1  0.092108   856.434716            182       0.210177
# 14  15             0.1  0.093278   897.334924            180       0.212821
# 15   1             0.2  0.080600    58.542458            368       0.126637
# 16   2             0.2  0.079392   124.140042            368       0.148323
# 17   3             0.2  0.078461   183.078985            366       0.154361
# 18   4             0.2  0.079498   243.622862            368       0.161458
# 19   5             0.2  0.079600   310.269811            365       0.165274
# 20   6             0.2  0.080169   365.950623            366       0.170548
# 21   7             0.2  0.079270   436.791389            364       0.173787
# 22   8             0.2  0.079263   484.072917            368       0.177757
# 23   9             0.2  0.081372   545.063832            360       0.183108
# 24  10             0.2  0.079020   621.696302            360       0.183329
# 25  11             0.2  0.078078   746.430460            363       0.187577
# 26  12             0.2  0.081788   822.764512            360       0.190000
# 27  13             0.2  0.079543   845.526488            364       0.188804
# 28  14             0.2  0.079185   920.566208            364       0.190762
# 29  15             0.2  0.080460  1059.623075            360       0.191902
# 30   1             0.3  0.068140    62.850665            552       0.114679
# 31   2             0.3  0.067369   126.641685            552       0.131287
# 32   3             0.3  0.066505   182.975820            552       0.143645
# 33   4             0.3  0.066868   242.458865            552       0.148141
# 34   5             0.3  0.066716   306.313340            550       0.152942
# 35   6             0.3  0.066221   371.519638            552       0.158655
# 36   7             0.3  0.067805   407.065474            546       0.163017
# 37   8             0.3  0.066124   468.907124            552       0.162797
# 38   9             0.3  0.067080   519.285238            549       0.168653
# 39  10             0.3  0.067570   580.085808            550       0.168234
# 40  11             0.3  0.065826   633.665735            550       0.169483
# 41  12             0.3  0.066568   735.292345            552       0.173797
# 42  13             0.3  0.068923  4107.559027            546       0.173171
# 43  14             0.3  0.069266   847.636824            546       0.177865
# 44  15             0.3  0.068133   977.402626            540       0.176963
#
# Final Results:
#      k  BudgetFraction       MAE      Runtime  UniqueQueried  AvgStdQueried
# 0    1             0.1  0.096092    62.992816            184       0.152952
# 1    2             0.1  0.091315   153.196187            184       0.166524
# 2    3             0.1  0.093504   220.422066            183       0.179626
# 3    4             0.1  0.093063   253.055698            184       0.183709
# 4    5             0.1  0.094527   310.225814            180       0.186090
# 5    6             0.1  0.093127   369.692526            180       0.194231
# 6    7             0.1  0.093436   420.478762            182       0.196875
# 7    8             0.1  0.094601   500.999215            184       0.195302
# 8    9             0.1  0.093541   561.798338            180       0.201463
# 9   10             0.1  0.094090   627.458959            180       0.202595
# 10  11             0.1  0.093000   709.188508            176       0.207440
# 11  12             0.1  0.093164   730.845702            180       0.205566
# 12  13             0.1  0.092583   817.316628            182       0.207620
# 13  14             0.1  0.092108   856.434716            182       0.210177
# 14  15             0.1  0.093278   897.334924            180       0.212821
# 15   1             0.2  0.080600    58.542458            368       0.126637
# 16   2             0.2  0.079392   124.140042            368       0.148323
# 17   3             0.2  0.078461   183.078985            366       0.154361
# 18   4             0.2  0.079498   243.622862            368       0.161458
# 19   5             0.2  0.079600   310.269811            365       0.165274
# 20   6             0.2  0.080169   365.950623            366       0.170548
# 21   7             0.2  0.079270   436.791389            364       0.173787
# 22   8             0.2  0.079263   484.072917            368       0.177757
# 23   9             0.2  0.081372   545.063832            360       0.183108
# 24  10             0.2  0.079020   621.696302            360       0.183329
# 25  11             0.2  0.078078   746.430460            363       0.187577
# 26  12             0.2  0.081788   822.764512            360       0.190000
# 27  13             0.2  0.079543   845.526488            364       0.188804
# 28  14             0.2  0.079185   920.566208            364       0.190762
# 29  15             0.2  0.080460  1059.623075            360       0.191902
# 30   1             0.3  0.068140    62.850665            552       0.114679
# 31   2             0.3  0.067369   126.641685            552       0.131287
# 32   3             0.3  0.066505   182.975820            552       0.143645
# 33   4             0.3  0.066868   242.458865            552       0.148141
# 34   5             0.3  0.066716   306.313340            550       0.152942
# 35   6             0.3  0.066221   371.519638            552       0.158655
# 36   7             0.3  0.067805   407.065474            546       0.163017
# 37   8             0.3  0.066124   468.907124            552       0.162797
# 38   9             0.3  0.067080   519.285238            549       0.168653
# 39  10             0.3  0.067570   580.085808            550       0.168234
# 40  11             0.3  0.065826   633.665735            550       0.169483
# 41  12             0.3  0.066568   735.292345            552       0.173797
# 42  13             0.3  0.068923  4107.559027            546       0.173171
# 43  14             0.3  0.069266   847.636824            546       0.177865
# 44  15             0.3  0.068133   977.402626            540       0.176963
# Results saved to German_iterative_activeFix_results.csv.

# %% [markdown]
# MAR

# %%
generator_mar = Inject_Missing_Values()
X_missing, index_mar = generator_mar.MAR(X, missing_rate=30,dependencies=dependencies_mar)
mask = X_missing.isna()
missing_pos = np.argwhere(mask.values)

results_fullyActive_mar = []
max_k = 15
budget_fractions = [0.1, 0.2, 0.3]

for budget_fraction in budget_fractions:
    print(f"\n===== Running for Budget Fraction: {budget_fraction} =====")
    budget = int(budget_fraction * len(missing_pos))

    for k in range(1, max_k + 1):
        print(f"\nRunning iterative ActiveFix with k={k} steps...")
        start = time.time()
        current_X = X_missing.copy()
        fixed_mask = np.zeros_like(mask.values, dtype=bool)  # Tracks fixed values
        budget_per_iter = budget // k

        if budget_per_iter == 0:
            print(f"  Skipping k={k} (budget too small per iteration)")
            continue

        intermediate_mae = []
        unique_queried_cells = set()
        avg_std_per_iteration = []

        for step in range(k):
            print(f"  Iteration {step+1}/{k}...")

            # Start from the original missing data with fixed values filled in
            initial_X = X_missing.values.copy()
            initial_X[fixed_mask] = GroundTruth.values[fixed_mask]

            # Run OTimputer 4 times to obtain aggregated imputed values
            X_runs = []
            for _ in range(4):
                Xt = torch.tensor(initial_X, dtype=torch.float64)
                X_imp = OTimputerFullyActive(niter=100, batchsize=64).fit_transform(Xt).detach().numpy()
                X_runs.append(X_imp)

            # Aggregate the imputed values (mean and std)
            X_stack = np.stack(X_runs)
            X_mean = np.mean(X_stack, axis=0)
            X_std = np.std(X_stack, axis=0)

            # Update the imputed values with the aggregated mean, keeping fixed values intact
            current_X.values[mask.values & ~fixed_mask] = X_mean[mask.values & ~fixed_mask]

            # Identify uncertain cells not fixed yet
            candidates = np.argwhere(mask.values & ~fixed_mask)
            std_vals = np.array([X_std[tuple(pos)] for pos in candidates])

            # Sort the standard deviations in descending order and select the top uncertain cells
            top_idx = np.argsort(-std_vals)[:min(budget_per_iter, len(std_vals))]
            selected_pos = candidates[top_idx]

            # Update unique queried cells and average std for this iteration
            unique_queried_cells.update([tuple(pos) for pos in selected_pos])
            avg_std = np.mean([X_std[tuple(pos)] for pos in selected_pos])
            avg_std_per_iteration.append(avg_std)

            print(f"    X_std (non-zero elements): {np.count_nonzero(X_std)}")
            print(f"    X_std (max value): {np.max(X_std)}")
            print(f"    Avg Std of Queried Cells: {avg_std:.4f}")

            # Query the oracle and update the dataset
            if selected_pos.size > 0:
                rows, cols = zip(*selected_pos)
                current_X.values[rows, cols] = GroundTruth.values[rows, cols]
                fixed_mask[rows, cols] = True  # Mark these cells as fixed

            # Calculate intermediate MAE after each iteration
            mae_iter = mean_absolute_error(GroundTruth.values[mask.values], current_X.values[mask.values])
            intermediate_mae.append(mae_iter)
            print(f"    Intermediate MAE after iteration {step+1}: {mae_iter:.4f}")

        elapsed = time.time() - start
        mae = mean_absolute_error(GroundTruth.values[mask.values], current_X.values[mask.values])
        num_unique = len(unique_queried_cells)
        avg_std_total = np.mean(avg_std_per_iteration)

        results_fullyActive_mar.append({
            'k': k,
            'BudgetFraction': budget_fraction,
            'MAE': mae,
            'Runtime': elapsed,
            'UniqueQueried': num_unique,
            'AvgStdQueried': avg_std_total
        })
        print(f"  Final MAE: {mae:.4f}, Time: {elapsed:.2f}s, Unique Queried: {num_unique}, Avg Std: {avg_std_total:.4f}")

df_iter_mar = pd.DataFrame(results_fullyActive_mar)
print("\nFinal Results:")
print(df_iter_mar)

df_iter_mar = pd.DataFrame(results_fullyActive_mar)
print("\nFinal Results:")
print(df_iter_mar)

# Save the results to CSV
df_iter_mar.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MAR.csv", index=False)
# Out:
# ===== Running for Budget Fraction: 0.1 =====
#
# Running iterative ActiveFix with k=1 steps...
#   Iteration 1/1...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.23859400004224565
#     Avg Std of Queried Cells: 0.1486
#     Intermediate MAE after iteration 1: 0.0941
#   Final MAE: 0.0941, Time: 53.44s, Unique Queried: 184, Avg Std: 0.1486
#
# Running iterative ActiveFix with k=2 steps...
#   Iteration 1/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22678553371898275
#     Avg Std of Queried Cells: 0.1605
#     Intermediate MAE after iteration 1: 0.0989
#   Iteration 2/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.259477808108232
#     Avg Std of Queried Cells: 0.1630
#     Intermediate MAE after iteration 2: 0.0922
#   Final MAE: 0.0922, Time: 143.33s, Unique Queried: 184, Avg Std: 0.1617
#
# Running iterative ActiveFix with k=3 steps...
#   Iteration 1/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2773394697805094
#     Avg Std of Queried Cells: 0.1768
#     Intermediate MAE after iteration 1: 0.1013
#   Iteration 2/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1782
#     X_std (max value): 0.23105136717883787
#     Avg Std of Queried Cells: 0.1592
#     Intermediate MAE after iteration 2: 0.0971
#   Iteration 3/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1721
#     X_std (max value): 0.24527288150054155
#     Avg Std of Queried Cells: 0.1688
#     Intermediate MAE after iteration 3: 0.0921
#   Final MAE: 0.0921, Time: 209.83s, Unique Queried: 183, Avg Std: 0.1683
#
# Running iterative ActiveFix with k=4 steps...
#   Iteration 1/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2510034424028164
#     Avg Std of Queried Cells: 0.1863
#     Intermediate MAE after iteration 1: 0.1020
#   Iteration 2/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1797
#     X_std (max value): 0.24346162488663586
#     Avg Std of Queried Cells: 0.1776
#     Intermediate MAE after iteration 2: 0.0971
#   Iteration 3/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.21978339836952202
#     Avg Std of Queried Cells: 0.1788
#     Intermediate MAE after iteration 3: 0.0964
#   Iteration 4/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1705
#     X_std (max value): 0.23081119811935638
#     Avg Std of Queried Cells: 0.1761
#     Intermediate MAE after iteration 4: 0.0921
#   Final MAE: 0.0921, Time: 306.01s, Unique Queried: 184, Avg Std: 0.1797
#
# Running iterative ActiveFix with k=5 steps...
#   Iteration 1/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22343981708072855
#     Avg Std of Queried Cells: 0.1798
#     Intermediate MAE after iteration 1: 0.1027
#   Iteration 2/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.2563851111555948
#     Avg Std of Queried Cells: 0.1968
#     Intermediate MAE after iteration 2: 0.1000
#   Iteration 3/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.24817457326156084
#     Avg Std of Queried Cells: 0.1880
#     Intermediate MAE after iteration 3: 0.0984
#   Iteration 4/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.26905111062050613
#     Avg Std of Queried Cells: 0.1852
#     Intermediate MAE after iteration 4: 0.0954
#   Iteration 5/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.23976576128195862
#     Avg Std of Queried Cells: 0.1788
#     Intermediate MAE after iteration 5: 0.0928
#   Final MAE: 0.0928, Time: 333.24s, Unique Queried: 180, Avg Std: 0.1857
#
# Running iterative ActiveFix with k=6 steps...
#   Iteration 1/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.25254419471671136
#     Avg Std of Queried Cells: 0.2010
#     Intermediate MAE after iteration 1: 0.1037
#   Iteration 2/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1813
#     X_std (max value): 0.23784522748477008
#     Avg Std of Queried Cells: 0.1906
#     Intermediate MAE after iteration 2: 0.1019
#   Iteration 3/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.22539064517386317
#     Avg Std of Queried Cells: 0.1900
#     Intermediate MAE after iteration 3: 0.0980
#   Iteration 4/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1753
#     X_std (max value): 0.24066083022285345
#     Avg Std of Queried Cells: 0.1884
#     Intermediate MAE after iteration 4: 0.0985
#   Iteration 5/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.2286028922382221
#     Avg Std of Queried Cells: 0.1804
#     Intermediate MAE after iteration 5: 0.0942
#   Iteration 6/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1693
#     X_std (max value): 0.258380045423418
#     Avg Std of Queried Cells: 0.1824
#     Intermediate MAE after iteration 6: 0.0936
#   Final MAE: 0.0936, Time: 510.48s, Unique Queried: 180, Avg Std: 0.1888
#
# Running iterative ActiveFix with k=7 steps...
#   Iteration 1/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.24390505882952096
#     Avg Std of Queried Cells: 0.1899
#     Intermediate MAE after iteration 1: 0.1030
#   Iteration 2/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1817
#     X_std (max value): 0.2692162960047915
#     Avg Std of Queried Cells: 0.1938
#     Intermediate MAE after iteration 2: 0.1021
#   Iteration 3/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1791
#     X_std (max value): 0.2645205567510716
#     Avg Std of Queried Cells: 0.2003
#     Intermediate MAE after iteration 3: 0.1012
#   Iteration 4/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1765
#     X_std (max value): 0.27048823000329425
#     Avg Std of Queried Cells: 0.1974
#     Intermediate MAE after iteration 4: 0.0984
#   Iteration 5/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1739
#     X_std (max value): 0.2699568984241038
#     Avg Std of Queried Cells: 0.1933
#     Intermediate MAE after iteration 5: 0.0961
#   Iteration 6/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1713
#     X_std (max value): 0.24235696964031117
#     Avg Std of Queried Cells: 0.1926
#     Intermediate MAE after iteration 6: 0.0948
#   Iteration 7/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.23980542943346814
#     Avg Std of Queried Cells: 0.1786
#     Intermediate MAE after iteration 7: 0.0915
#   Final MAE: 0.0915, Time: 449.69s, Unique Queried: 182, Avg Std: 0.1923
#
# Running iterative ActiveFix with k=8 steps...
#   Iteration 1/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22953444869444717
#     Avg Std of Queried Cells: 0.1937
#     Intermediate MAE after iteration 1: 0.1055
#   Iteration 2/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1820
#     X_std (max value): 0.25946973967044973
#     Avg Std of Queried Cells: 0.1942
#     Intermediate MAE after iteration 2: 0.1043
#   Iteration 3/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1797
#     X_std (max value): 0.24049186717514806
#     Avg Std of Queried Cells: 0.1940
#     Intermediate MAE after iteration 3: 0.1001
#   Iteration 4/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1774
#     X_std (max value): 0.2210597647221234
#     Avg Std of Queried Cells: 0.1938
#     Intermediate MAE after iteration 4: 0.0992
#   Iteration 5/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.2239299786747738
#     Avg Std of Queried Cells: 0.1903
#     Intermediate MAE after iteration 5: 0.0958
#   Iteration 6/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1728
#     X_std (max value): 0.2667821479346304
#     Avg Std of Queried Cells: 0.1885
#     Intermediate MAE after iteration 6: 0.0953
#   Iteration 7/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1705
#     X_std (max value): 0.2311876904215175
#     Avg Std of Queried Cells: 0.1839
#     Intermediate MAE after iteration 7: 0.0940
#   Iteration 8/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1682
#     X_std (max value): 0.24006007030740786
#     Avg Std of Queried Cells: 0.1940
#     Intermediate MAE after iteration 8: 0.0913
#   Final MAE: 0.0913, Time: 541.07s, Unique Queried: 184, Avg Std: 0.1915
#
# Running iterative ActiveFix with k=9 steps...
#   Iteration 1/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22214954351801697
#     Avg Std of Queried Cells: 0.1979
#     Intermediate MAE after iteration 1: 0.1060
#   Iteration 2/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1823
#     X_std (max value): 0.25831896818273775
#     Avg Std of Queried Cells: 0.2088
#     Intermediate MAE after iteration 2: 0.1013
#   Iteration 3/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1803
#     X_std (max value): 0.26006400631930815
#     Avg Std of Queried Cells: 0.1995
#     Intermediate MAE after iteration 3: 0.1017
#   Iteration 4/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.21255209781531376
#     Avg Std of Queried Cells: 0.1948
#     Intermediate MAE after iteration 4: 0.0994
#   Iteration 5/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1763
#     X_std (max value): 0.26093896963853547
#     Avg Std of Queried Cells: 0.2039
#     Intermediate MAE after iteration 5: 0.0963
#   Iteration 6/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1743
#     X_std (max value): 0.2569833271894125
#     Avg Std of Queried Cells: 0.2026
#     Intermediate MAE after iteration 6: 0.0967
#   Iteration 7/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.251997293247616
#     Avg Std of Queried Cells: 0.1964
#     Intermediate MAE after iteration 7: 0.0948
#   Iteration 8/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1703
#     X_std (max value): 0.2589430660425583
#     Avg Std of Queried Cells: 0.1952
#     Intermediate MAE after iteration 8: 0.0925
#   Iteration 9/9...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1683
#     X_std (max value): 0.26469763006959435
#     Avg Std of Queried Cells: 0.1968
#     Intermediate MAE after iteration 9: 0.0926
#   Final MAE: 0.0926, Time: 538.84s, Unique Queried: 180, Avg Std: 0.1996
#
# Running iterative ActiveFix with k=10 steps...
#   Iteration 1/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22630458597621456
#     Avg Std of Queried Cells: 0.2030
#     Intermediate MAE after iteration 1: 0.1063
#   Iteration 2/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1825
#     X_std (max value): 0.22572322330421832
#     Avg Std of Queried Cells: 0.2042
#     Intermediate MAE after iteration 2: 0.1035
#   Iteration 3/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.2550080675705931
#     Avg Std of Queried Cells: 0.1928
#     Intermediate MAE after iteration 3: 0.1022
#   Iteration 4/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1789
#     X_std (max value): 0.2639678018671019
#     Avg Std of Queried Cells: 0.2039
#     Intermediate MAE after iteration 4: 0.1008
#   Iteration 5/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.23019576017192073
#     Avg Std of Queried Cells: 0.1900
#     Intermediate MAE after iteration 5: 0.0980
#   Iteration 6/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1753
#     X_std (max value): 0.2558477706759864
#     Avg Std of Queried Cells: 0.1863
#     Intermediate MAE after iteration 6: 0.0996
#   Iteration 7/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.2343819801003972
#     Avg Std of Queried Cells: 0.1992
#     Intermediate MAE after iteration 7: 0.0970
#   Iteration 8/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1717
#     X_std (max value): 0.21606423756288423
#     Avg Std of Queried Cells: 0.1873
#     Intermediate MAE after iteration 8: 0.0955
#   Iteration 9/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.24394032510691813
#     Avg Std of Queried Cells: 0.1898
#     Intermediate MAE after iteration 9: 0.0944
#   Iteration 10/10...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1681
#     X_std (max value): 0.236195694834068
#     Avg Std of Queried Cells: 0.1875
#     Intermediate MAE after iteration 10: 0.0926
#   Final MAE: 0.0926, Time: 623.53s, Unique Queried: 180, Avg Std: 0.1944
#
# Running iterative ActiveFix with k=11 steps...
#   Iteration 1/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.23647961400155668
#     Avg Std of Queried Cells: 0.2037
#     Intermediate MAE after iteration 1: 0.1054
#   Iteration 2/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1827
#     X_std (max value): 0.22010934540483892
#     Avg Std of Queried Cells: 0.1982
#     Intermediate MAE after iteration 2: 0.1034
#   Iteration 3/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1811
#     X_std (max value): 0.22517856238823386
#     Avg Std of Queried Cells: 0.1933
#     Intermediate MAE after iteration 3: 0.1030
#   Iteration 4/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1795
#     X_std (max value): 0.2397927361334892
#     Avg Std of Queried Cells: 0.1985
#     Intermediate MAE after iteration 4: 0.1012
#   Iteration 5/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1779
#     X_std (max value): 0.26519248212341723
#     Avg Std of Queried Cells: 0.2188
#     Intermediate MAE after iteration 5: 0.1027
#   Iteration 6/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1763
#     X_std (max value): 0.25238818759427056
#     Avg Std of Queried Cells: 0.2027
#     Intermediate MAE after iteration 6: 0.0982
#   Iteration 7/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1747
#     X_std (max value): 0.257446722254289
#     Avg Std of Queried Cells: 0.2141
#     Intermediate MAE after iteration 7: 0.0978
#   Iteration 8/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1731
#     X_std (max value): 0.2395086272313354
#     Avg Std of Queried Cells: 0.1983
#     Intermediate MAE after iteration 8: 0.0955
#   Iteration 9/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1715
#     X_std (max value): 0.2555253052319706
#     Avg Std of Queried Cells: 0.2011
#     Intermediate MAE after iteration 9: 0.0954
#   Iteration 10/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.26237362279368975
#     Avg Std of Queried Cells: 0.2080
#     Intermediate MAE after iteration 10: 0.0936
#   Iteration 11/11...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1683
#     X_std (max value): 0.21756060303505625
#     Avg Std of Queried Cells: 0.1941
#     Intermediate MAE after iteration 11: 0.0938
#   Final MAE: 0.0938, Time: 624.71s, Unique Queried: 176, Avg Std: 0.2028
#
# Running iterative ActiveFix with k=12 steps...
#   Iteration 1/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.23854120632546305
#     Avg Std of Queried Cells: 0.2029
#     Intermediate MAE after iteration 1: 0.1049
#   Iteration 2/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1828
#     X_std (max value): 0.2530394633506595
#     Avg Std of Queried Cells: 0.2116
#     Intermediate MAE after iteration 2: 0.1028
#   Iteration 3/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1813
#     X_std (max value): 0.24496806793483653
#     Avg Std of Queried Cells: 0.2029
#     Intermediate MAE after iteration 3: 0.1025
#   Iteration 4/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1798
#     X_std (max value): 0.24456390216898338
#     Avg Std of Queried Cells: 0.2071
#     Intermediate MAE after iteration 4: 0.0999
#   Iteration 5/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.25910627691688487
#     Avg Std of Queried Cells: 0.2080
#     Intermediate MAE after iteration 5: 0.0993
#   Iteration 6/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1768
#     X_std (max value): 0.27612853948301613
#     Avg Std of Queried Cells: 0.2047
#     Intermediate MAE after iteration 6: 0.0993
#   Iteration 7/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1753
#     X_std (max value): 0.25041834095028837
#     Avg Std of Queried Cells: 0.2090
#     Intermediate MAE after iteration 7: 0.0970
#   Iteration 8/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1738
#     X_std (max value): 0.2624988161355298
#     Avg Std of Queried Cells: 0.2131
#     Intermediate MAE after iteration 8: 0.0953
#   Iteration 9/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.2376918085584442
#     Avg Std of Queried Cells: 0.2005
#     Intermediate MAE after iteration 9: 0.0952
#   Iteration 10/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1708
#     X_std (max value): 0.264682488424013
#     Avg Std of Queried Cells: 0.2030
#     Intermediate MAE after iteration 10: 0.0948
#   Iteration 11/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1693
#     X_std (max value): 0.2432387888913938
#     Avg Std of Queried Cells: 0.2002
#     Intermediate MAE after iteration 11: 0.0929
#   Iteration 12/12...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1678
#     X_std (max value): 0.24014964986590698
#     Avg Std of Queried Cells: 0.1954
#     Intermediate MAE after iteration 12: 0.0905
#   Final MAE: 0.0905, Time: 782.03s, Unique Queried: 180, Avg Std: 0.2049
#
# Running iterative ActiveFix with k=13 steps...
#   Iteration 1/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2410975650897306
#     Avg Std of Queried Cells: 0.2113
#     Intermediate MAE after iteration 1: 0.1035
#   Iteration 2/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1829
#     X_std (max value): 0.24860959371135577
#     Avg Std of Queried Cells: 0.2178
#     Intermediate MAE after iteration 2: 0.1042
#   Iteration 3/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1815
#     X_std (max value): 0.2164243653445071
#     Avg Std of Queried Cells: 0.2025
#     Intermediate MAE after iteration 3: 0.1026
#   Iteration 4/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1801
#     X_std (max value): 0.25421744756632975
#     Avg Std of Queried Cells: 0.2075
#     Intermediate MAE after iteration 4: 0.1023
#   Iteration 5/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1787
#     X_std (max value): 0.2657519426659595
#     Avg Std of Queried Cells: 0.2024
#     Intermediate MAE after iteration 5: 0.1003
#   Iteration 6/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1773
#     X_std (max value): 0.27171496798412065
#     Avg Std of Queried Cells: 0.2074
#     Intermediate MAE after iteration 6: 0.0995
#   Iteration 7/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1759
#     X_std (max value): 0.25138740042337626
#     Avg Std of Queried Cells: 0.2256
#     Intermediate MAE after iteration 7: 0.0990
#   Iteration 8/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1745
#     X_std (max value): 0.22812570446237307
#     Avg Std of Queried Cells: 0.1988
#     Intermediate MAE after iteration 8: 0.0988
#   Iteration 9/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1731
#     X_std (max value): 0.2362306839644659
#     Avg Std of Queried Cells: 0.1895
#     Intermediate MAE after iteration 9: 0.0968
#   Iteration 10/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1717
#     X_std (max value): 0.21952514380566587
#     Avg Std of Queried Cells: 0.2036
#     Intermediate MAE after iteration 10: 0.0956
#   Iteration 11/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1703
#     X_std (max value): 0.2682014138294316
#     Avg Std of Queried Cells: 0.2047
#     Intermediate MAE after iteration 11: 0.0955
#   Iteration 12/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1689
#     X_std (max value): 0.2261647877590844
#     Avg Std of Queried Cells: 0.1910
#     Intermediate MAE after iteration 12: 0.0927
#   Iteration 13/13...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1675
#     X_std (max value): 0.26253071356529195
#     Avg Std of Queried Cells: 0.2101
#     Intermediate MAE after iteration 13: 0.0918
#   Final MAE: 0.0918, Time: 823.98s, Unique Queried: 182, Avg Std: 0.2056
#
# Running iterative ActiveFix with k=14 steps...
#   Iteration 1/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2705473500820637
#     Avg Std of Queried Cells: 0.2196
#     Intermediate MAE after iteration 1: 0.1054
#   Iteration 2/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1830
#     X_std (max value): 0.268256697358043
#     Avg Std of Queried Cells: 0.2162
#     Intermediate MAE after iteration 2: 0.1037
#   Iteration 3/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1817
#     X_std (max value): 0.2880924877868387
#     Avg Std of Queried Cells: 0.2088
#     Intermediate MAE after iteration 3: 0.1021
#   Iteration 4/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1804
#     X_std (max value): 0.24590112581199067
#     Avg Std of Queried Cells: 0.2030
#     Intermediate MAE after iteration 4: 0.1012
#   Iteration 5/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1791
#     X_std (max value): 0.2445733213023253
#     Avg Std of Queried Cells: 0.2069
#     Intermediate MAE after iteration 5: 0.0996
#   Iteration 6/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1778
#     X_std (max value): 0.2556642974008791
#     Avg Std of Queried Cells: 0.2220
#     Intermediate MAE after iteration 6: 0.1000
#   Iteration 7/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1765
#     X_std (max value): 0.2151315059801448
#     Avg Std of Queried Cells: 0.2002
#     Intermediate MAE after iteration 7: 0.0995
#   Iteration 8/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1752
#     X_std (max value): 0.24918915536880537
#     Avg Std of Queried Cells: 0.2189
#     Intermediate MAE after iteration 8: 0.0973
#   Iteration 9/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1739
#     X_std (max value): 0.254952365085003
#     Avg Std of Queried Cells: 0.2020
#     Intermediate MAE after iteration 9: 0.0956
#   Iteration 10/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1726
#     X_std (max value): 0.22117663545122043
#     Avg Std of Queried Cells: 0.1982
#     Intermediate MAE after iteration 10: 0.0945
#   Iteration 11/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1713
#     X_std (max value): 0.25897860260301886
#     Avg Std of Queried Cells: 0.2043
#     Intermediate MAE after iteration 11: 0.0945
#   Iteration 12/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1700
#     X_std (max value): 0.2753125180872004
#     Avg Std of Queried Cells: 0.2128
#     Intermediate MAE after iteration 12: 0.0935
#   Iteration 13/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.2729209253726306
#     Avg Std of Queried Cells: 0.2098
#     Intermediate MAE after iteration 13: 0.0929
#   Iteration 14/14...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1674
#     X_std (max value): 0.2521722973856551
#     Avg Std of Queried Cells: 0.1876
#     Intermediate MAE after iteration 14: 0.0921
#   Final MAE: 0.0921, Time: 3417.42s, Unique Queried: 182, Avg Std: 0.2079
#
# Running iterative ActiveFix with k=15 steps...
#   Iteration 1/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22012632596505716
#     Avg Std of Queried Cells: 0.1998
#     Intermediate MAE after iteration 1: 0.1056
#   Iteration 2/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1831
#     X_std (max value): 0.25640077377776793
#     Avg Std of Queried Cells: 0.2259
#     Intermediate MAE after iteration 2: 0.1048
#   Iteration 3/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1819
#     X_std (max value): 0.24406677919491251
#     Avg Std of Queried Cells: 0.2075
#     Intermediate MAE after iteration 3: 0.1029
#   Iteration 4/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1807
#     X_std (max value): 0.22900793266587693
#     Avg Std of Queried Cells: 0.2010
#     Intermediate MAE after iteration 4: 0.1008
#   Iteration 5/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1795
#     X_std (max value): 0.24067080055962595
#     Avg Std of Queried Cells: 0.2147
#     Intermediate MAE after iteration 5: 0.1023
#   Iteration 6/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1783
#     X_std (max value): 0.2220399878065619
#     Avg Std of Queried Cells: 0.2015
#     Intermediate MAE after iteration 6: 0.1001
#   Iteration 7/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1771
#     X_std (max value): 0.2541020954195082
#     Avg Std of Queried Cells: 0.2148
#     Intermediate MAE after iteration 7: 0.1014
#   Iteration 8/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1759
#     X_std (max value): 0.26263563672918355
#     Avg Std of Queried Cells: 0.2137
#     Intermediate MAE after iteration 8: 0.0988
#   Iteration 9/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1747
#     X_std (max value): 0.24120164888065312
#     Avg Std of Queried Cells: 0.2063
#     Intermediate MAE after iteration 9: 0.0978
#   Iteration 10/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1735
#     X_std (max value): 0.24298715225179693
#     Avg Std of Queried Cells: 0.2018
#     Intermediate MAE after iteration 10: 0.0978
#   Iteration 11/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1723
#     X_std (max value): 0.24560890839439628
#     Avg Std of Queried Cells: 0.2106
#     Intermediate MAE after iteration 11: 0.0969
#   Iteration 12/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1711
#     X_std (max value): 0.2504531652087741
#     Avg Std of Queried Cells: 0.2030
#     Intermediate MAE after iteration 12: 0.0960
#   Iteration 13/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1699
#     X_std (max value): 0.2569423748099592
#     Avg Std of Queried Cells: 0.2121
#     Intermediate MAE after iteration 13: 0.0943
#   Iteration 14/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1687
#     X_std (max value): 0.24624539514869168
#     Avg Std of Queried Cells: 0.2156
#     Intermediate MAE after iteration 14: 0.0945
#   Iteration 15/15...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1675
#     X_std (max value): 0.23047611857565045
#     Avg Std of Queried Cells: 0.1885
#     Intermediate MAE after iteration 15: 0.0924
#   Final MAE: 0.0924, Time: 871.97s, Unique Queried: 180, Avg Std: 0.2078
#
# ===== Running for Budget Fraction: 0.2 =====
#
# Running iterative ActiveFix with k=1 steps...
#   Iteration 1/1...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.2713816655546733
#     Avg Std of Queried Cells: 0.1284
#     Intermediate MAE after iteration 1: 0.0805
#   Final MAE: 0.0805, Time: 68.67s, Unique Queried: 368, Avg Std: 0.1284
#
# Running iterative ActiveFix with k=2 steps...
#   Iteration 1/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22652596518469276
#     Avg Std of Queried Cells: 0.1485
#     Intermediate MAE after iteration 1: 0.0936
#   Iteration 2/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1659
#     X_std (max value): 0.254768871649315
#     Avg Std of Queried Cells: 0.1385
#     Intermediate MAE after iteration 2: 0.0786
#   Final MAE: 0.0786, Time: 111.94s, Unique Queried: 368, Avg Std: 0.1435
#
# Running iterative ActiveFix with k=3 steps...
#   Iteration 1/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.27491018170614157
#     Avg Std of Queried Cells: 0.1581
#     Intermediate MAE after iteration 1: 0.0985
#   Iteration 2/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1721
#     X_std (max value): 0.2603600206590337
#     Avg Std of Queried Cells: 0.1559
#     Intermediate MAE after iteration 2: 0.0871
#   Iteration 3/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1599
#     X_std (max value): 0.24503003023031436
#     Avg Std of Queried Cells: 0.1451
#     Intermediate MAE after iteration 3: 0.0787
#   Final MAE: 0.0787, Time: 177.68s, Unique Queried: 366, Avg Std: 0.1530
#
# Running iterative ActiveFix with k=4 steps...
#   Iteration 1/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22366248175076794
#     Avg Std of Queried Cells: 0.1657
#     Intermediate MAE after iteration 1: 0.1012
#   Iteration 2/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1751
#     X_std (max value): 0.2451704489965485
#     Avg Std of Queried Cells: 0.1620
#     Intermediate MAE after iteration 2: 0.0931
#   Iteration 3/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1659
#     X_std (max value): 0.24142513304549557
#     Avg Std of Queried Cells: 0.1593
#     Intermediate MAE after iteration 3: 0.0853
#   Iteration 4/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1567
#     X_std (max value): 0.23546736662141501
#     Avg Std of Queried Cells: 0.1517
#     Intermediate MAE after iteration 4: 0.0786
#   Final MAE: 0.0786, Time: 235.77s, Unique Queried: 368, Avg Std: 0.1597
#
# Running iterative ActiveFix with k=5 steps...
#   Iteration 1/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.22641032320891044
#     Avg Std of Queried Cells: 0.1701
#     Intermediate MAE after iteration 1: 0.1014
#   Iteration 2/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1770
#     X_std (max value): 0.25883923555572497
#     Avg Std of Queried Cells: 0.1739
#     Intermediate MAE after iteration 2: 0.0949
#   Iteration 3/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1697
#     X_std (max value): 0.28738693388014974
#     Avg Std of Queried Cells: 0.1690
#     Intermediate MAE after iteration 3: 0.0890
#   Iteration 4/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1624
#     X_std (max value): 0.22484707943851215
#     Avg Std of Queried Cells: 0.1555
#     Intermediate MAE after iteration 4: 0.0842
#   Iteration 5/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1551
#     X_std (max value): 0.2226615379380214
#     Avg Std of Queried Cells: 0.1594
#     Intermediate MAE after iteration 5: 0.0799
#   Final MAE: 0.0799, Time: 341.70s, Unique Queried: 365, Avg Std: 0.1656
#
# Running iterative ActiveFix with k=6 steps...
#   Iteration 1/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1843
#     X_std (max value): 0.25656315025680465
#     Avg Std of Queried Cells: 0.1830
#     Intermediate MAE after iteration 1: 0.1019
#   Iteration 2/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1782
#     X_std (max value): 0.2644077274689002
#     Avg Std of Queried Cells: 0.1728
#     Intermediate MAE after iteration 2: 0.0958
#   Iteration 3/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1721
#     X_std (max value): 0.24983530534195297
#     Avg Std of Queried Cells: 0.1732
#     Intermediate MAE after iteration 3: 0.0911
#   Iteration 4/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 1660
#     X_std (max value): 0.23058399941846974
#     Avg Std of Queried Cells: 0.1648
#     Intermediate MAE after iteration 4: 0.0890
#   Iteration 5/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!

# %% [markdown]
# MNAR

# %%
generator_mnar = Inject_Missing_Values()
X_missing, index_mcar = generator_mcar.MNAR(X, missing_rate=30,dependencies=dependencies_mnar)
mask = X_missing.isna()
missing_pos = np.argwhere(mask.values)

results_fullyActive_mnar = []
max_k = 15
budget_fractions = [0.1, 0.2, 0.3]

for budget_fraction in budget_fractions:
    print(f"\n===== Running for Budget Fraction: {budget_fraction} =====")
    budget = int(budget_fraction * len(missing_pos))

    for k in range(1, max_k + 1):
        print(f"\nRunning iterative ActiveFix with k={k} steps...")
        start = time.time()
        current_X = X_missing.copy()
        fixed_mask = np.zeros_like(mask.values, dtype=bool)  # Tracks fixed values
        budget_per_iter = budget // k

        if budget_per_iter == 0:
            print(f"  Skipping k={k} (budget too small per iteration)")
            continue

        intermediate_mae = []
        unique_queried_cells = set()
        avg_std_per_iteration = []

        for step in range(k):
            print(f"  Iteration {step+1}/{k}...")

            # Start from the original missing data with fixed values filled in
            initial_X = X_missing.values.copy()
            initial_X[fixed_mask] = GroundTruth.values[fixed_mask]

            # Run OTimputer 4 times to obtain aggregated imputed values
            X_runs = []
            for _ in range(4):
                Xt = torch.tensor(initial_X, dtype=torch.float64)
                X_imp = OTimputerFullyActive(niter=100, batchsize=64).fit_transform(Xt).detach().numpy()
                X_runs.append(X_imp)

            # Aggregate the imputed values (mean and std)
            X_stack = np.stack(X_runs)
            X_mean = np.mean(X_stack, axis=0)
            X_std = np.std(X_stack, axis=0)

            # Update the imputed values with the aggregated mean, keeping fixed values intact
            current_X.values[mask.values & ~fixed_mask] = X_mean[mask.values & ~fixed_mask]

            # Identify uncertain cells not fixed yet
            candidates = np.argwhere(mask.values & ~fixed_mask)
            std_vals = np.array([X_std[tuple(pos)] for pos in candidates])

            # Sort the standard deviations in descending order and select the top uncertain cells
            top_idx = np.argsort(-std_vals)[:min(budget_per_iter, len(std_vals))]
            selected_pos = candidates[top_idx]

            # Update unique queried cells and average std for this iteration
            unique_queried_cells.update([tuple(pos) for pos in selected_pos])
            avg_std = np.mean([X_std[tuple(pos)] for pos in selected_pos])
            avg_std_per_iteration.append(avg_std)

            print(f"    X_std (non-zero elements): {np.count_nonzero(X_std)}")
            print(f"    X_std (max value): {np.max(X_std)}")
            print(f"    Avg Std of Queried Cells: {avg_std:.4f}")

            # Query the oracle and update the dataset
            if selected_pos.size > 0:
                rows, cols = zip(*selected_pos)
                current_X.values[rows, cols] = GroundTruth.values[rows, cols]
                fixed_mask[rows, cols] = True  # Mark these cells as fixed

            # Calculate intermediate MAE after each iteration
            mae_iter = mean_absolute_error(GroundTruth.values[mask.values], current_X.values[mask.values])
            intermediate_mae.append(mae_iter)
            print(f"    Intermediate MAE after iteration {step+1}: {mae_iter:.4f}")

        elapsed = time.time() - start
        mae = mean_absolute_error(GroundTruth.values[mask.values], current_X.values[mask.values])
        num_unique = len(unique_queried_cells)
        avg_std_total = np.mean(avg_std_per_iteration)

        results_fullyActive_mnar.append({
            'k': k,
            'BudgetFraction': budget_fraction,
            'MAE': mae,
            'Runtime': elapsed,
            'UniqueQueried': num_unique,
            'AvgStdQueried': avg_std_total
        })
        print(f"  Final MAE: {mae:.4f}, Time: {elapsed:.2f}s, Unique Queried: {num_unique}, Avg Std: {avg_std_total:.4f}")

# Convert results to DataFrame and display
df_iter_mnar = pd.DataFrame(results_fullyActive_mnar)
print("\nFinal Results:")
print(df_iter_mnar)

df_iter_mnar = pd.DataFrame(results_fullyActive_mnar)
print("\nFinal Results:")
print(df_iter_mnar)

# Save the results to CSV
df_iter_mnar.to_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MNAR.csv", index=False)
# Out:
# Running iterative ActiveFix with k=1 steps...
#   Iteration 1/1...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.2741122672710596
#     Avg Std of Queried Cells: 0.1462
#     Intermediate MAE after iteration 1: 0.1782
#   Final MAE: 0.1782, Time: 29.53s, Unique Queried: 20513, Avg Std: 0.1462
#
# Running iterative ActiveFix with k=2 steps...
#   Iteration 1/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.2629870274483607
#     Avg Std of Queried Cells: 0.1597
#     Intermediate MAE after iteration 1: 0.1881
#   Iteration 2/2...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 194880
#     X_std (max value): 0.2508199735910041
#     Avg Std of Queried Cells: 0.1584
#     Intermediate MAE after iteration 2: 0.1760
#   Final MAE: 0.1760, Time: 2599.96s, Unique Queried: 20512, Avg Std: 0.1590
#
# Running iterative ActiveFix with k=3 steps...
#   Iteration 1/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.2680783456412533
#     Avg Std of Queried Cells: 0.1668
#     Intermediate MAE after iteration 1: 0.1916
#   Iteration 2/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 198299
#     X_std (max value): 0.27393149968904257
#     Avg Std of Queried Cells: 0.1656
#     Intermediate MAE after iteration 2: 0.1834
#   Iteration 3/3...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 191462
#     X_std (max value): 0.2701726415075083
#     Avg Std of Queried Cells: 0.1650
#     Intermediate MAE after iteration 3: 0.1754
#   Final MAE: 0.1754, Time: 70.19s, Unique Queried: 20511, Avg Std: 0.1658
#
# Running iterative ActiveFix with k=4 steps...
#   Iteration 1/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.25850037451536195
#     Avg Std of Queried Cells: 0.1711
#     Intermediate MAE after iteration 1: 0.1933
#   Iteration 2/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 200008
#     X_std (max value): 0.2635217551756177
#     Avg Std of Queried Cells: 0.1713
#     Intermediate MAE after iteration 2: 0.1871
#   Iteration 3/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 194880
#     X_std (max value): 0.25084328629301633
#     Avg Std of Queried Cells: 0.1699
#     Intermediate MAE after iteration 3: 0.1813
#   Iteration 4/4...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 189752
#     X_std (max value): 0.27226941940421007
#     Avg Std of Queried Cells: 0.1704
#     Intermediate MAE after iteration 4: 0.1751
#   Final MAE: 0.1751, Time: 46.21s, Unique Queried: 20512, Avg Std: 0.1707
#
# Running iterative ActiveFix with k=5 steps...
#   Iteration 1/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.26699758296025644
#     Avg Std of Queried Cells: 0.1750
#     Intermediate MAE after iteration 1: 0.1945
#   Iteration 2/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 201034
#     X_std (max value): 0.26426474646756626
#     Avg Std of Queried Cells: 0.1742
#     Intermediate MAE after iteration 2: 0.1896
#   Iteration 3/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 196932
#     X_std (max value): 0.2617993316455004
#     Avg Std of Queried Cells: 0.1743
#     Intermediate MAE after iteration 3: 0.1843
#   Iteration 4/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 192830
#     X_std (max value): 0.26550782549743523
#     Avg Std of Queried Cells: 0.1732
#     Intermediate MAE after iteration 4: 0.1796
#   Iteration 5/5...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 188728
#     X_std (max value): 0.2738988797956668
#     Avg Std of Queried Cells: 0.1738
#     Intermediate MAE after iteration 5: 0.1747
#   Final MAE: 0.1747, Time: 53.50s, Unique Queried: 20510, Avg Std: 0.1741
#
# Running iterative ActiveFix with k=6 steps...
#   Iteration 1/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.24895924371010647
#     Avg Std of Queried Cells: 0.1778
#     Intermediate MAE after iteration 1: 0.1950
#   Iteration 2/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 201718
#     X_std (max value): 0.24924834869317355
#     Avg Std of Queried Cells: 0.1779
#     Intermediate MAE after iteration 2: 0.1909
#   Iteration 3/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 198300
#     X_std (max value): 0.28090481236373
#     Avg Std of Queried Cells: 0.1769
#     Intermediate MAE after iteration 3: 0.1867
#   Iteration 4/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 194882
#     X_std (max value): 0.2704863582686674
#     Avg Std of Queried Cells: 0.1761
#     Intermediate MAE after iteration 4: 0.1827
#   Iteration 5/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 191464
#     X_std (max value): 0.27651891762859654
#     Avg Std of Queried Cells: 0.1770
#     Intermediate MAE after iteration 5: 0.1785
#   Iteration 6/6...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 188046
#     X_std (max value): 0.2559976278771216
#     Avg Std of Queried Cells: 0.1759
#     Intermediate MAE after iteration 6: 0.1746
#   Final MAE: 0.1746, Time: 67.05s, Unique Queried: 20508, Avg Std: 0.1769
#
# Running iterative ActiveFix with k=7 steps...
#   Iteration 1/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.2662133377245676
#     Avg Std of Queried Cells: 0.1805
#     Intermediate MAE after iteration 1: 0.1954
#   Iteration 2/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 202206
#     X_std (max value): 0.27181258600390074
#     Avg Std of Queried Cells: 0.1800
#     Intermediate MAE after iteration 2: 0.1917
#   Iteration 3/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 199276
#     X_std (max value): 0.26817514362098827
#     Avg Std of Queried Cells: 0.1799
#     Intermediate MAE after iteration 3: 0.1880
#   Iteration 4/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 196346
#     X_std (max value): 0.2705482748978924
#     Avg Std of Queried Cells: 0.1798
#     Intermediate MAE after iteration 4: 0.1847
#   Iteration 5/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 193416
#     X_std (max value): 0.26940279055856897
#     Avg Std of Queried Cells: 0.1792
#     Intermediate MAE after iteration 5: 0.1812
#   Iteration 6/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 190486
#     X_std (max value): 0.27958288505942624
#     Avg Std of Queried Cells: 0.1793
#     Intermediate MAE after iteration 6: 0.1777
#   Iteration 7/7...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 187556
#     X_std (max value): 0.2933637459656477
#     Avg Std of Queried Cells: 0.1789
#     Intermediate MAE after iteration 7: 0.1741
#   Final MAE: 0.1741, Time: 78.72s, Unique Queried: 20510, Avg Std: 0.1797
#
# Running iterative ActiveFix with k=8 steps...
#   Iteration 1/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 205136
#     X_std (max value): 0.26213303672378585
#     Avg Std of Queried Cells: 0.1823
#     Intermediate MAE after iteration 1: 0.1960
#   Iteration 2/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 202572
#     X_std (max value): 0.25589863490591563
#     Avg Std of Queried Cells: 0.1817
#     Intermediate MAE after iteration 2: 0.1927
#   Iteration 3/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 200008
#     X_std (max value): 0.2901843334108031
#     Avg Std of Queried Cells: 0.1823
#     Intermediate MAE after iteration 3: 0.1898
#   Iteration 4/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 197444
#     X_std (max value): 0.2567607781961681
#     Avg Std of Queried Cells: 0.1826
#     Intermediate MAE after iteration 4: 0.1864
#   Iteration 5/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 194880
#     X_std (max value): 0.2839708852789714
#     Avg Std of Queried Cells: 0.1816
#     Intermediate MAE after iteration 5: 0.1834
#   Iteration 6/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 192316
#     X_std (max value): 0.28856947945023875
#     Avg Std of Queried Cells: 0.1813
#     Intermediate MAE after iteration 6: 0.1802
#   Iteration 7/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 189752
#     X_std (max value): 0.2632394587967656
#     Avg Std of Queried Cells: 0.1814
#     Intermediate MAE after iteration 7: 0.1771
#   Iteration 8/8...
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
# OT imputer vanilla implementation!!
#     X_std (non-zero elements): 187188
#     X_std (max value): 0.2721382536306778
#     Avg Std of Queried Cells: 0.1815
#     Intermediate MAE after iteration 8: 0.1743
#   Final MAE: 0.1743, Time: 87.28s, Unique Queried: 20512, Avg Std: 0.1818
#
# Final Results:
#    k       MAE      Runtime  UniqueQueried  AvgStdQueried
# 0  1  0.178158    29.533065          20513       0.146216
# 1  2  0.175966  2599.956932          20512       0.159035
# 2  3  0.175401    70.189646          20511       0.165799
# 3  4  0.175143    46.213095          20512       0.170673
# 4  5  0.174665    53.503843          20510       0.174104
# 5  6  0.174556    67.053292          20508       0.176921
# 6  7  0.174142    78.720068          20510       0.179653
# 7  8  0.174264    87.278337          20512       0.181845

# %% [markdown]
# ## Visualization

# %% [markdown]
# MAE vs Missingness among OT-Impute, OT-Rand, Batch-Impute

# %% [markdown]
# MCAR

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the experiment results
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_results_mcar_metrics.csv")
df.columns = [ "MissingRate","Budget", "Method", "MAE", "MSE"]

# Plotting
print("Plotting results...")

# Filter to include only the required methods
methods_to_plot = ["OT-Impute", "OT-Rand", "Batch-Impute"]
df = df[df['Method'].isin(methods_to_plot)]
# Replace 'Index' with actual missing rate in percent
df["MissingRate"] = (df["MissingRate"] + 1) * 10


# Rename methods for clarity
#df['Method'] = df['Method'].replace({
    #"OT-Impute": "OT-Impute",
    #"OT + Random": "OT-Rand",
    #"OT + Confidence": "Batch-Impute"
#})

# Set fixed Y-axis range for all plots
y_min = 0.08
y_max = 0.20

# Custom font sizes
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
marker_size = 15

# Enforce font sizes with rcParams
plt.rcParams.update({
    'axes.titlesize': x_label_fontsize,
    'axes.labelsize': y_label_fontsize,
    'xtick.labelsize': x_tick_fontsize,
    'ytick.labelsize': y_tick_fontsize,
    'legend.fontsize': legend_label_fontsize,
    'legend.title_fontsize': legend_title_fontsize
})

# Plot settings with the "muted" palette
sns.set(style="whitegrid", font_scale=1.2)
sns.set_palette("muted")  # Use the muted palette for slightly darker colors

# Define marker styles for each method
markers = {"OT-Impute": "o", "OT-Rand": "s", "Batch-Impute": "D"}  # Circle, square, diamond

for i, budget in enumerate([0.1, 0.2, 0.3]):
    plt.figure(figsize=(8, 8))  # Equal width and height
    subset = df[df['Budget'] == budget]
    
    # Create the line plot
    ax = sns.lineplot(
        data=subset, x="MissingRate", y="MAE", hue="Method", 
        style="Method", markers=markers, dashes=False, markersize=marker_size
    )
    
    # Set consistent Y-axis range
    plt.ylim(y_min, y_max)

    # Customize axis labels
    plt.xlabel("Missing Rate%", fontsize=x_label_fontsize)
    plt.ylabel("MAE", fontsize=y_label_fontsize)

    # Add legend only to the first plot
    if i == 0:
        plt.legend(title="Method", fontsize=legend_label_fontsize, title_fontsize=legend_title_fontsize)
    else:
        ax.get_legend().remove()

    # Dark black borders on all four sides
    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_color('black')
        spine.set_linewidth(2)

    # Adding small horizontal grid lines for y-axis values
    ax.yaxis.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)

    # Adjust the line and marker size
    for line in ax.lines:
        line.set_markersize(marker_size)  # Increased symbol size
        line.set_linewidth(2)

    # Set font size for X and Y axis tick labels
    ax.tick_params(axis='x', labelsize=x_tick_fontsize)
    ax.tick_params(axis='y', labelsize=y_tick_fontsize)

    # Adding small tick marks on the y-axis
    ax.yaxis.set_tick_params(width=1.5, length=5)

    # Save the plot as PDF without title
    plt.tight_layout()
    #plt.savefig(f"active_imputation_budget_{int(budget * 100)}.pdf", format="pdf", bbox_inches="tight")
    plt.savefig(
    rf"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MCAR_active_imputation_budget_{int(budget * 100)}.pdf",
    format="pdf",
    bbox_inches="tight"
)
    print(f"Saved plot for budget {int(budget * 100)}%")
    plt.show()
    plt.close()

print("All plots generated successfully.")
# Out:
# Plotting results...
# Saved plot for budget 10%
# Saved plot for budget 20%
# Saved plot for budget 30%
# All plots generated successfully.

# %% [markdown]
# MAR

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the experiment results
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_results_mar_metrics.csv")
df.columns = [ "MissingRate","Budget", "Method", "MAE", "MSE"]

# Plotting
print("Plotting results...")

# Filter to include only the required methods
methods_to_plot = ["OT-Impute", "OT-Rand", "Batch-Impute"]
df = df[df['Method'].isin(methods_to_plot)]
# Replace 'Index' with actual missing rate in percent
df["MissingRate"] = (df["MissingRate"] + 1) * 10


# Rename methods for clarity
#df['Method'] = df['Method'].replace({
    #"OT-Impute": "OT-Impute",
    #"OT + Random": "OT-Rand",
    #"OT + Confidence": "Batch-Impute"
#})

# Set fixed Y-axis range for all plots
y_min = 0.08
y_max = 0.20

# Custom font sizes
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
marker_size = 15

# Enforce font sizes with rcParams
plt.rcParams.update({
    'axes.titlesize': x_label_fontsize,
    'axes.labelsize': y_label_fontsize,
    'xtick.labelsize': x_tick_fontsize,
    'ytick.labelsize': y_tick_fontsize,
    'legend.fontsize': legend_label_fontsize,
    'legend.title_fontsize': legend_title_fontsize
})

# Plot settings with the "muted" palette
sns.set(style="whitegrid", font_scale=1.2)
sns.set_palette("muted")  # Use the muted palette for slightly darker colors

# Define marker styles for each method
markers = {"OT-Impute": "o", "OT-Rand": "s", "Batch-Impute": "D"}  # Circle, square, diamond

for i, budget in enumerate([0.1, 0.2, 0.3]):
    plt.figure(figsize=(8, 8))  # Equal width and height
    subset = df[df['Budget'] == budget]
    
    # Create the line plot
    ax = sns.lineplot(
        data=subset, x="MissingRate", y="MAE", hue="Method", 
        style="Method", markers=markers, dashes=False, markersize=marker_size
    )
    
    # Set consistent Y-axis range
    plt.ylim(y_min, y_max)

    # Customize axis labels
    plt.xlabel("Missing Rate", fontsize=x_label_fontsize)
    plt.ylabel("MAE", fontsize=y_label_fontsize)

    # Add legend only to the first plot
    if i == 0:
        plt.legend(title="Method", fontsize=legend_label_fontsize, title_fontsize=legend_title_fontsize)
    else:
        ax.get_legend().remove()

    # Dark black borders on all four sides
    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_color('black')
        spine.set_linewidth(2)

    # Adding small horizontal grid lines for y-axis values
    ax.yaxis.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)

    # Adjust the line and marker size
    for line in ax.lines:
        line.set_markersize(marker_size)  # Increased symbol size
        line.set_linewidth(2)

    # Set font size for X and Y axis tick labels
    ax.tick_params(axis='x', labelsize=x_tick_fontsize)
    ax.tick_params(axis='y', labelsize=y_tick_fontsize)

    # Adding small tick marks on the y-axis
    ax.yaxis.set_tick_params(width=1.5, length=5)

    # Save the plot as PDF without title
    plt.tight_layout()
    #plt.savefig(f"active_imputation_budget_{int(budget * 100)}.pdf", format="pdf", bbox_inches="tight")
    plt.savefig(
    rf"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAR_active_imputation_budget_{int(budget * 100)}.pdf",
    format="pdf",
    bbox_inches="tight"
)
    print(f"Saved plot for budget {int(budget * 100)}%")
    plt.show()
    plt.close()

print("All plots generated successfully.")
# Out:
# Plotting results...
# Saved plot for budget 10%
# Saved plot for budget 20%
# Saved plot for budget 30%
# All plots generated successfully.

# %% [markdown]
# MNAR

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the experiment results
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_results_mnar_metrics.csv")
df.columns = [ "MissingRate","Budget", "Method", "MAE", "MSE"]

# Plotting
print("Plotting results...")

# Filter to include only the required methods
methods_to_plot = ["OT-Impute", "OT-Rand", "Batch-Impute"]
df = df[df['Method'].isin(methods_to_plot)]
# Replace 'Index' with actual missing rate in percent
df["MissingRate"] = (df["MissingRate"] + 1) * 10


# Rename methods for clarity
#df['Method'] = df['Method'].replace({
    #"OT-Impute": "OT-Impute",
    #"OT + Random": "OT-Rand",
    #"OT + Confidence": "Batch-Impute"
#})

# Set fixed Y-axis range for all plots
y_min = 0.10
y_max = 0.27

# Custom font sizes
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
marker_size = 15

# Enforce font sizes with rcParams
plt.rcParams.update({
    'axes.titlesize': x_label_fontsize,
    'axes.labelsize': y_label_fontsize,
    'xtick.labelsize': x_tick_fontsize,
    'ytick.labelsize': y_tick_fontsize,
    'legend.fontsize': legend_label_fontsize,
    'legend.title_fontsize': legend_title_fontsize
})

# Plot settings with the "muted" palette
sns.set(style="whitegrid", font_scale=1.2)
sns.set_palette("muted")  # Use the muted palette for slightly darker colors

# Define marker styles for each method
markers = {"OT-Impute": "o", "OT-Rand": "s", "Batch-Impute": "D"}  # Circle, square, diamond

for i, budget in enumerate([0.1, 0.2, 0.3]):
    plt.figure(figsize=(8, 8))  # Equal width and height
    subset = df[df['Budget'] == budget]
    
    # Create the line plot
    ax = sns.lineplot(
        data=subset, x="MissingRate", y="MAE", hue="Method", 
        style="Method", markers=markers, dashes=False, markersize=marker_size
    )
    
    # Set consistent Y-axis range
    plt.ylim(y_min, y_max)

    # Customize axis labels
    plt.xlabel("Missing Rate", fontsize=x_label_fontsize)
    plt.ylabel("MAE", fontsize=y_label_fontsize)

    # Add legend only to the first plot
    if i == 0:
        plt.legend(title="Method", fontsize=legend_label_fontsize, title_fontsize=legend_title_fontsize)
    else:
        ax.get_legend().remove()

    # Dark black borders on all four sides
    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_color('black')
        spine.set_linewidth(2)

    # Adding small horizontal grid lines for y-axis values
    ax.yaxis.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)

    # Adjust the line and marker size
    for line in ax.lines:
        line.set_markersize(marker_size)  # Increased symbol size
        line.set_linewidth(2)

    # Set font size for X and Y axis tick labels
    ax.tick_params(axis='x', labelsize=x_tick_fontsize)
    ax.tick_params(axis='y', labelsize=y_tick_fontsize)

    # Adding small tick marks on the y-axis
    ax.yaxis.set_tick_params(width=1.5, length=5)

    # Save the plot as PDF without title
    plt.tight_layout()
    #plt.savefig(f"active_imputation_budget_{int(budget * 100)}.pdf", format="pdf", bbox_inches="tight")
    plt.savefig(
    rf"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MNAR_active_imputation_budget_{int(budget * 100)}.pdf",
    format="pdf",
    bbox_inches="tight"
)
    print(f"Saved plot for budget {int(budget * 100)}%")
    plt.show()
    plt.close()

print("All plots generated successfully.")
# Out:
# Plotting results...
# Saved plot for budget 10%
# Saved plot for budget 20%
# Saved plot for budget 30%
# All plots generated successfully.

# %% [markdown]
# ### Base Comparision

# %% [markdown]
# MCAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df_mae_diabetic = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_mae_base_comparison_mcar_budget01_allruns.csv")

# Group by method and missing rate
grouped_mae = df_mae_diabetic.groupby(["MissingRate(%)", "Method"])["MAE"].agg(["mean", "std"]).reset_index()

# Plot styling
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("Set2", n_colors=grouped_mae["Method"].nunique())

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 10

# Create line plot
plt.figure(figsize=(10, 8))
ax = sns.lineplot(
    data=df_mae_diabetic,
    x="MissingRate(%)",
    y="MAE",
    hue="Method",
    style="Method",
    markers=True,
    dashes=False,
    err_style="band",
    ci="sd",  # shaded band = ± standard deviation
    palette=palette,
    linewidth=line_width,
    markersize=marker_size
)

# === Axis labels and ticks ===
plt.xlabel("Missing Rate (%)", fontsize=x_label_fontsize, labelpad=5)
plt.ylabel("MAE", fontsize=y_label_fontsize, labelpad=5)
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and border ===
plt.grid(True, linestyle='--', color='gray', linewidth=0.7, alpha=0.7)
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(2)

# === Legend ===
plt.legend(
    title="Method",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    frameon=True
)

# Save and show
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAE_vs_MissingRate_MCAR.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# C:\Users\zhossai3\AppData\Local\Temp\ipykernel_26664\2065086437.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.lineplot(

# %% [markdown]
# MAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df_mae_diabetic = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_mae_base_comparison_mar_budget01_allruns.csv")

# Group by method and missing rate
grouped_mae = df_mae_diabetic.groupby(["MissingRate(%)", "Method"])["MAE"].agg(["mean", "std"]).reset_index()

# Plot styling
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("Set2", n_colors=grouped_mae["Method"].nunique())

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 10

# Create line plot
plt.figure(figsize=(10, 8))
ax = sns.lineplot(
    data=df_mae_diabetic,
    x="MissingRate(%)",
    y="MAE",
    hue="Method",
    style="Method",
    markers=True,
    dashes=False,
    err_style="band",
    ci="sd",  # shaded band = ± standard deviation
    palette=palette,
    linewidth=line_width,
    markersize=marker_size
)

# === Axis labels and ticks ===
plt.xlabel("Missing Rate (%)", fontsize=x_label_fontsize, labelpad=5)
plt.ylabel("MAE", fontsize=y_label_fontsize, labelpad=5)
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and border ===
plt.grid(True, linestyle='--', color='gray', linewidth=0.7, alpha=0.7)
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(2)

# === Legend ===
plt.legend(
    title="Method",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    frameon=True
)

# Save and show
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAE_vs_MissingRate_MAR.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# MNAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df_mae_diabetic = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_mae_base_comparison_mnar_budget01_allruns.csv")

# Group by method and missing rate
grouped_mae = df_mae_diabetic.groupby(["MissingRate(%)", "Method"])["MAE"].agg(["mean", "std"]).reset_index()

# Plot styling
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("Set2", n_colors=grouped_mae["Method"].nunique())

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 10

# Create line plot
plt.figure(figsize=(10, 8))
ax = sns.lineplot(
    data=df_mae_diabetic,
    x="MissingRate(%)",
    y="MAE",
    hue="Method",
    style="Method",
    markers=True,
    dashes=False,
    err_style="band",
    ci="sd",  # shaded band = ± standard deviation
    palette=palette,
    linewidth=line_width,
    markersize=marker_size
)

# === Axis labels and ticks ===
plt.xlabel("Missing Rate (%)", fontsize=x_label_fontsize, labelpad=5)
plt.ylabel("MAE", fontsize=y_label_fontsize, labelpad=5)
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and border ===
plt.grid(True, linestyle='--', color='gray', linewidth=0.7, alpha=0.7)
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(2)

# === Legend ===
plt.legend(
    title="Method",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    frameon=True
)

# Save and show
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAE_vs_MissingRate_MNAR.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### MAE VS Dropout Noise

# %% [markdown]
# MCAR

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib.ticker import LogFormatterMathtext

# Load the CSV
df_dropout = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MCAR_DropoutNoise_MAE_Results.csv")
df_dropout["DropoutNoise"] = pd.to_numeric(df_dropout["DropoutNoise"], errors='coerce')
df_dropout["MAE"] = pd.to_numeric(df_dropout["MAE"], errors='coerce')
df_dropout = df_dropout.dropna(subset=["DropoutNoise", "MAE"])

# Dropout values to include
dropOutNoises = [0.0, 0.00001, 0.00005, 0.0001, 0.0005,
                 0.001, 0.005, 0.01, 0.05]

# Filter and compute mean + std
df_line = (
    df_dropout[df_dropout["DropoutNoise"].isin(dropOutNoises)]
    .groupby("DropoutNoise")["MAE"]
    .agg(["mean", "std"])
    .reset_index()
    .sort_values("DropoutNoise")
)

# Plot styling
sns.set(style="whitegrid", font_scale=1.2)
plt.figure(figsize=(8, 8))

# Line + shaded area
plt.plot(
    df_line["DropoutNoise"], df_line["mean"],
    marker='o', color="#4c72b0", linewidth=2.5, markersize=6
)
plt.fill_between(
    df_line["DropoutNoise"],
    df_line["mean"] - df_line["std"],
    df_line["mean"] + df_line["std"],
    alpha=0.3,
    color="#4c72b0"
)

# Log scale and scientific ticks
plt.xscale("log")
plt.gca().xaxis.set_major_formatter(LogFormatterMathtext())

# Labels
plt.xlabel("Dropout Noise (δ)", fontsize=25, labelpad=5)
plt.ylabel("MAE", fontsize=25, labelpad=5)

# Ticks and rotation
plt.xticks(fontsize=23, rotation=0)
plt.yticks(fontsize=23)

# Grid and border
plt.grid(True, linestyle='--', color='gray', linewidth=0.8, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)


plt.title(r"(b) MAE vs $\delta$ (MCAR, 30%)", fontsize=22, y=-0.25)

# Save + show
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MCAR_DropoutNoise_LogPlot.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MAR

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib.ticker import LogFormatterMathtext

# Load the CSV
df_dropout = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MAR_DropoutNoise_MAE_Results.csv")
df_dropout["DropoutNoise"] = pd.to_numeric(df_dropout["DropoutNoise"], errors='coerce')
df_dropout["MAE"] = pd.to_numeric(df_dropout["MAE"], errors='coerce')
df_dropout = df_dropout.dropna(subset=["DropoutNoise", "MAE"])

# Dropout values to include
dropOutNoises = [0.0, 0.00001, 0.00005, 0.0001, 0.0005,
                 0.001, 0.005, 0.01, 0.05]

# Filter and compute mean + std
df_line = (
    df_dropout[df_dropout["DropoutNoise"].isin(dropOutNoises)]
    .groupby("DropoutNoise")["MAE"]
    .agg(["mean", "std"])
    .reset_index()
    .sort_values("DropoutNoise")
)

# Plot styling
sns.set(style="whitegrid", font_scale=1.2)
plt.figure(figsize=(8, 8))

# Line + shaded area
plt.plot(
    df_line["DropoutNoise"], df_line["mean"],
    marker='o', color="#4c72b0", linewidth=2.5, markersize=6
)
plt.fill_between(
    df_line["DropoutNoise"],
    df_line["mean"] - df_line["std"],
    df_line["mean"] + df_line["std"],
    alpha=0.3,
    color="#4c72b0"
)

# Log scale and scientific ticks
plt.xscale("log")
plt.gca().xaxis.set_major_formatter(LogFormatterMathtext())

# Labels
plt.xlabel("Dropout Noise (δ)", fontsize=25, labelpad=5)
plt.ylabel("MAE", fontsize=25, labelpad=5)

# Ticks and rotation
plt.xticks(fontsize=23, rotation=0)
plt.yticks(fontsize=23)

# Grid and border
plt.grid(True, linestyle='--', color='gray', linewidth=0.8, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)


plt.title(r"(b) MAE vs $\delta$ (MAR, 30%)", fontsize=22, y=-0.25)

# Save + show
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAR_DropoutNoise_LogPlot.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MNAR

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib.ticker import LogFormatterMathtext

# Load the CSV
df_dropout = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MNAR_DropoutNoise_MAE_Results.csv")
df_dropout["DropoutNoise"] = pd.to_numeric(df_dropout["DropoutNoise"], errors='coerce')
df_dropout["MAE"] = pd.to_numeric(df_dropout["MAE"], errors='coerce')
df_dropout = df_dropout.dropna(subset=["DropoutNoise", "MAE"])

# Dropout values to include
dropOutNoises = [0.0, 0.00001, 0.00005, 0.0001, 0.0005,
                 0.001, 0.005, 0.01, 0.05]

# Filter and compute mean + std
df_line = (
    df_dropout[df_dropout["DropoutNoise"].isin(dropOutNoises)]
    .groupby("DropoutNoise")["MAE"]
    .agg(["mean", "std"])
    .reset_index()
    .sort_values("DropoutNoise")
)

# Plot styling
sns.set(style="whitegrid", font_scale=1.2)
plt.figure(figsize=(8, 8))

# Line + shaded area
plt.plot(
    df_line["DropoutNoise"], df_line["mean"],
    marker='o', color="#4c72b0", linewidth=2.5, markersize=6
)
plt.fill_between(
    df_line["DropoutNoise"],
    df_line["mean"] - df_line["std"],
    df_line["mean"] + df_line["std"],
    alpha=0.3,
    color="#4c72b0"
)

# Log scale and scientific ticks
plt.xscale("log")
plt.gca().xaxis.set_major_formatter(LogFormatterMathtext())

# Labels
plt.xlabel("Dropout Noise (δ)", fontsize=25, labelpad=5)
plt.ylabel("MAE", fontsize=25, labelpad=5)

# Ticks and rotation
plt.xticks(fontsize=23, rotation=0)
plt.yticks(fontsize=23)

# Grid and border
plt.grid(True, linestyle='--', color='gray', linewidth=0.8, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)


plt.title(r"(b) MAE vs $\delta$ (MNAR, 30%)", fontsize=22, y=-0.25)

# Save + show
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MNAR_DropoutNoise_LogPlot.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### MAE VS Missing Rate OT-Impute, OT-Rand, Batch-Impute, BatchOP-Impute

# %% [markdown]
# MCAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load CSV ===
df_mar_mae = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MCAR_OPT_Results_MAE.csv")

# === Extract values ===
missing_rates = df_mar_mae["MissingRate"].values
results_mar_opt = {
    "Batch-Impute": df_mar_mae["Batch-Impute"].values,
    "BatchOpt-Impute": df_mar_mae["BatchOpt-Impute"].values
}

# === Plot styling ===
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("muted")

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 15

# === Create figure ===
plt.figure(figsize=(8, 8))

# Plot: Batch-Impute
plt.plot(missing_rates, results_mar_opt["Batch-Impute"],
         label="Batch-Impute",
         marker='o', color="green", linewidth=line_width, markersize=marker_size)

# Plot: BatchOpt-Impute
plt.plot(missing_rates, results_mar_opt["BatchOpt-Impute"],
         label="BatchOpt-Impute",
         marker='o', color=palette[1], linewidth=line_width, markersize=marker_size)

# === Axis and Labels ===
plt.xlabel("Missing Rate %", fontsize=x_label_fontsize, labelpad=2, fontweight='regular')
plt.ylabel("MAE", fontsize=y_label_fontsize, labelpad=2, fontweight='regular')
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and Border ===
plt.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)
ax.tick_params(axis='y', width=1.5, length=5)

# === Legend ===
plt.legend(title="Method", fontsize=legend_label_fontsize,
           title_fontsize=legend_title_fontsize, loc="center left",
           bbox_to_anchor=(0.01, 0.4), frameon=True)

# === Save and Show ===
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MCAR_OptComparision_MAE.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load CSV ===
df_mar_mae = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MAR_OPT_Results_MAE.csv")

# === Extract values ===
missing_rates = df_mar_mae["MissingRate"].values
results_mar_opt = {
    "Batch-Impute": df_mar_mae["Batch-Impute"].values,
    "BatchOpt-Impute": df_mar_mae["BatchOpt-Impute"].values
}

# === Plot styling ===
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("muted")

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 15

# === Create figure ===
plt.figure(figsize=(8, 8))

# Plot: Batch-Impute
plt.plot(missing_rates, results_mar_opt["Batch-Impute"],
         label="Batch-Impute",
         marker='o', color="green", linewidth=line_width, markersize=marker_size)

# Plot: BatchOpt-Impute
plt.plot(missing_rates, results_mar_opt["BatchOpt-Impute"],
         label="BatchOpt-Impute",
         marker='o', color=palette[1], linewidth=line_width, markersize=marker_size)

# === Axis and Labels ===
plt.xlabel("Missing Rate %", fontsize=x_label_fontsize, labelpad=2, fontweight='regular')
plt.ylabel("MAE", fontsize=y_label_fontsize, labelpad=2, fontweight='regular')
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and Border ===
plt.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)
ax.tick_params(axis='y', width=1.5, length=5)

# === Legend ===
plt.legend(title="Method", fontsize=legend_label_fontsize,
           title_fontsize=legend_title_fontsize, loc="center left",
           bbox_to_anchor=(0.01, 0.4), frameon=True)

# === Save and Show ===
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAR_OptComparision_MAE.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MNAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load CSV ===
df_mar_mae = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MNAR_OPT_Results_MAE.csv")

# === Extract values ===
missing_rates = df_mar_mae["MissingRate"].values
results_mar_opt = {
    "Batch-Impute": df_mar_mae["Batch-Impute"].values,
    "BatchOpt-Impute": df_mar_mae["BatchOpt-Impute"].values
}

# === Plot styling ===
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("muted")

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 15

# === Create figure ===
plt.figure(figsize=(8, 8))

# Plot: Batch-Impute
plt.plot(missing_rates, results_mar_opt["Batch-Impute"],
         label="Batch-Impute",
         marker='o', color="green", linewidth=line_width, markersize=marker_size)

# Plot: BatchOpt-Impute
plt.plot(missing_rates, results_mar_opt["BatchOpt-Impute"],
         label="BatchOpt-Impute",
         marker='o', color=palette[1], linewidth=line_width, markersize=marker_size)

# === Axis and Labels ===
plt.xlabel("Missing Rate %", fontsize=x_label_fontsize, labelpad=2, fontweight='regular')
plt.ylabel("MAE", fontsize=y_label_fontsize, labelpad=2, fontweight='regular')
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and Border ===
plt.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)
ax.tick_params(axis='y', width=1.5, length=5)

# === Legend ===
plt.legend(title="Method", fontsize=legend_label_fontsize,
           title_fontsize=legend_title_fontsize, loc="lower left",
           bbox_to_anchor=(0.01, 0.4), frameon=True)

# === Save and Show ===
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MNAR_OptComparision_MAE.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Runtime VS Missing Rate Batch-Impute and BatchOpt-Impute

# %% [markdown]
# MCAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load CSV ===
df_mar_time = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MCAR_OPT_Results_Time.csv")

# === Extract values ===
missing_rates = df_mar_time["MissingRate"].values
results_time_mar = {
    "Batch-Impute": df_mar_time["Batch-Impute"].values,
    "BatchOpt-Impute": df_mar_time["BatchOpt-Impute"].values
}

# === Plot styling ===
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("muted")

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 15

# === Create figure ===
plt.figure(figsize=(8, 8))

# Plot: Batch-Impute
plt.plot(missing_rates, results_time_mar["Batch-Impute"],
         label="Batch-Impute",
         marker='o', color="green", linewidth=line_width, markersize=marker_size)

# Plot: BatchOpt-Impute
plt.plot(missing_rates, results_time_mar["BatchOpt-Impute"],
         label="BatchOpt-Impute",
         marker='o', color=palette[1], linewidth=line_width, markersize=marker_size)

# === Axis and Labels ===
plt.xlabel("Missing Rate %", fontsize=x_label_fontsize, labelpad=2, fontweight='regular')
plt.ylabel("Runtime (seconds)", fontsize=y_label_fontsize, labelpad=2, fontweight='regular')
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and Border ===
plt.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)
ax.tick_params(axis='y', width=1.5, length=5)

# === Legend ===
plt.legend(title="Method", fontsize=legend_label_fontsize,
           title_fontsize=legend_title_fontsize, loc="center left",
           bbox_to_anchor=(0.01, 0.4), frameon=True)

# === Save and Show ===
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MCAR_OptComparision_Time.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load CSV ===
df_mar_time = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MAR_OPT_Results_Time.csv")

# === Extract values ===
missing_rates = df_mar_time["MissingRate"].values
results_time_mar = {
    "Batch-Impute": df_mar_time["Batch-Impute"].values,
    "BatchOpt-Impute": df_mar_time["BatchOpt-Impute"].values
}

# === Plot styling ===
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("muted")

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 15

# === Create figure ===
plt.figure(figsize=(8, 8))

# Plot: Batch-Impute
plt.plot(missing_rates, results_time_mar["Batch-Impute"],
         label="Batch-Impute",
         marker='o', color="green", linewidth=line_width, markersize=marker_size)

# Plot: BatchOpt-Impute
plt.plot(missing_rates, results_time_mar["BatchOpt-Impute"],
         label="BatchOpt-Impute",
         marker='o', color=palette[1], linewidth=line_width, markersize=marker_size)

# === Axis and Labels ===
plt.xlabel("Missing Rate %", fontsize=x_label_fontsize, labelpad=2, fontweight='regular')
plt.ylabel("Runtime (seconds)", fontsize=y_label_fontsize, labelpad=2, fontweight='regular')
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and Border ===
plt.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)
ax.tick_params(axis='y', width=1.5, length=5)

# === Legend ===
plt.legend(title="Method", fontsize=legend_label_fontsize,
           title_fontsize=legend_title_fontsize, loc="center left",
           bbox_to_anchor=(0.01, 0.4), frameon=True)

# === Save and Show ===
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MAR_OptComparision_Time.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MNAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load CSV ===
df_mar_time = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_MNAR_OPT_Results_Time.csv")

# === Extract values ===
missing_rates = df_mar_time["MissingRate"].values
results_time_mar = {
    "Batch-Impute": df_mar_time["Batch-Impute"].values,
    "BatchOpt-Impute": df_mar_time["BatchOpt-Impute"].values
}

# === Plot styling ===
sns.set(style="whitegrid", font_scale=1.2)
palette = sns.color_palette("muted")

# Font and marker settings
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25
line_width = 2
marker_size = 15

# === Create figure ===
plt.figure(figsize=(8, 8))

# Plot: Batch-Impute
plt.plot(missing_rates, results_time_mar["Batch-Impute"],
         label="Batch-Impute",
         marker='o', color="green", linewidth=line_width, markersize=marker_size)

# Plot: BatchOpt-Impute
plt.plot(missing_rates, results_time_mar["BatchOpt-Impute"],
         label="BatchOpt-Impute",
         marker='o', color=palette[1], linewidth=line_width, markersize=marker_size)

# === Axis and Labels ===
plt.xlabel("Missing Rate %", fontsize=x_label_fontsize, labelpad=2, fontweight='regular')
plt.ylabel("Runtime (seconds)", fontsize=y_label_fontsize, labelpad=2, fontweight='regular')
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# === Grid and Border ===
plt.grid(True, linestyle='--', color='grey', linewidth=0.7, alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)
ax.tick_params(axis='y', width=1.5, length=5)

# === Legend ===
plt.legend(title="Method", fontsize=legend_label_fontsize,
           title_fontsize=legend_title_fontsize, loc="center left",
           bbox_to_anchor=(0.01, 0.4), frameon=True)

# === Save and Show ===
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_MNAR_OptComparision_Time.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### MAE VS Number of Iteration for budget 0.1, 0.2, 0.3 (Iter-Impute)

# %% [markdown]
# MCAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MCAR.csv")

# Set plot style and font sizes
sns.set(style="whitegrid", font_scale=1.2)
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 20
legend_label_fontsize = 20
marker_size = 12
line_width = 3

# Define colors and markers
palette = sns.color_palette("Set2", df['BudgetFraction'].nunique())
markers = ['o', 's', 'D', '^', 'v']

# Create the plot
plt.figure(figsize=(8, 8))

for i, (budget, subset) in enumerate(df.groupby('BudgetFraction')):
    plt.plot(
        subset['k'], subset['MAE'],
        marker=markers[i % len(markers)],
        label=f"{budget:.2f}",
        linewidth=line_width,
        markersize=marker_size,
        color=palette[i]
    )

# Axis labels and ticks
plt.xlabel("Number of Iterations (k)", fontsize=x_label_fontsize)
plt.ylabel("MAE", fontsize=y_label_fontsize)
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# Grid and border
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)

plt.grid(True, linestyle='--', linewidth=0.7, color='gray', alpha=0.7)

# Legend
plt.legend(
    title="Budget",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
)

# Final layout
plt.tight_layout()

# Save the plot as PDF
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_iterative_MAE_vs_k_MCAR.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# MAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MAR.csv")

# Set plot style and font sizes
sns.set(style="whitegrid", font_scale=1.2)
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 20
legend_label_fontsize = 20
marker_size = 12
line_width = 3

# Define colors and markers
palette = sns.color_palette("Set2", df['BudgetFraction'].nunique())
markers = ['o', 's', 'D', '^', 'v']

# Create the plot
plt.figure(figsize=(8, 8))

for i, (budget, subset) in enumerate(df.groupby('BudgetFraction')):
    plt.plot(
        subset['k'], subset['MAE'],
        marker=markers[i % len(markers)],
        label=f"{budget:.2f}",
        linewidth=line_width,
        markersize=marker_size,
        color=palette[i]
    )

# Axis labels and ticks
plt.xlabel("Number of Iterations (k)", fontsize=x_label_fontsize)
plt.ylabel("MAE", fontsize=y_label_fontsize)
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# Grid and border
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)

plt.grid(True, linestyle='--', linewidth=0.7, color='gray', alpha=0.7)

# Legend
plt.legend(
    title="Budget",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
)

# Final layout
plt.tight_layout()

# Save the plot as PDF
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_iterative_MAE_vs_k_MAR.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# MNAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MNAR.csv")

# Set plot style and font sizes
sns.set(style="whitegrid", font_scale=1.2)
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 20
legend_label_fontsize = 20
marker_size = 12
line_width = 3

# Define colors and markers
palette = sns.color_palette("Set2", df['BudgetFraction'].nunique())
markers = ['o', 's', 'D', '^', 'v']

# Create the plot
plt.figure(figsize=(8, 8))

for i, (budget, subset) in enumerate(df.groupby('BudgetFraction')):
    plt.plot(
        subset['k'], subset['MAE'],
        marker=markers[i % len(markers)],
        label=f"{budget:.2f}",
        linewidth=line_width,
        markersize=marker_size,
        color=palette[i]
    )

# Axis labels and ticks
plt.xlabel("Number of Iterations (k)", fontsize=x_label_fontsize)
plt.ylabel("MAE", fontsize=y_label_fontsize)
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# Grid and border
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)

plt.grid(True, linestyle='--', linewidth=0.7, color='gray', alpha=0.7)

# Legend
plt.legend(
    title="Budget",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
)

# Final layout
plt.tight_layout()

# Save the plot as PDF
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_iterative_MAE_vs_k_MNAR.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# ### Runtime vs Number of Iteration Iter-Impute

# %% [markdown]
# MCAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MCAR.csv")

# Filter for budget = 0.1
df_budget_01 = df[df["BudgetFraction"] == 0.1]

# Set the Seaborn style
sns.set(style="whitegrid", font_scale=1.2)

# Font sizes
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25

# Plot
plt.figure(figsize=(8, 8))
plt.plot(
    df_budget_01["k"],
    df_budget_01["Runtime"],
    marker='o',
    linewidth=3,
    markersize=10,
    color="#2ca02c",  # green
    label="Budget = 0.1"
)

# Axis labels
plt.xlabel("Number of Iterations (k)", fontsize=x_label_fontsize)
plt.ylabel("Runtime (seconds)", fontsize=y_label_fontsize)

# Ticks
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# Grid and border styling
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)

# Legend
plt.legend(
    title="Method",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="upper left",
    frameon=True
)

# Layout and save
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_iterative_Runtime_vs_k_MCAR_budget01.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MAR.csv")

# Filter for budget = 0.1
df_budget_01 = df[df["BudgetFraction"] == 0.1]

# Set the Seaborn style
sns.set(style="whitegrid", font_scale=1.2)

# Font sizes
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25

# Plot
plt.figure(figsize=(8, 8))
plt.plot(
    df_budget_01["k"],
    df_budget_01["Runtime"],
    marker='o',
    linewidth=3,
    markersize=10,
    color="#2ca02c",  # green
    label="Budget = 0.1"
)

# Axis labels
plt.xlabel("Number of Iterations (k)", fontsize=x_label_fontsize)
plt.ylabel("Runtime (seconds)", fontsize=y_label_fontsize)

# Ticks
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# Grid and border styling
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)

# Legend
plt.legend(
    title="Method",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="upper left",
    frameon=True
)

# Layout and save
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_iterative_Runtime_vs_k_MAR_budget01.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# MNAR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
df = pd.read_csv(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\results\Diabetic_iterative_activeFix_results_MNAR.csv")

# Filter for budget = 0.1
df_budget_01 = df[df["BudgetFraction"] == 0.1]

# Set the Seaborn style
sns.set(style="whitegrid", font_scale=1.2)

# Font sizes
x_label_fontsize = 25
y_label_fontsize = 25
x_tick_fontsize = 23
y_tick_fontsize = 23
legend_title_fontsize = 27
legend_label_fontsize = 25

# Plot
plt.figure(figsize=(8, 8))
plt.plot(
    df_budget_01["k"],
    df_budget_01["Runtime"],
    marker='o',
    linewidth=3,
    markersize=10,
    color="#2ca02c",  # green
    label="Budget = 0.1"
)

# Axis labels
plt.xlabel("Number of Iterations (k)", fontsize=x_label_fontsize)
plt.ylabel("Runtime (seconds)", fontsize=y_label_fontsize)

# Ticks
plt.xticks(fontsize=x_tick_fontsize)
plt.yticks(fontsize=y_tick_fontsize)

# Grid and border styling
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth(2)

# Legend
plt.legend(
    title="Method",
    fontsize=legend_label_fontsize,
    title_fontsize=legend_title_fontsize,
    loc="upper left",
    frameon=True
)

# Layout and save
plt.tight_layout()
plt.savefig(r"C:\Users\zhossai3\Desktop\Active Imputation\active_imputation\Output\Diabetic_iterative_Runtime_vs_k_MNAR_budget01.pdf", format="pdf", bbox_inches='tight')
plt.show()
